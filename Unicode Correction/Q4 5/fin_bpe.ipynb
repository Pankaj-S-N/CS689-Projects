# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import json
import re

# %%
filepath = '/content/gdrive/MyDrive/cs689/a1/pped_txt.txt'

# %%
import sentencepiece as spm

# %%
spm.SentencePieceTrainer.Train('--input='+filepath+' --model_prefix=marathi_bpe --model_type=bpe --vocab_size=1000')

# %%
sp = spm.SentencePieceProcessor()
sp.load("marathi_bpe.model")
# Out:
# True

# %%
tokens = [sp.id_to_piece(i) for i in range(sp.get_piece_size())]

# %%
from collections import Counter

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/q3.txt','r',encoding='utf-8',errors='ignore')
q3_txt = z.read()
z.close()

# %%
q3_txt = re.sub(r"[^\u0900-\u094F\s,\u0966-\u096F1234567890]", "", q3_txt)

# %%
q3_txt = q3_txt.split('\n')

# %%
q3_txt[5]
# Out:
# 'त्यामुळे, पश्चिम रेल्वेवरील, लोकसेवा, १० ते १५ मिनिटं, उशिराने, धावतील'

# %%
for i in range(len(q3_txt)):
  ''.join(q3_txt[i])
  q3_txt[i] = q3_txt[i].split(',')

# %%
# ground_truth

# %%
ground_truth = []
for i in range(len(q3_txt)):
  ground_truth.append(q3_txt[i])

# %%
test_sent = []
for i in range(len(q3_txt)):
  test_sent.append(''.join(q3_txt[i]))

# %%
new_tokens=[]

# %%
for tests in test_sent:
    tokens = sp.encode(tests, out_type=str)
    new_tokens.append(tokens)

# %%
new_tokens[0][1]
# Out:
# 'ग'

# %%
corrected_new_tokens = []

# %%
for i in range(len(new_tokens)):
  corrected_new_tokens.append([])
  for j in range(len(new_tokens[i])):
    corrected_new_tokens[i].append([])

# %%
for k in range(len(new_tokens)):
  for l in range(len(new_tokens[k])):
    for i in range(len(new_tokens[k][l])-1):
        # print(i)
        if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            if (new_tokens[k][l][i]!='अ' or new_tokens[k][l][i+1]!='ं'):
                corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            else:
                corrected_new_tokens[k][l].append('अं')
        elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            if ((ord(new_tokens[k][l][i+1])<2366 or ord(new_tokens[k][l][i+1])>=2382) and new_tokens[k][l][i+1] !='ं'):
                corrected_new_tokens[k][l].append('अ')
        elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
        elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309) and new_tokens[k][l][i-1] != 'अ'):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

    i = len(new_tokens[k][l])-1
    if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
    elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
        corrected_new_tokens[k][l].append(new_tokens[k][l][i])
        corrected_new_tokens[k][l].append('अ')
    elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
    elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309)):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

# %%
for i in range(len(corrected_new_tokens)):
    corrected_new_tokens[i] = [sublist for sublist in corrected_new_tokens[i] if sublist]

# %%
for i in range(len(corrected_new_tokens)):
  for j in range(len(corrected_new_tokens[i])):
    corrected_new_tokens[i][j] = ''.join(corrected_new_tokens[i][j])
  # if i%10000==0:
  #   print(i)

# %%
# corrected_new_tokens[0]

# %%
corrected_ground_truth = []

# %%
for i in range(len(ground_truth)):
  corrected_ground_truth.append([])
  for j in range(len(ground_truth[i])):
    corrected_ground_truth[i].append([])

# %%
for k in range(len(ground_truth)):
  for l in range(len(ground_truth[k])):
    for i in range(len(ground_truth[k][l])-1):
        # print(i)
        if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            if (ground_truth[k][l][i]!='अ' or ground_truth[k][l][i+1]!='ं'):
                corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            else:
                corrected_ground_truth[k][l].append('अं')
        elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            if ((ord(ground_truth[k][l][i+1])<2366 or ord(ground_truth[k][l][i+1])>=2382) and ground_truth[k][l][i+1] !='ं'):
                corrected_ground_truth[k][l].append('अ')
        elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
        elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309) and ground_truth[k][l][i-1] != 'अ'):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

    i = len(ground_truth[k][l])-1
    if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
    elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
        corrected_ground_truth[k][l].append(ground_truth[k][l][i])
        corrected_ground_truth[k][l].append('अ')
    elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
    elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309)):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

# %%
for i in range(len(corrected_ground_truth)):
    corrected_ground_truth[i] = [sublist for sublist in corrected_ground_truth[i] if sublist]

# %%
for i in range(len(corrected_ground_truth)):
  for j in range(len(corrected_ground_truth[i])):
    corrected_ground_truth[i][j] = ''.join(corrected_ground_truth[i][j])
  # if i%10000==0:
  #   print(i)

# %%
intersection = []
for i in range(len(q3_txt)):
  intersection.append(Counter(corrected_new_tokens[i]).keys() & Counter(corrected_ground_truth[i]).keys())

# %%
intersection[1]
# Out:
# {'तयआअंनई'}

# %%
len(set(corrected_new_tokens[0]))
# Out:
# 73

# %%
precision = []
recall = []
f_score = []
for i in range(len(q3_txt)):
  precision.append([])
  recall.append([])
  f_score.append([])

# %%
for i in range(len(q3_txt)):
  precision[i] = 100*len(intersection[i]) / len(set(corrected_new_tokens[i]))

  recall[i] = 100*len(intersection[i]) / len(set(corrected_ground_truth[i]))

  f_score[i] = 2 * precision[i] * recall[i] / (precision[i] + recall[i]) if precision[i] + recall[i] > 0 else 0

# %%
avg_precision = sum(precision)/len(precision)
avg_recall = sum(recall)/len(recall)
avg_f_score = sum(f_score)/len(f_score)

# %%
avg_precision,avg_recall,avg_f_score
# Out:
# (2.8548685934274403, 9.323086773981915, 4.354578189439615)

# %%
# 'क्'+  'ू'
# Out:
# 'क्ू'

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/q5_bpe1k.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('avg_precision : avg_recall : avg_f_score\n')
    f3.write('%s : %s : %s\n' % (avg_precision, avg_recall, avg_f_score))
    f3.write('precision_per_sentence : recall_per_sentence : f_score_per_sentence\n')
    for i in range(len(q3_txt)):
        f3.write('%s : %s : %s\n' % (precision[i], recall[i], f_score[i]))

# %% [markdown]
#  **On Corpus**

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/pped_txt.txt','r',encoding='utf-8',errors='ignore')
ip = z.read()
z.close()

encoded = sp.encode(ip, out_type=str)

# %%
encoded[:100]
# Out:
# ['▁स्व',
#  'प्',
#  'न',
#  '▁दाख',
#  'वि',
#  'णे',
#  '▁आणि',
#  '▁आ',
#  'श्',
#  'वास',
#  'ने',
#  '▁दे',
#  'णार',
#  'े',
#  '▁नेत',
#  'े',
#  'ही',
#  '▁लोक',
#  'ांना',
#  '▁खूप',
#  '▁आ',
#  'वड',
#  'तात',
#  '▁मुला',
#  'ं',
#  'स',
#  'ोब',
#  'त',
#  'च',
#  '▁पा',
#  'लक',
#  'ांना',
#  '▁स',
#  'ां',
#  'भा',
#  'ळ',
#  'ण्याची',
#  '▁ज',
#  'बाब',
#  'द',
#  'ारी',
#  '▁ही',
#  '▁वि',
#  'व',
#  'ाही',
#  'त',
#  '▁महिला',
#  'ंची',
#  'ही',
#  '▁आहे',
#  '▁के',
#  'वळ',
#  '▁वि',
#  'व',
#  'ाह',
#  '▁झाला',
#  'य',
#  '▁म्हणून',
#  '▁व',
#  'ृ',
#  'द्ध',
#  '▁पा',
#  'लक',
#  'ांची',
#  '▁ज',
#  'बाब',
#  'द',
#  'ारी',
#  '▁त्यांना',
#  '▁झ',
#  'टक',
#  'ता',
#  '▁येणार',
#  '▁नाही',
#  '▁असं',
#  '▁ह',
#  'ायक',
#  'ो',
#  'र्ट',
#  'ान',
#  'ं',
#  '▁म्हट',
#  'लं',
#  'य',
#  '▁प',
#  'हा',
#  '▁काय',
#  '▁ब',
#  'र',
#  'ळ',
#  'ला',
#  '▁पा',
#  'कड',
#  '्यां',
#  'चा',
#  '▁प',
#  'ंत',
#  'प्र',
#  'धान',
#  '▁इ']

# %%
token_unigram_frequencies = Counter(encoded)

bi_grams = [(encoded[i], encoded[i + 1]) for i in range(len(encoded) - 1)]

bi_gram_frequencies = Counter(bi_grams)

# %%
corrected_tokenized_corpus = []

# %%
for i in range(len(encoded)):
  corrected_tokenized_corpus.append([])

# %%
# for encoded[j] in encoded[j]:
j=0
while j < len(encoded):
  for i in range(len(encoded[j])-1):
      # print(i)
      if (ord(encoded[j][i])>=2309 and ord(encoded[j][i])<=2324):
          if (encoded[j][i]!='अ' or encoded[j][i+1]!='ं'):
              corrected_tokenized_corpus[j].append(encoded[j][i])
          else:
              corrected_tokenized_corpus[j].append('अं')
      elif (ord(encoded[j][i])>=2325 and ord(encoded[j][i])<=2361):
          corrected_tokenized_corpus[j].append(encoded[j][i])
          if ((ord(encoded[j][i+1])<2366 or ord(encoded[j][i+1])>=2382) and encoded[j][i+1] !='ं'):
              corrected_tokenized_corpus[j].append('अ')
      elif ((ord(encoded[j][i])>=2366 and ord(encoded[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(encoded[j][i])-56))
      elif ((ord(encoded[j][i])>=2305 and ord(encoded[j][i])<2309) and encoded[j][i-1] != 'अ'):
          corrected_tokenized_corpus[j].append('अ'+encoded[j][i])
      # elif encoded[j][i] == '#':
      #     corrected_tokenized_corpus[j].append('#')
  i = len(encoded[j])-1
  if (ord(encoded[j][i])>=2309 and ord(encoded[j][i])<=2324):
          corrected_tokenized_corpus[j].append(encoded[j][i])
  elif (ord(encoded[j][i])>=2325 and ord(encoded[j][i])<=2361):
      corrected_tokenized_corpus[j].append(encoded[j][i])
      corrected_tokenized_corpus[j].append('अ')
  elif ((ord(encoded[j][i])>=2366 and ord(encoded[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(encoded[j][i])-56))
  elif ((ord(encoded[j][i])>=2305 and ord(encoded[j][i])<2309)):
          corrected_tokenized_corpus[j].append('अ'+encoded[j][i])
  # elif encoded[j][i] == '#':
  #         corrected_tokenized_corpus[j].append('#')

  if j%10000==0:
    print(j)
  j+=1

# %%
corrected_tokenized_corpus = [sublist for sublist in corrected_tokenized_corpus if sublist]

# %%
for i in range(len(corrected_tokenized_corpus)):
  corrected_tokenized_corpus[i] = ''.join(corrected_tokenized_corpus[i])
  # if i%10000==0:
  #   print(i)

# %%
corrected_uni_freq = Counter(corrected_tokenized_corpus)

bi_grams = [(corrected_tokenized_corpus[i], corrected_tokenized_corpus[i + 1]) for i in range(len(corrected_tokenized_corpus) - 1)]
corrected_bi_freq = Counter(bi_grams)

# %%
fin_dict = {k: v for k, v in sorted(corrected_uni_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi = {k: v for k, v in sorted(corrected_bi_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe1k_uni_tokens.txt', 'w',encoding = 'utf-8') as f3:
    for key, value in fin_dict.items():
        f3.write('%s : %s\n' % (key, value))
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe1k_bi_tokens.txt', 'w',encoding = 'utf-8') as f4:
    for key, value in fin_dict_bi.items():
        f4.write('%s : %s\n' % (key, value))

# %%
all_tokens = list(fin_dict.keys())

# %%
L_char_bi = []
L_syl_bi = []

# %%
syl_bi_global = {}
syl_bi_local = {}
char_bi_global = {}
char_bi_local = {}

# %%
i=0
# while (i<len(all_tokens)-1):
for tok in all_tokens:
  i=len(tok)-1
  while (i>0):
    if tok[i] != 'ं' and tok[i] != 'ँ' and tok[i] != 'ः' and tok[i-1] != 'ं' and tok[i-1] != 'ँ' and tok[i-1] != 'ः':
        if tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-1]+tok[i]] += fin_dict[tok]
    elif i>1 and tok[i-1] == 'ं' or tok[i-1] == 'ँ' or tok[i-1] == 'ः' or  tok[i] == 'ं' or tok[i] == 'ँ' or tok[i] == 'ः':
        if tok[i-2]+tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] += fin_dict[tok]
        # i-=1
    if (i<len(tok)-1) and (tok[i+1] == 'ं' or tok[i+1] == 'ँ' or tok[i+1] == 'ः'):
      i-=1
    i-=1

# %%
all_syllables = []
for i in range(len(all_tokens)):
    all_syllables.append([])

# %%
dict_count_uni = {}
dict_count_bi = {}
syl_count_uni = {}
syl_count_bi = {}

# %%
k=0
for words in all_tokens:
    j=0
    # for i in range(len(words)):
    i=0
    while (i<len(words)):
        if ord(words[i]) >=2305 and ord(words[i])<2325:
            if i<len(words)-1 and words[i+1] != 'ः' and words[i+1] != 'ं' and words[i+1] != 'ँ':
                if words[j:i+1] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+1]] = 1
                else:
                    syl_count_uni[words[j:i+1]] += 1
                all_syllables[k].append(words[j:i+1])
                j=i+1
            else:
                if words[j:i+2] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+2]] = 1
                else:
                    syl_count_uni[words[j:i+2]] += 1
                all_syllables[k].append(words[j:i+2])
                j=i+2
                i+=1
        i+=1
    if k%1000 == 0:
        print(k)
    k+=1
# Out:
# 0

# %%
# fin_dict(all_tokens[0])

# %%
k=0
for syls in all_syllables:
    j=0
    for i in range(len(syls)-1):
        if syls[i]+syls[i+1] not in list(syl_bi_local.keys()):
            syl_bi_local[syls[i]+syls[i+1]] = 1
            syl_bi_global[syls[i]+syls[i+1]] = fin_dict[all_tokens[k]]
        else:
            syl_bi_local[syls[i]+syls[i+1]] += 1
            syl_bi_global[syls[i]+syls[i+1]] += fin_dict[all_tokens[k]]
    k+=1
    if k%10000==0:
        print(k)

# %%
fin_dict_char_l = {k: v for k, v in sorted(char_bi_local.items(), key=lambda item: item[1],reverse=True)}
fin_dict_syl_l = {k: v for k, v in sorted(syl_bi_local.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe1k_bi_chars.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('Char : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_char_l.items():
        f3.write('%s : %s : %s\n' % (key, value, char_bi_global[key]))
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe1k_bi_syls.txt', 'w',encoding = 'utf-8') as f4:
    f4.write('Syl : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_syl_l.items():
        f4.write('%s : %s : %s\n' % (key, value, syl_bi_global[key]))

# %%
spm.SentencePieceTrainer.Train('--input='+filepath+' --model_prefix=marathi_bpe_2 --model_type=bpe --vocab_size=2000')

# %%
sp = spm.SentencePieceProcessor()
sp.load("marathi_bpe_2.model")
# Out:
# True

# %%
tokens = [sp.id_to_piece(i) for i in range(sp.get_piece_size())]

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/pped_txt.txt','r',encoding='utf-8',errors='ignore')
ip = z.read()
z.close()

encoded = sp.encode(ip, out_type=str)

# %%
encoded[:100]
# Out:
# ['▁स्व',
#  'प्',
#  'न',
#  '▁दाख',
#  'वि',
#  'णे',
#  '▁आणि',
#  '▁आ',
#  'श्',
#  'वास',
#  'ने',
#  '▁दे',
#  'णारे',
#  '▁नेते',
#  'ही',
#  '▁लोकांना',
#  '▁खूप',
#  '▁आवड',
#  'तात',
#  '▁मुला',
#  'ं',
#  'सोबत',
#  'च',
#  '▁पालक',
#  'ांना',
#  '▁स',
#  'ां',
#  'भा',
#  'ळ',
#  'ण्याची',
#  '▁जबाब',
#  'दारी',
#  '▁ही',
#  '▁वि',
#  'व',
#  'ाही',
#  'त',
#  '▁महिला',
#  'ंची',
#  'ही',
#  '▁आहे',
#  '▁केवळ',
#  '▁वि',
#  'वाह',
#  '▁झाला',
#  'य',
#  '▁म्हणून',
#  '▁व',
#  'ृ',
#  'द्ध',
#  '▁पालक',
#  'ांची',
#  '▁जबाब',
#  'दारी',
#  '▁त्यांना',
#  '▁झ',
#  'टक',
#  'ता',
#  '▁येणार',
#  '▁नाही',
#  '▁असं',
#  '▁ह',
#  'ायक',
#  'ो',
#  'र्ट',
#  'ान',
#  'ं',
#  '▁म्हट',
#  'लं',
#  'य',
#  '▁प',
#  'हा',
#  '▁काय',
#  '▁ब',
#  'र',
#  'ळ',
#  'ला',
#  '▁पा',
#  'कड',
#  '्यांचा',
#  '▁पंतप्रधान',
#  '▁इ',
#  'म',
#  'र',
#  'ान',
#  '▁खान',
#  '▁पी',
#  'सी',
#  'बी',
#  '▁म',
#  'ाव',
#  'ळ',
#  'मध्ये',
#  '▁प',
#  'व',
#  'ना',
#  '▁जल',
#  'वाह',
#  'ि',
#  'नी']

# %%
token_unigram_frequencies = Counter(encoded)

bi_grams = [(encoded[i], encoded[i + 1]) for i in range(len(encoded) - 1)]

bi_gram_frequencies = Counter(bi_grams)

# %%
corrected_tokenized_corpus = []

# %%
for i in range(len(encoded)):
  corrected_tokenized_corpus.append([])

# %%
# for encoded[j] in encoded[j]:
j=0
while j < len(encoded):
  for i in range(len(encoded[j])-1):
      # print(i)
      if (ord(encoded[j][i])>=2309 and ord(encoded[j][i])<=2324):
          if (encoded[j][i]!='अ' or encoded[j][i+1]!='ं'):
              corrected_tokenized_corpus[j].append(encoded[j][i])
          else:
              corrected_tokenized_corpus[j].append('अं')
      elif (ord(encoded[j][i])>=2325 and ord(encoded[j][i])<=2361):
          corrected_tokenized_corpus[j].append(encoded[j][i])
          if ((ord(encoded[j][i+1])<2366 or ord(encoded[j][i+1])>=2382) and encoded[j][i+1] !='ं'):
              corrected_tokenized_corpus[j].append('अ')
      elif ((ord(encoded[j][i])>=2366 and ord(encoded[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(encoded[j][i])-56))
      elif ((ord(encoded[j][i])>=2305 and ord(encoded[j][i])<2309) and encoded[j][i-1] != 'अ'):
          corrected_tokenized_corpus[j].append('अ'+encoded[j][i])
      # elif encoded[j][i] == '#':
      #     corrected_tokenized_corpus[j].append('#')
  i = len(encoded[j])-1
  if (ord(encoded[j][i])>=2309 and ord(encoded[j][i])<=2324):
          corrected_tokenized_corpus[j].append(encoded[j][i])
  elif (ord(encoded[j][i])>=2325 and ord(encoded[j][i])<=2361):
      corrected_tokenized_corpus[j].append(encoded[j][i])
      corrected_tokenized_corpus[j].append('अ')
  elif ((ord(encoded[j][i])>=2366 and ord(encoded[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(encoded[j][i])-56))
  elif ((ord(encoded[j][i])>=2305 and ord(encoded[j][i])<2309)):
          corrected_tokenized_corpus[j].append('अ'+encoded[j][i])
  # elif encoded[j][i] == '#':
  #         corrected_tokenized_corpus[j].append('#')

  if j%10000==0:
    print(j)
  j+=1

# %%
corrected_tokenized_corpus = [sublist for sublist in corrected_tokenized_corpus if sublist]

# %%
for i in range(len(corrected_tokenized_corpus)):
  corrected_tokenized_corpus[i] = ''.join(corrected_tokenized_corpus[i])
  if i%10000==0:
    print(i)

# %%
corrected_uni_freq = Counter(corrected_tokenized_corpus)

bi_grams = [(corrected_tokenized_corpus[i], corrected_tokenized_corpus[i + 1]) for i in range(len(corrected_tokenized_corpus) - 1)]
corrected_bi_freq = Counter(bi_grams)

# %%
fin_dict = {k: v for k, v in sorted(corrected_uni_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi = {k: v for k, v in sorted(corrected_bi_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe2k_uni_tokens.txt', 'w',encoding = 'utf-8') as f3:
    for key, value in fin_dict.items():
        f3.write('%s : %s\n' % (key, value))
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe2k_bi_tokens.txt', 'w',encoding = 'utf-8') as f4:
    for key, value in fin_dict_bi.items():
        f4.write('%s : %s\n' % (key, value))

# %%
all_tokens = list(fin_dict.keys())

# %%
L_char_bi = []
L_syl_bi = []

# %%
syl_bi_global = {}
syl_bi_local = {}
char_bi_global = {}
char_bi_local = {}

# %%
i=0
# while (i<len(all_tokens)-1):
for tok in all_tokens:
  i=len(tok)-1
  while (i>0):
    if tok[i] != 'ं' and tok[i] != 'ँ' and tok[i] != 'ः' and tok[i-1] != 'ं' and tok[i-1] != 'ँ' and tok[i-1] != 'ः':
        if tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-1]+tok[i]] += fin_dict[tok]
    elif i>1 and tok[i-1] == 'ं' or tok[i-1] == 'ँ' or tok[i-1] == 'ः' or  tok[i] == 'ं' or tok[i] == 'ँ' or tok[i] == 'ः':
        if tok[i-2]+tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] += fin_dict[tok]
        # i-=1
    if (i<len(tok)-1) and (tok[i+1] == 'ं' or tok[i+1] == 'ँ' or tok[i+1] == 'ः'):
      i-=1
    i-=1

# %%
all_syllables = []
for i in range(len(all_tokens)):
    all_syllables.append([])

# %%
dict_count_uni = {}
dict_count_bi = {}
syl_count_uni = {}
syl_count_bi = {}

# %%
k=0
for words in all_tokens:
    j=0
    # for i in range(len(words)):
    i=0
    while (i<len(words)):
        if ord(words[i]) >=2305 and ord(words[i])<2325:
            if i<len(words)-1 and words[i+1] != 'ः' and words[i+1] != 'ं' and words[i+1] != 'ँ':
                if words[j:i+1] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+1]] = 1
                else:
                    syl_count_uni[words[j:i+1]] += 1
                all_syllables[k].append(words[j:i+1])
                j=i+1
            else:
                if words[j:i+2] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+2]] = 1
                else:
                    syl_count_uni[words[j:i+2]] += 1
                all_syllables[k].append(words[j:i+2])
                j=i+2
                i+=1
        i+=1
    if k%1000 == 0:
        print(k)
    k+=1
# Out:
# 0
# 1000

# %%
# fin_dict(all_tokens[0])

# %%
k=0
for syls in all_syllables:
    j=0
    for i in range(len(syls)-1):
        if syls[i]+syls[i+1] not in list(syl_bi_local.keys()):
            syl_bi_local[syls[i]+syls[i+1]] = 1
            syl_bi_global[syls[i]+syls[i+1]] = fin_dict[all_tokens[k]]
        else:
            syl_bi_local[syls[i]+syls[i+1]] += 1
            syl_bi_global[syls[i]+syls[i+1]] += fin_dict[all_tokens[k]]
    k+=1
    if k%10000==0:
        print(k)

# %%
fin_dict_char_l = {k: v for k, v in sorted(char_bi_local.items(), key=lambda item: item[1],reverse=True)}
fin_dict_syl_l = {k: v for k, v in sorted(syl_bi_local.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe2k_bi_chars.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('Char : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_char_l.items():
        f3.write('%s : %s : %s\n' % (key, value, char_bi_global[key]))
with open('/content/gdrive/MyDrive/cs689/a1/bpe/fin_bpe2k_bi_syls.txt', 'w',encoding = 'utf-8') as f4:
    f4.write('Syl : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_syl_l.items():
        f4.write('%s : %s : %s\n' % (key, value, syl_bi_global[key]))

# %%
fin_dict
# Out:
# {'तअ': 142057,
#  'नअ': 137998,
#  'आहए': 137150,
#  'यआ': 135792,
#  'कअ': 133827,
#  'रअ': 131527,
#  'वअ': 121971,
#  'सअ': 118291,
#  'चअ': 116558,
#  'लआ': 113912,
#  'मअ': 98956,
#  'आ': 97789,
#  'लअ': 94470,
#  'पअ': 94199,
#  'चयआ': 84538,
#  'आणइ': 81340,
#  'यअ': 80618,
#  'जअ': 79008,
#  'टअ': 77481,
#  'दअ': 76886,
#  'ए': 76461,
#  'बअ': 75162,
#  'ई': 72172,
#  'इ': 69258,
#  'डअ': 67857,
#  'उ': 67147,
#  'हअ': 66079,
#  'आतअ': 65149,
#  'गअ': 64912,
#  'चए': 60443,
#  'हई': 59950,
#  'चआ': 59896,
#  'ऊ': 58798,
#  'नए': 58601,
#  'तए': 57922,
#  'अ': 57420,
#  'शअ': 56935,
#  'लए': 55855,
#  'अं': 53925,
#  'ओ': 52573,
#  'ऊनअ': 52412,
#  'लई': 51343,
#  'वइ': 50333,
#  'चई': 49683,
#  'फअ': 49470,
#  'एकअ': 47538,
#  'ळअ': 45521,
#  'परअ': 44720,
#  'वअरअ': 44695,
#  'तई': 44675,
#  'नआ': 44145,
#  'खअ': 44073,
#  'णअ': 43588,
#  'तआ': 42120,
#  'रई': 41605,
#  'वआ': 41118,
#  'कअरअ': 40845,
#  'कआ': 40044,
#  'इकअ': 39952,
#  'हए': 37779,
#  'इतअ': 37471,
#  'मअधयए': 37326,
#  'नइ': 37006,
#  'धअ': 36332,
#  'नआहई': 36214,
#  'सआ': 35555,
#  'भअ': 34025,
#  'आअं': 32565,
#  'आरअ': 32337,
#  'आहएतअ': 32256,
#  'तअरअ': 32049,
#  'यआअंनई': 30788,
#  'आवअ': 30769,
#  'रए': 30564,
#  'सअं': 29497,
#  'रआ': 29156,
#  'तयआ': 28929,
#  'तओ': 28795,
#  'हआ': 28656,
#  'आयअ': 28632,
#  'थअ': 28105,
#  'कई': 27496,
#  'स': 27174,
#  'मई': 26427,
#  'ऑ': 25970,
#  'पआ': 25439,
#  'आजअ': 25298,
#  'असअ': 24870,
#  'दए': 24577,
#  'लयआ': 24005,
#  'आनअ': 23919,
#  'कआरअ': 23581,
#  'मआ': 23482,
#  'घअ': 23444,
#  'टई': 22644,
#  'र': 22599,
#  'वए': 22424,
#  'अंडअ': 22403,
#  'हओतए': 22386,
#  'णए': 21659,
#  'आनए': 21520,
#  'यआतअ': 21404,
#  'सउ': 21298,
#  'अंगअ': 21170,
#  'आवअरअ': 20723,
#  'शइ': 20545,
#  'ठअ': 20396,
#  'मउ': 19990,
#  'आतईलअ': 19640,
#  'कआहई': 19625,
#  'एतअ': 19557,
#  'सए': 19430,
#  'कएलए': 19211,
#  'आमअ': 19188,
#  'सआठई': 19178,
#  'ऐ': 19173,
#  'कओ': 19076,
#  'सअरवअ': 18999,
#  'पअणअ': 18982,
#  'कएलई': 18933,
#  'णई': 18917,
#  'सटअ': 18767,
#  'डई': 18570,
#  'आसअ': 18530,
#  'कषअ': 18444,
#  'यआअंचयआ': 18305,
#  'तईलअ': 18231,
#  'कए': 17822,
#  'असए': 17777,
#  'मआनअ': 17749,
#  'शई': 17524,
#  'आपअ': 17500,
#  'झअ': 17392,
#  'णआ': 17200,
#  'ऍ': 16853,
#  'वई': 16617,
#  'दआ': 16591,
#  'ळई': 16588,
#  'आअंनआ': 16232,
#  'आणअ': 16137,
#  'णआरअ': 16093,
#  'मए': 16018,
#  'लअं': 15972,
#  'डए': 15928,
#  'कअरअणयआतअ': 15893,
#  'नई': 15872,
#  'आअंनई': 15825,
#  'आलआ': 15572,
#  'दएशअ': 15568,
#  'सई': 15542,
#  'ळआ': 15312,
#  'पउ': 15267,
#  'चअं': 15072,
#  'पअरअ': 15049,
#  'कआमअ': 14734,
#  'दई': 14659,
#  'यआअं': 14464,
#  'ईलअ': 14348,
#  'सअहअ': 14244,
#  'अंदअ': 14194,
#  'कएलआ': 14191,
#  'दइ': 14098,
#  'आअंचयआ': 14048,
#  'आलए': 13950,
#  'षअ': 13757,
#  'अंतअ': 13741,
#  'दउ': 13714,
#  'वहअ': 13707,
#  'कअडए': 13559,
#  'जई': 13404,
#  'यए': 13248,
#  'जए': 13185,
#  'हओ': 13184,
#  'मओ': 13148,
#  'तइ': 13131,
#  'हओतई': 13113,
#  'आगअ': 13037,
#  'मइ': 13003,
#  'रआजअ': 12836,
#  'झआलए': 12821,
#  'णयआसआठई': 12818,
#  'तयआमउळए': 12805,
#  'हओतआ': 12777,
#  'महअणऊनअ': 12615,
#  'ळए': 12566,
#  'यआअंनआ': 12563,
#  'कउ': 12499,
#  'सतअ': 12462,
#  'इयआ': 12382,
#  'अनएकअ': 12375,
#  'मइळअ': 12238,
#  'सइ': 12226,
#  'लओकअ': 12199,
#  'आतआ': 12032,
#  'दयआ': 11966,
#  'औ': 11888,
#  'मआतरअ': 11851,
#  'तरअ': 11647,
#  'आहई': 11525,
#  'बआ': 11491,
#  'जआ': 11456,
#  'सअरअ': 11350,
#  'रओ': 11348,
#  'कआयअ': 11299,
#  'तआतअ': 11273,
#  'मउअंबअई': 11267,
#  'इअंगअ': 11232,
#  'आपअणअ': 11222,
#  'असऊनअ': 11101,
#  'तयआअंचयआ': 11055,
#  'पआसऊनअ': 11025,
#  'मउळए': 11012,
#  'ऋ': 11008,
#  'सओ': 11008,
#  'ढअ': 10977,
#  'वआढअ': 10940,
#  'आवआ': 10938,
#  'वआरई': 10921,
#  'धई': 10905,
#  'गउ': 10883,
#  'आअंचई': 10836,
#  'आपअलयआ': 10835,
#  'शआ': 10788,
#  'लआगअ': 10709,
#  'एटअ': 10657,
#  'उपअ': 10625,
#  'टए': 10570,
#  'क': 10514,
#  'मअहअ': 10450,
#  'कअरऊनअ': 10437,
#  'आचयआ': 10368,
#  'हइ': 10338,
#  'एकआ': 10329,
#  'आलअ': 10307,
#  'चआरअ': 10238,
#  'यउ': 10218,
#  'कइ': 10192,
#  'आअंतअ': 10183,
#  'ल': 10167,
#  'पए': 10122,
#  'दअरअ': 10096,
#  'नअंतअरअ': 10088,
#  'तयआअंनई': 10086,
#  'सउरऊ': 10060,
#  'वअरषअ': 10011,
#  'शए': 10009,
#  'कइअंवआ': 10008,
#  'भअरअ': 9999,
#  'मअनअ': 9959,
#  'पई': 9951,
#  'णयआ': 9935,
#  'आलई': 9912,
#  'सअमअ': 9839,
#  'लएलयआ': 9616,
#  'झआलई': 9614,
#  'दआरअ': 9602,
#  'आरई': 9568,
#  'गआवअ': 9565,
#  'वयआ': 9513,
#  'दओनअ': 9489,
#  'सथअ': 9449,
#  'आबअ': 9419,
#  'एशअ': 9375,
#  'जअनअ': 9370,
#  'णयआतअ': 9369,
#  'अशई': 9310,
#  'सअरअकआरअ': 9266,
#  'झआलआ': 9249,
#  'आर': 9221,
#  'णयआचई': 9180,
#  'ओरअ': 9176,
#  'करअ': 9150,
#  'मआरअ': 9148,
#  'गओ': 9110,
#  'यएतअ': 9053,
#  'न': 9007,
#  'रउ': 8983,
#  'मआहइतई': 8944,
#  'गरअ': 8943,
#  'इनअ': 8900,
#  'आवए': 8837,
#  'आहअ': 8824,
#  'इकआ': 8812,
#  'भआगअ': 8786,
#  'अंबअ': 8746,
#  'पअडअ': 8742,
#  'वआरअ': 8716,
#  'त': 8697,
#  'तअसएचअ': 8534,
#  'अशआ': 8512,
#  'जआतअ': 8453,
#  'असआ': 8388,
#  'पओ': 8356,
#  'तयआअंनआ': 8344,
#  'वआपअरअ': 8333,
#  'घए': 8256,
#  'रआतअ': 8250,
#  'आअंचआ': 8244,
#  'छअ': 8196,
#  'पऊ': 8190,
#  'वआटअ': 8183,
#  'भआजअपअ': 8181,
#  'बई': 8056,
#  'रआहअ': 7907,
#  'दधअ': 7881,
#  'दइवअसअ': 7855,
#  'भआ': 7846,
#  'तअरई': 7836,
#  'सआरअ': 7831,
#  'कअरअणयआसआठई': 7790,
#  'कअरअतअ': 7778,
#  'डआ': 7765,
#  'वइचआरअ': 7716,
#  'ठएवअ': 7646,
#  'महअणअजए': 7601,
#  'पआहअ': 7543,
#  'नअसअ': 7540,
#  'इयअ': 7536,
#  'इमअ': 7536,
#  'मअतअ': 7509,
#  'झआलयआ': 7490,
#  'पऊरणअ': 7468,
#  'प': 7384,
#  'हओतअ': 7338,
#  'दइलई': 7337,
#  'कआढअ': 7276,
#  'फए': 7233,
#  'उनअ': 7228,
#  'तयआचयआ': 7219,
#  'लइ': 7207,
#  'आवअशयअकअ': 7191,
#  'वआदअ': 7158,
#  'हअजआरअ': 7153,
#  'यएथए': 7124,
#  'ठअरअ': 7108,
#  'आअंचए': 7095,
#  'गई': 7045,
#  'आनआ': 7035,
#  'कअडऊनअ': 7022,
#  'गआ': 7016,
#  'षटअ': 6995,
#  'ओडअ': 6980,
#  'अंचअ': 6969,
#  'आई': 6949,
#  'हओणआरअ': 6939,
#  'डइ': 6926,
#  'तउ': 6916,
#  'इवअ': 6910,
#  'कतअ': 6902,
#  'सआअंगअ': 6886,
#  'बअसअ': 6882,
#  'सवअतअ': 6870,
#  'ओलअ': 6854,
#  'यआवअरअ': 6849,
#  'यआअंचई': 6838,
#  'थए': 6796,
#  'कअमई': 6756,
#  'पअरयअंतअ': 6737,
#  'परअकआरअ': 6723,
#  'उकअ': 6683,
#  'वइषअ': 6657,
#  'ओकअ': 6644,
#  'भआवअ': 6600,
#  'लएलए': 6570,
#  'अंनआ': 6554,
#  'ऱयआ': 6492,
#  'ओटअ': 6460,
#  'वऊनअ': 6456,
#  'कआअँगरएसअ': 6430,
#  'णयआचआ': 6400,
#  'इसअ': 6320,
#  'कषआ': 6316,
#  'अंतरअ': 6307,
#  'लआवअ': 6295,
#  'आयअलआ': 6258,
#  'लओ': 6257,
#  'वअर': 6247,
#  'वइकअ': 6245,
#  'इलअ': 6233,
#  'आचए': 6232,
#  'सवअ': 6205,
#  'आचई': 6197,
#  'घएतअ': 6182,
#  'अंटअ': 6161,
#  'अधइकअ': 6140,
#  'परअतइ': 6123,
#  'कअरअणआरअ': 6109,
#  'अवअ': 6102,
#  'वएळई': 6084,
#  'टअकअ': 6065,
#  'कएलयआ': 6044,
#  'पअणए': 6041,
#  'रमअ': 6014,
#  'णआऱयआ': 5979,
#  'मअहआरआषटरअ': 5945,
#  'दअरशअ': 5922,
#  'अंधअ': 5912,
#  'घअडअ': 5889,
#  'सआयअ': 5888,
#  'पआणई': 5878,
#  'सथआनअ': 5878,
#  'वयअ': 5858,
#  'कऑ': 5841,
#  'आवई': 5836,
#  'चइतरअपअटअ': 5825,
#  'भआरअ': 5817,
#  'रआजयअ': 5809,
#  'महअणअ': 5805,
#  'कआरअणअ': 5796,
#  'द': 5791,
#  'ऊरअ': 5766,
#  'पऊरअ': 5757,
#  'बओलअ': 5740,
#  'पअकषअ': 5724,
#  'खए': 5698,
#  'पउरअ': 5696,
#  'दआनअ': 5693,
#  'असअलएलयआ': 5684,
#  'टअरअ': 5652,
#  'असएलअ': 5642,
#  'सअंघअ': 5625,
#  'बअंदअ': 5622,
#  'एलअ': 5613,
#  'आचआ': 5612,
#  'चआलअ': 5605,
#  'रइ': 5604,
#  'दइसअ': 5600,
#  'एसअ': 5598,
#  'नअगअरअ': 5596,
#  'श': 5594,
#  'वइभआगअ': 5575,
#  'वयअवअ': 5572,
#  'हआतअ': 5560,
#  'यएथईलअ': 5558,
#  'ऱअ': 5553,
#  'कअरअणए': 5551,
#  'कअरऊ': 5550,
#  'अंजअ': 5548,
#  'दइलए': 5536,
#  'वअडअ': 5525,
#  'तअयआरअ': 5524,
#  'लयआनए': 5521,
#  'असअं': 5520,
#  'वऐ': 5510,
#  'परअयअतनअ': 5488,
#  'मअलआ': 5474,
#  'वएगअ': 5457,
#  'असअलयआचए': 5434,
#  'इतअरअ': 5431,
#  'असअलयआ': 5426,
#  'ठआ': 5417,
#  'मउलआ': 5409,
#  'पअदअ': 5409,
#  'नअं': 5405,
#  'खआ': 5403,
#  'फअकतअ': 5378,
#  'अंचआ': 5340,
#  'अंबअरअ': 5334,
#  'आतऊनअ': 5330,
#  'गए': 5325,
#  'लअकषअ': 5319,
#  'कआळअ': 5317,
#  'यएणआरअ': 5310,
#  'अभअ': 5304,
#  'अनउ': 5271,
#  'कआरयअ': 5270,
#  'नअवअ': 5265,
#  'अंचयआ': 5258,
#  'लआखअ': 5257,
#  'सआअंगइतअलए': 5251,
#  'बरअ': 5249,
#  'लएलआ': 5249,
#  'तयआतअ': 5243,
#  'जअगअ': 5242,
#  'अंनई': 5237,
#  'आमहई': 5234,
#  'मऊ': 5219,
#  'ओगअ': 5211,
#  'तयआलआ': 5188,
#  'दउसअ': 5185,
#  'बआबअ': 5185,
#  'वएळअ': 5178,
#  'पओलइसअ': 5176,
#  'बए': 5160,
#  'कषअणअ': 5156,
#  'आअंमअधयए': 5155,
#  'दएतअ': 5150,
#  'उलअ': 5122,
#  'दइलआ': 5111,
#  'इरअ': 5094,
#  'ष': 5087,
#  'मआलअ': 5083,
#  'मअंतरई': 5077,
#  'षठअ': 5076,
#  'यआअंचआ': 5075,
#  'इकए': 5074,
#  'रवअ': 5068,
#  'मअधईलअ': 5063,
#  'अः': 5059,
#  'आळअ': 5049,
#  'ऊलअ': 5028,
#  'तईनअ': 5016,
#  'सउरअ': 5003,
#  'आअंवअरअ': 4983,
#  'मअहइलआ': 4981,
#  'गएलयआ': 4980,
#  'जअवअळअ': 4977,
#  'वआजअ': 4976,
#  'मआरगअ': 4962,
#  'गअरअ': 4956,
#  'नआवअ': 4943,
#  'परअशनअ': 4918,
#  'ठई': 4915,
#  'वइवइधअ': 4897,
#  'आकअ': 4892,
#  'उत': 4883,
#  'यआअंचए': 4866,
#  'आरआ': 4866,
#  'नआतअ': 4841,
#  'ळयआ': 4831,
#  'पइ': 4787,
#  'असअतए': 4786,
#  'पआलअ': 4785,
#  'अरअ': 4778,
#  'शअनअ': 4777,
#  'अंदरअ': 4776,
#  'सअंपअ': 4762,
#  'मउखयअ': 4760,
#  'पअटअ': 4738,
#  'बअनअ': 4729,
#  'करअमअ': 4716,
#  'वइशएषअ': 4711,
#  'कसअ': 4709,
#  'नइरणअयअ': 4694,
#  'कओणअ': 4688,
#  'दअरअमयआनअ': 4682,
#  'सऊ': 4682,
#  'आठअ': 4677,
#  'म': 4667,
#  'इटअ': 4648,
#  'ननअ': 4643,
#  'जअरअ': 4642,
#  'एमअ': 4640,
#  'जआतए': 4632,
#  'धआरअ': 4621,
#  'उरअ': 4621,
#  'यआतईलअ': 4605,
#  'सअमओरअ': 4602,
#  'इतई': 4587,
#  'मओदई': 4583,
#  'ऋतअ': 4576,
#  'मआगअ': 4576,
#  'तआनआ': 4561,
#  'पओलईसअ': 4552,
#  'दआखअलअ': 4550,
#  'मअंतरअ': 4540,
#  'आणई': 4530,
#  'पउनहआ': 4527,
#  'मअधअ': 4517,
#  'कओटई': 4501,
#  'रतअ': 4484,
#  'दएखईलअ': 4483,
#  'यई': 4479,
#  'रसअ': 4473,
#  'खअरअ': 4454,
#  'खआलई': 4442,
#  'पआटईलअ': 4441,
#  'नइयअ': 4439,
#  'वयअकतअ': 4439,
#  'झआलएलयआ': 4430,
#  'पआठअ': 4426,
#  'लएलई': 4423,
#  'ओजअ': 4418,
#  'परअतयएकअ': 4407,
#  'शइकअ': 4405,
#  'घएऊनअ': 4400,
#  'दयअ': 4399,
#  'झआ': 4396,
#  'लपअ': 4382,
#  'यआचई': 4382,
#  'जआगअ': 4367,
#  'घअरअ': 4366,
#  'पआरअ': 4356,
#  'डअकअ': 4352,
#  'गआरअ': 4349,
#  'तएवहआ': 4326,
#  'ग': 4320,
#  'शअकअतए': 4308,
#  'डऑ': 4306,
#  'वइदयआरथअ': 4295,
#  'जइलहअ': 4288,
#  'सओडअ': 4285,
#  'जइलहआ': 4281,
#  'हओईलअ': 4272,
#  'बअदअलअ': 4269,
#  'कषअकअ': 4267,
#  'नसअ': 4267,
#  'शरअ': 4264,
#  'अपअ': 4263,
#  'असअतआनआ': 4249,
#  'अंचई': 4245,
#  'यआवएळई': 4236,
#  'पऊरवई': 4228,
#  'यओगअ': 4222,
#  'सअधयआ': 4215,
#  'वआहअ': 4214,
#  'शरई': 4210,
#  'सअमआजअ': 4209,
#  'सथआपअ': 4201,
#  'कअडअ': 4196,
#  'तईनए': 4192,
#  'भऊ': 4187,
#  'यआचआ': 4173,
#  'शउ': 4169,
#  'णयआचए': 4169,
#  'मआगअणई': 4154,
#  'मइळआ': 4153,
#  'बइ': 4149,
#  'ऋतई': 4147,
#  'रअंगअ': 4141,
#  'दएणयआतअ': 4139,
#  'ज': 4138,
#  'रटअ': 4137,
#  'पअतरअ': 4118,
#  'सअगअ': 4104,
#  'जआणअ': 4087,
#  'जयआ': 4083,
#  'तयआनअंतअरअ': 4080,
#  'अधयअकषअ': 4076,
#  'खऊपअ': 4066,
#  'भआरअतईयअ': 4066,
#  'शअहअ': 4046,
#  'रअणअ': 4039,
#  'बउ': 4038,
#  'सकअ': 4038,
#  'खयआ': 4033,
#  'अरथअ': 4031,
#  'नओ': 4020,
#  'अंतअरअ': 4019,
#  'नउसआरअ': 4008,
#  'चइ': 4004,
#  'दइललई': 3994,
#  'महअणआलए': 3993,
#  'कऍ': 3975,
#  'नआहईतअ': 3970,
#  'खएळअ': 3970,
#  'वइरओधअ': 3969,
#  'जआसतअ': 3967,
#  'कएअंदरअ': 3958,
#  'अनअ': 3955,
#  'आजई': 3950,
#  'एशअनअ': 3935,
#  'कअधई': 3932,
#  'सआधअ': 3931,
#  'कषएतरअ': 3928,
#  'एवअ': 3923,
#  'अंकअ': 3915,
#  'सअंसथअ': 3913,
#  'जओ': 3911,
#  'कअरआ': 3910,
#  'ईरअ': 3901,
#  'भए': 3888,
#  'आणए': 3888,
#  'आअंबअ': 3882,
#  'सआतअ': 3881,
#  'पआचअ': 3877,
#  'दआखअ': 3870,
#  'नइरमआणअ': 3868,
#  'परआ': 3864,
#  'नइवअडअ': 3852,
#  'पअवआरअ': 3844,
#  'रजअ': 3834,
#  'भअवअ': 3830,
#  'वयअकतई': 3823,
#  'तअं': 3813,
#  'भआरअतअ': 3805,
#  'आलयआ': 3801,
#  'सपअ': 3791,
#  'टआकअ': 3778,
#  'मआझअ': 3766,
#  'आमअदआरअ': 3766,
#  'रआषटरअवआदई': 3720,
#  'अंपअ': 3718,
#  'कतई': 3712,
#  'शअकअतआ': 3702,
#  'ब': 3692,
#  'सअमअजअ': 3689,
#  'नयआयआलअयआ': 3681,
#  'धइकअ': 3672,
#  'कअंपअनई': 3669,
#  'कटअ': 3659,
#  'ओपअ': 3658,
#  'ललआ': 3653,
#  'घएतअलआ': 3647,
#  'ईतअ': 3637,
#  'जञअ': 3636,
#  'घयआ': 3633,
#  'बआहएरअ': 3627,
#  'पअहइलयआ': 3619,
#  'नआगअरइकअ': 3617,
#  'वआसअ': 3616,
#  'भआषअ': 3601,
#  'मउखयअमअंतरई': 3599,
#  'मआझयआ': 3591,
#  'तवअ': 3590,
#  'पअरअंतउ': 3584,
#  'मआणअ': 3569,
#  'मअगअ': 3565,
#  'ऑलअ': 3559,
#  'घअटअ': 3559,
#  'मओठयआ': 3557,
#  'उततअरअ': 3557,
#  'डओ': 3549,
#  'कएवअळअ': 3537,
#  'नएतअ': 3537,
#  'वअतअ': 3537,
#  'असअलयआनए': 3534,
#  'नअवहअ': 3532,
#  'तईतअ': 3529,
#  'हआरअ': 3528,
#  'ठइकआणई': 3513,
#  'मइतअ': 3510,
#  'टरअ': 3504,
#  'लअढअ': 3495,
#  'सअरवआतअ': 3481,
#  'यआचयआ': 3477,
#  'सपअरधअ': 3476,
#  'णयआसअ': 3468,
#  'मअदअतअ': 3459,
#  'पअरइणआमअ': 3456,
#  'भएटअ': 3455,
#  'सआमअ': 3449,
#  'तरई': 3442,
#  'वआयअ': 3441,
#  'वआचअ': 3437,
#  'रईयअ': 3434,
#  'ओबअ': 3427,
#  'आदअ': 3422,
#  'सतरअ': 3414,
#  'यअशअ': 3413,
#  'कअरमअ': 3407,
#  'रषअ': 3396,
#  'मअहइनअ': 3386,
#  'बओ': 3383,
#  'शइवअसएनए': 3373,
#  'शअहअरअ': 3356,
#  'पअतई': 3354,
#  'ऋत': 3347,
#  'चअरचआ': 3346,
#  'रउपअयए': 3342,
#  'पउढए': 3340,
#  'रकअ': 3329,
#  'ककअ': 3322,
#  'सउरउवआतअ': 3312,
#  'वअलए': 3310,
#  'इलआ': 3294,
#  'नअवईनअ': 3282,
#  'ठआकअरए': 3278,
#  'पअरइ': 3274,
#  'कअरअणयआचई': 3269,
#  'ऊकअ': 3267,
#  'शओधअ': 3256,
#  'सअमइतई': 3249,
#  'टआ': 3248,
#  'सपअषटअ': 3244,
#  'रयअ': 3244,
#  'गएलए': 3240,
#  'यओगयअ': 3240,
#  'धआनअ': 3240,
#  'घअटअनआ': 3233,
#  'यआनए': 3226,
#  'घएतअलई': 3216,
#  'दरअ': 3214,
#  'टअककए': 3205,
#  'ओनअ': 3204,
#  'सअंकअ': 3202,
#  'सउरउ': 3201,
#  'रआमअ': 3193,
#  'फउ': 3187,
#  'आमई': 3183,
#  'पआहइजए': 3179,
#  'आनअंदअ': 3167,
#  'आअंगअ': 3167,
#  'णयआचयआ': 3160,
#  'पएकषआ': 3157,
#  'घआलअ': 3157,
#  'उपअसथइतअ': 3155,
#  'वइजअयअ': 3151,
#  'रएलवए': 3150,
#  'कएलएलयआ': 3142,
#  'घआतअ': 3139,
#  'ऋहअ': 3138,
#  'आयअकअ': 3137,
#  'वइकआसअ': 3125,
#  'तयआचआ': 3117,
#  'रओजई': 3117,
#  'वआनअ': 3115,
#  'लअहआनअ': 3109,
#  'हओऊ': 3107,
#  'हओतअं': 3100,
#  'आअंसआठई': 3100,
#  'यऊ': 3099,
#  'मअरआठई': 3093,
#  'कअरअतआ': 3076,
#  'कउठअ': 3072,
#  'फआरअ': 3059,
#  'कअरअणअ': 3059,
#  'बअलअ': 3053,
#  'असअतआतअ': 3039,
#  'यआचअ': 3029,
#  'मअंदअ': 3024,
#  'चऔ': 3018,
#  'मआजई': 3006,
#  'हओतओ': 3004,
#  'दओनहई': 3004,
#  'कउटउअंबअ': 3003,
#  'जअयअ': 2996,
#  'णआरए': 2990,
#  'अऍ': 2989,
#  'ओषअ': 2988,
#  'शचअ': 2987,
#  'कआरअवआई': 2987,
#  'पअहइ': 2986,
#  'सओबअतअ': 2983,
#  'धआवअ': 2980,
#  'ततआ': 2978,
#  'जआणआरअ': 2973,
#  'रडअ': 2969,
#  'तउमहई': 2966,
#  'मअंडअ': 2966,
#  'पओलइसआअंनई': 2957,
#  'मओठअ': 2953,
#  'जअणअ': 2948,
#  'तयआनए': 2944,
#  'लएखअ': 2943,
#  'आअंडअ': 2939,
#  'तयआचअ': 2927,
#  'लअयआ': 2923,
#  'कआरयआ': 2920,
#  'वअलई': 2918,
#  'नओअंदअ': 2915,
#  'कएलअं': 2906,
#  'शआसअ': 2902,
#  'भआरअतआ': 2899,
#  'थआ': 2876,
#  'पआकइसतआनअ': 2876,
#  'मअधऊनअ': 2857,
#  'हऑ': 2854,
#  'जआऊ': 2852,
#  'उपअलअबधअ': 2851,
#  'पउणए': 2850,
#  'बआबअतअ': 2848,
#  'चअनआ': 2847,
#  'बअहउ': 2841,
#  'खई': 2838,
#  'परअदएशअ': 2835,
#  'तइचयआ': 2828,
#  'परए': 2827,
#  'कऋ': 2824,
#  'रअसतअ': 2821,
#  'नअरअ': 2817,
#  'तअमअ': 2814,
#  'कअरअतआनआ': 2809,
#  'परअमआणअ': 2807,
#  'रणअ': 2807,
#  'णअं': 2805,
#  'अशअ': 2804,
#  'आधई': 2803,
#  'तयआचई': 2798,
#  'पअंतअपरअधआनअ': 2797,
#  'परअमआणए': 2797,
#  'णआरआ': 2790,
#  'लअकअ': 2779,
#  'जआहईरअ': 2775,
#  'तयआअंचई': 2774,
#  'आरओपअ': 2772,
#  'परअतयअ': 2771,
#  'कषइतअ': 2771,
#  'खउ': 2770,
#  'जइ': 2768,
#  'परअशआसअ': 2766,
#  'भआजअ': 2766,
#  'अडअ': 2765,
#  'तयआअंचए': 2761,
#  'नएतए': 2759,
#  'चइतअ': 2757,
#  'यआसआठई': 2753,
#  'गअडअ': 2752,
#  'षटई': 2745,
#  'पआतअ': 2744,
#  'कअलआ': 2738,
#  'पअरइसथइतई': 2736,
#  'आअंकअ': 2732,
#  'जआगआ': 2723,
#  'परअवएशअ': 2723,
#  'लअकषआतअ': 2719,
#  'वअरऊनअ': 2713,
#  'कओणअतयआहई': 2711,
#  'शअकयअतआ': 2707,
#  'लयआनअंतअरअ': 2706,
#  'फआयअ': 2704,
#  'अँ': 2703,
#  'सथआ': 2698,
#  'इअंडअ': 2696,
#  'तऊनअ': 2695,
#  'अधइकआरई': 2686,
#  'दओघअ': 2677,
#  'तआलउकअ': 2673,
#  'बआजआरअ': 2671,
#  'रयआ': 2669,
#  'कअरअणयआ': 2664,
#  'तयअ': 2663,
#  'अंभअ': 2663,
#  'खओ': 2661,
#  'मआर': 2660,
#  'वआलअ': 2660,
#  'असअतओ': 2654,
#  'शइकषअणअ': 2653,
#  'ऑफअ': 2652,
#  'कअरअणयआचआ': 2649,
#  'उचचअ': 2646,
#  'सअरअकआरअनए': 2644,
#  'वअनअ': 2643,
#  'रथअ': 2643,
#  'गआअंधई': 2638,
#  'ऊपअ': 2637,
#  'तयआचए': 2635,
#  'खआतअ': 2634,
#  'घआ': 2632,
#  'भऊमइकआ': 2631,
#  'धयआ': 2629,
#  'आयओजअ': 2626,
#  'नइरमअ': 2622,
#  'बअददअलअ': 2622,
#  'कआरयअकरअमअ': 2619,
#  'उपअचआरअ': 2614,
#  'पअरअतअ': 2613,
#  'सइनए': 2613,
#  'टएलअ': 2612,
#  'मउलई': 2611,
#  'नआगअ': 2611,
#  'परअकअरअणअ': 2599,
#  'पअदधअ': 2596,
#  'जएवअ': 2595,
#  'अगअदई': 2595,
#  'कईयअ': 2589,
#  'शअकअ': 2588,
#  'गउणअ': 2582,
#  'ओळअखअ': 2582,
#  'नइवअडअणऊकअ': 2581,
#  'अंदआ': 2575,
#  'लअवअकअरअ': 2575,
#  'कअरजअ': 2574,
#  'रगअ': 2570,
#  'रआजअकईयअ': 2568,
#  'यएईलअ': 2564,
#  'उमएदअवआरअ': 2561,
#  'दऋ': 2557,
#  'रएसअ': 2556,
#  'नअवई': 2553,
#  'बअघअ': 2552,
#  'अंडई': 2543,
#  'सअंपऊरणअ': 2543,
#  'सअमआवएशअ': 2538,
#  'अंदआजअ': 2534,
#  'शएवअ': 2532,
#  'सअंघअटअ': 2529,
#  'यआमउळए': 2528,
#  'मओठआ': 2527,
#  'तअपआसअ': 2526,
#  'कआरयअकअ': 2525,
#  'आमअधयए': 2515,
#  'रभअ': 2515,
#  'नआथअ': 2511,
#  'खअरचअ': 2509,
#  'मउलअ': 2508,
#  'ऱअयआ': 2503,
#  'सवआ': 2502,
#  'मऐ': 2502,
#  'वअलआ': 2496,
#  'पअणआ': 2491,
#  'अरजअ': 2490,
#  'अंचए': 2488,
#  'खअरएदई': 2488,
#  'गओषटई': 2488,
#  'शअलअ': 2487,
#  'कअरअणई': 2486,
#  'लयआचए': 2485,
#  'रआतरई': 2483,
#  'मऋतयऊ': 2483,
#  'ददअ': 2481,
#  'चआअंगअ': 2478,
#  'मअहअततवआ': 2478,
#  'ऍटअ': 2476,
#  'गअरअजअ': 2475,
#  'आरथइकअ': 2473,
#  'इचछअ': 2470,
#  'शअबदअ': 2469,
#  'गइरई': 2465,
#  'दधआ': 2459,
#  ...}

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/q3.txt','r',encoding='utf-8',errors='ignore')
q3_txt = z.read()
z.close()

# %%
q3_txt = re.sub(r"[^\u0900-\u094F\s,\u0966-\u096F1234567890]", "", q3_txt)

# %%
q3_txt = q3_txt.split('\n')

# %%
q3_txt[5]
# Out:
# 'त्यामुळे, पश्चिम रेल्वेवरील, लोकसेवा, १० ते १५ मिनिटं, उशिराने, धावतील'

# %%
for i in range(len(q3_txt)):
  ''.join(q3_txt[i])
  q3_txt[i] = q3_txt[i].split(',')

# %%
# ground_truth

# %%
ground_truth = []
for i in range(len(q3_txt)):
  ground_truth.append(q3_txt[i])

# %%
test_sent = []
for i in range(len(q3_txt)):
  test_sent.append(''.join(q3_txt[i]))

# %%
new_tokens=[]

# %%
for tests in test_sent:
    tokens = sp.encode(tests, out_type=str)
    new_tokens.append(tokens)

# %%
new_tokens[0][1]
# Out:
# 'ग'

# %%
corrected_new_tokens = []

# %%
for i in range(len(new_tokens)):
  corrected_new_tokens.append([])
  for j in range(len(new_tokens[i])):
    corrected_new_tokens[i].append([])

# %%
for k in range(len(new_tokens)):
  for l in range(len(new_tokens[k])):
    for i in range(len(new_tokens[k][l])-1):
        # print(i)
        if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            if (new_tokens[k][l][i]!='अ' or new_tokens[k][l][i+1]!='ं'):
                corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            else:
                corrected_new_tokens[k][l].append('अं')
        elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            if ((ord(new_tokens[k][l][i+1])<2366 or ord(new_tokens[k][l][i+1])>=2382) and new_tokens[k][l][i+1] !='ं'):
                corrected_new_tokens[k][l].append('अ')
        elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
        elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309) and new_tokens[k][l][i-1] != 'अ'):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

    i = len(new_tokens[k][l])-1
    if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
    elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
        corrected_new_tokens[k][l].append(new_tokens[k][l][i])
        corrected_new_tokens[k][l].append('अ')
    elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
    elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309)):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

# %%
for i in range(len(corrected_new_tokens)):
    corrected_new_tokens[i] = [sublist for sublist in corrected_new_tokens[i] if sublist]

# %%
for i in range(len(corrected_new_tokens)):
  for j in range(len(corrected_new_tokens[i])):
    corrected_new_tokens[i][j] = ''.join(corrected_new_tokens[i][j])
  # if i%10000==0:
  #   print(i)

# %%
# corrected_new_tokens[0]

# %%
corrected_ground_truth = []

# %%
for i in range(len(ground_truth)):
  corrected_ground_truth.append([])
  for j in range(len(ground_truth[i])):
    corrected_ground_truth[i].append([])

# %%
for k in range(len(ground_truth)):
  for l in range(len(ground_truth[k])):
    for i in range(len(ground_truth[k][l])-1):
        # print(i)
        if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            if (ground_truth[k][l][i]!='अ' or ground_truth[k][l][i+1]!='ं'):
                corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            else:
                corrected_ground_truth[k][l].append('अं')
        elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            if ((ord(ground_truth[k][l][i+1])<2366 or ord(ground_truth[k][l][i+1])>=2382) and ground_truth[k][l][i+1] !='ं'):
                corrected_ground_truth[k][l].append('अ')
        elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
        elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309) and ground_truth[k][l][i-1] != 'अ'):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

    i = len(ground_truth[k][l])-1
    if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
    elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
        corrected_ground_truth[k][l].append(ground_truth[k][l][i])
        corrected_ground_truth[k][l].append('अ')
    elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
    elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309)):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

# %%
for i in range(len(corrected_ground_truth)):
    corrected_ground_truth[i] = [sublist for sublist in corrected_ground_truth[i] if sublist]

# %%
for i in range(len(corrected_ground_truth)):
  for j in range(len(corrected_ground_truth[i])):
    corrected_ground_truth[i][j] = ''.join(corrected_ground_truth[i][j])
  # if i%10000==0:
  #   print(i)

# %%
intersection = []
for i in range(len(q3_txt)):
  intersection.append(Counter(corrected_new_tokens[i]).keys() & Counter(corrected_ground_truth[i]).keys())

# %%
intersection[1]
# Out:
# {'तयआअंनई'}

# %%
len(set(corrected_new_tokens[0]))
# Out:
# 74

# %%
precision = []
recall = []
f_score = []
for i in range(len(q3_txt)):
  precision.append([])
  recall.append([])
  f_score.append([])

# %%
for i in range(len(q3_txt)):
  precision[i] = 100*len(intersection[i]) / len(set(corrected_new_tokens[i]))

  recall[i] = 100*len(intersection[i]) / len(set(corrected_ground_truth[i]))

  f_score[i] = 2 * precision[i] * recall[i] / (precision[i] + recall[i]) if precision[i] + recall[i] > 0 else 0

# %%
avg_precision = sum(precision)/len(precision)
avg_recall = sum(recall)/len(recall)
avg_f_score = sum(f_score)/len(f_score)

# %%
avg_precision,avg_recall,avg_f_score
# Out:
# (5.059196514632342, 14.326971181702639, 7.443371880716082)

# %%
# 'क्'+  'ू'

# %%
with open('/content/gdrive/MyDrive/cs689/a1/bpe/q5_bpe2k.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('avg_precision : avg_recall : avg_f_score\n')
    f3.write('%s : %s : %s\n' % (avg_precision, avg_recall, avg_f_score))
    f3.write('precision_per_sentence : recall_per_sentence : f_score_per_sentence\n')
    for i in range(len(q3_txt)):
        f3.write('%s : %s : %s\n' % (precision[i], recall[i], f_score[i]))
