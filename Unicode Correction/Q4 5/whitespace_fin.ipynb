# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from collections import Counter

# %%
filepath = "/content/gdrive/MyDrive/cs689/a1/pped_txt.txt"

# %%
z = open(filepath,'r',errors='ignore',encoding = 'utf-8')

# %%
ip = z.read()

# %%
z.close()

# %%
ip_uni = ip.split()

# %%
ip_bi = ip.split('\n')

# %%
while '' in  ip_uni:
  ip_uni.remove('')

# %%
token_unigram_frequencies = Counter(ip_uni)

bi_grams = [(sents.split()[i], sents.split()[i + 1]) for sents in ip_bi for i in range(len(sents.split()) - 1) ]

bi_gram_frequencies = Counter(bi_grams)

# %%
corrected_tokenized_corpus = []

# %%
for i in range(len(ip_uni)):
  corrected_tokenized_corpus.append([])

# %%
j=0
while j < len(ip_uni):
  for i in range(len(ip_uni[j])-1):
      # print(i)
      if (ord(ip_uni[j][i])>=2309 and ord(ip_uni[j][i])<=2324):
          if (ip_uni[j][i]!='अ' or ip_uni[j][i+1]!='ं'):
              corrected_tokenized_corpus[j].append(ip_uni[j][i])
          else:
              corrected_tokenized_corpus[j].append('अं')
      elif (ord(ip_uni[j][i])>=2325 and ord(ip_uni[j][i])<=2361):
          corrected_tokenized_corpus[j].append(ip_uni[j][i])
          if ((ord(ip_uni[j][i+1])<2366 or ord(ip_uni[j][i+1])>=2382) and ip_uni[j][i+1] !='ं'):
              corrected_tokenized_corpus[j].append('अ')
      elif ((ord(ip_uni[j][i])>=2366 and ord(ip_uni[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(ip_uni[j][i])-56))
      elif ((ord(ip_uni[j][i])>=2305 and ord(ip_uni[j][i])<2309) and ip_uni[j][i-1] != 'अ'):
          corrected_tokenized_corpus[j].append('अ'+ip_uni[j][i])
      # elif ip_uni[j][i] == '#':
      #     corrected_tokenized_corpus[j].append('#')
  i = len(ip_uni[j])-1
  if (ord(ip_uni[j][i])>=2309 and ord(ip_uni[j][i])<=2324):
          corrected_tokenized_corpus[j].append(ip_uni[j][i])
  elif (ord(ip_uni[j][i])>=2325 and ord(ip_uni[j][i])<=2361):
      corrected_tokenized_corpus[j].append(ip_uni[j][i])
      corrected_tokenized_corpus[j].append('अ')
  elif ((ord(ip_uni[j][i])>=2366 and ord(ip_uni[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(ip_uni[j][i])-56))
  elif ((ord(ip_uni[j][i])>=2305 and ord(ip_uni[j][i])<2309)):
          corrected_tokenized_corpus[j].append('अ'+ip_uni[j][i])
  # elif ip_uni[j][i] == '#':
  #         corrected_tokenized_corpus[j].append('#')

  if j%10000==0:
    print(j)
  j+=1

# %%
corrected_tokenized_corpus = [sublist for sublist in corrected_tokenized_corpus if sublist]

# %%
for i in range(len(corrected_tokenized_corpus)):
  corrected_tokenized_corpus[i] = ''.join(corrected_tokenized_corpus[i])
  # if i%10000==0:
  #   print(i)

# %%
corrected_uni_freq = Counter(corrected_tokenized_corpus)

bi_grams = [(corrected_tokenized_corpus[i], corrected_tokenized_corpus[i + 1]) for i in range(len(corrected_tokenized_corpus) - 1)]
corrected_bi_freq = Counter(bi_grams)

# %%
fin_dict = {k: v for k, v in sorted(corrected_uni_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi = {k: v for k, v in sorted(corrected_bi_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
# fin_dict['']

# %%
fin_dict_bi
# Out:
# {('आहए', 'यआ'): 5230,
#  ('कएलई', 'आहए'): 4421,
#  ('आवअशयअकअ', 'आहए'): 4189,
#  ('कअरअणयआतअ', 'आलई'): 3936,
#  ('आलई', 'आहए'): 3388,
#  ('कएलआ', 'आहए'): 3299,
#  ('कअरअणयआतअ', 'आलए'): 3270,
#  ('कएलए', 'आहए'): 2997,
#  ('आहए', 'आणइ'): 2881,
#  ('आहए', 'तयआमउळए'): 2770,
#  ('कअरअणयआतअ', 'आलआ'): 2757,
#  ('आहए', 'कई'): 2597,
#  ('आलआ', 'आहए'): 2567,
#  ('आहए', 'पअणअ'): 2559,
#  ('आलए', 'आहए'): 2549,
#  ('झआलई', 'आहए'): 2546,
#  ('आहए', 'हए'): 2498,
#  ('असएलअ', 'तअरअ'): 2439,
#  ('हओणआरअ', 'आहए'): 2224,
#  ('जआतअ', 'आहए'): 2127,
#  ('झआलआ', 'आहए'): 2025,
#  ('हओतअ', 'आहए'): 2018,
#  ('कएलई', 'हओतई'): 1999,
#  ('आहए', 'मआतरअ'): 1915,
#  ('नआहई', 'तअरअ'): 1897,
#  ('आहए', 'असए'): 1867,
#  ('यएणआरअ', 'आहए'): 1860,
#  ('आहए', 'तअरअ'): 1717,
#  ('कअरऊ', 'शअकअतआ'): 1707,
#  ('झआलए', 'आहए'): 1647,
#  ('कअरअणए', 'आवअशयअकअ'): 1615,
#  ('शअकअतअ', 'नआहई'): 1608,
#  ('नअवई', 'दइललई'): 1558,
#  ('यएतअ', 'आहए'): 1552,
#  ('आलए', 'हओतए'): 1542,
#  ('दइलई', 'आहए'): 1438,
#  ('जआऊ', 'शअकअतए'): 1415,
#  ('उपअसथइतअ', 'हओतए'): 1334,
#  ('यआअंनई', 'सआअंगइतअलए'): 1331,
#  ('आहए', 'तए'): 1297,
#  ('कएलए', 'हओतए'): 1272,
#  ('महअटअलए', 'आहए'): 1265,
#  ('कएलआ', 'हओतआ'): 1250,
#  ('आहए', 'तओ'): 1236,
#  ('सउरऊ', 'आहए'): 1224,
#  ('शअकयअतआ', 'आहए'): 1207,
#  ('नअरएअंदरअ', 'मओदई'): 1197,
#  ('दइलआ', 'आहए'): 1186,
#  ('आलई', 'हओतई'): 1181,
#  ('सअमआवएशअ', 'आहए'): 1155,
#  ('आहएतअ', 'यआ'): 1149,
#  ('आहए', 'तअसएचअ'): 1138,
#  ('झआलए', 'आहएतअ'): 1128,
#  ('गउनहआ', 'दआखअलअ'): 1124,
#  ('नइरणअयअ', 'घएतअलआ'): 1115,
#  ('उदधअवअ', 'ठआकअरए'): 1106,
#  ('पउनहआ', 'एकअदआ'): 1096,
#  ('दएवएअंदरअ', 'फअडअणअवईसअ'): 1091,
#  ('जआणआरअ', 'आहए'): 1084,
#  ('अशई', 'मआगअणई'): 1065,
#  ('दआखअलअ', 'कअरअणयआतअ'): 1062,
#  ('लआखअ', 'हअजआरअ'): 1034,
#  ('मओठयआ', 'परअमआणआतअ'): 1017,
#  ('परअयअतनअ', 'कएलआ'): 1016,
#  ('पअंतअपरअधआनअ', 'नअरएअंदरअ'): 1015,
#  ('शअरअदअ', 'पअवआरअ'): 1004,
#  ('झआलए', 'हओतए'): 1001,
#  ('दएणयआतअ', 'आलई'): 998,
#  ('कअरअणयआतअ', 'यएणआरअ'): 991,
#  ('तए', 'महअणआलए'): 988,
#  ('पआटईलअ', 'यआअंनई'): 977,
#  ('झआलआ', 'हओतआ'): 961,
#  ('मऋतयऊ', 'झआलआ'): 954,
#  ('आलआ', 'हओतआ'): 951,
#  ('कअरअतअ', 'आहएतअ'): 950,
#  ('झआलई', 'हओतई'): 932,
#  ('आणइ', 'एकअ'): 926,
#  ('सउरउवआतअ', 'कएलई'): 925,
#  ('नआहई', 'पअणअ'): 908,
#  ('नआहई', 'असए'): 907,
#  ('नआहई', 'आणइ'): 906,
#  ('आलए', 'आहएतअ'): 905,
#  ('असऊ', 'शअकअतए'): 898,
#  ('घएतअलआ', 'आहए'): 887,
#  ('आहए', 'एकअ'): 882,
#  ('वयअकतअ', 'कएलई'): 879,
#  ('नआहई', 'हए'): 869,
#  ('नआहई', 'यआ'): 863,
#  ('आहए', 'हआ'): 840,
#  ('तओ', 'एकअ'): 835,
#  ('आणइ', 'इतअरअ'): 834,
#  ('असअलयआचई', 'मआहइतई'): 827,
#  ('हओतअ', 'नआहई'): 814,
#  ('आहएतअ', 'आणइ'): 814,
#  ('आहए', 'कआ'): 814,
#  ('यएतअ', 'नआहई'): 805,
#  ('मउखयअमअंतरई', 'दएवएअंदरअ'): 803,
#  ('असअलए', 'तअरई'): 799,
#  ('दएणयआतअ', 'आलए'): 791,
#  ('सपअषटअ', 'कएलए'): 790,
#  ('आहए', 'हई'): 784,
#  ('ठआकअरए', 'यआअंनई'): 783,
#  ('कअरअतअ', 'आहए'): 782,
#  ('आहए', 'मउअंबअई'): 781,
#  ('आहए', 'आतआ'): 780,
#  ('नअ', 'कअरअतआ'): 761,
#  ('पअवआरअ', 'यआअंनई'): 760,
#  ('हओतए', 'यआ'): 756,
#  ('महअणआलए', 'कई'): 755,
#  ('यआ', 'परअकअरअणआतअ'): 744,
#  ('अटअकअ', 'कएलई'): 743,
#  ('अशई', 'मआहइतई'): 742,
#  ('नअवहए', 'तअरअ'): 730,
#  ('आहए', 'पअरअंतउ'): 722,
#  ('रआहउलअ', 'गआअंधई'): 721,
#  ('यआ', 'सअरवअ'): 716,
#  ('यआअंनई', 'दइलई'): 709,
#  ('हअजआरअ', 'रउपअयए'): 708,
#  ('वयअकतअ', 'कएलआ'): 706,
#  ('आहए', 'तयआ'): 706,
#  ('यआअंनई', 'कएलए'): 697,
#  ('आहए', 'दअरअमयआनअ'): 678,
#  ('सओशअलअ', 'मईडइयआवअरअ'): 676,
#  ('आहएतअ', 'तयआमउळए'): 671,
#  ('मआगअणई', 'कएलई'): 667,
#  ('आणइ', 'तओ'): 667,
#  ('हओतए', 'आणइ'): 667,
#  ('कएलअं', 'आहए'): 664,
#  ('कअरअणयआतअ', 'यएतअ'): 663,
#  ('मआतरअ', 'यआ'): 662,
#  ('कअरअणयआचआ', 'नइरणअयअ'): 655,
#  ('हओणयआचई', 'शअकयअतआ'): 655,
#  ('आहए', 'कआरअणअ'): 654,
#  ('आणअखई', 'एकअ'): 647,
#  ('दइलए', 'आहए'): 645,
#  ('कएलए', 'आहएतअ'): 643,
#  ('कओटई', 'रउपअयए'): 637,
#  ('आहएतअ', 'पअणअ'): 636,
#  ('आहए', 'आपअणअ'): 628,
#  ('कएलआ', 'जआतओ'): 628,
#  ('सवअतअ', 'चयआ'): 628,
#  ('गअरअजअ', 'आहए'): 628,
#  ('आहए', 'तयआनअंतअरअ'): 621,
#  ('कएलई', 'जआतए'): 618,
#  ('गएलयआ', 'कआहई'): 617,
#  ('आहए', 'अशई'): 615,
#  ('असआ', 'परअशनअ'): 613,
#  ('कअरअणयआचआ', 'परअयअतनअ'): 613,
#  ('कआयअ', 'आहए'): 611,
#  ('हओणआरअ', 'नआहई'): 610,
#  ('असअणए', 'आवअशयअकअ'): 610,
#  ('लआगअणआरअ', 'आहए'): 606,
#  ('असअलई', 'तअरई'): 601,
#  ('आहए', 'असआ'): 598,
#  ('हओऊ', 'शअकअतए'): 598,
#  ('दइसअतअ', 'आहए'): 597,
#  ('अजइतअ', 'पअवआरअ'): 594,
#  ('तअरअ', 'तओ'): 593,
#  ('मआहइतई', 'दइलई'): 591,
#  ('आणइ', 'तए'): 589,
#  ('नआहई', 'तयआमउळए'): 586,
#  ('आहए', 'अशआ'): 584,
#  ('तयआमउळए', 'यआ'): 583,
#  ('हए', 'सअरवअ'): 579,
#  ('कएलए', 'जआतए'): 577,
#  ('आहए', 'यआवएळई'): 574,
#  ('यआ', 'ठइकआणई'): 571,
#  ('यआअंनई', 'कएलआ'): 569,
#  ('कएलए', 'जआऊ'): 563,
#  ('यआअंनई', 'कएलई'): 563,
#  ('आणइ', 'यआ'): 562,
#  ('बओलअतअ', 'हओतए'): 561,
#  ('असअणआरअ', 'आहए'): 560,
#  ('दएणयआतअ', 'आलआ'): 560,
#  ('कअरअणयआतअ', 'आलएलयआ'): 557,
#  ('आहए', 'असअं'): 556,
#  ('असअलआ', 'तअरई'): 556,
#  ('हओतए', 'पअणअ'): 555,
#  ('रआजअ', 'ठआकअरए'): 554,
#  ('असऊनअ', 'यआ'): 553,
#  ('फअडअणअवईसअ', 'यआअंनई'): 552,
#  ('कएलई', 'जआतअ'): 552,
#  ('आहएतअ', 'हए'): 549,
#  ('कई', 'नआहई'): 549,
#  ('यआ', 'वएळई'): 546,
#  ('आहए', 'तई'): 546,
#  ('दइलए', 'आहएतअ'): 545,
#  ('आहए', 'मई'): 545,
#  ('तयआअंनई', 'सआअंगइतअलए'): 544,
#  ('यआ', 'दओनहई'): 542,
#  ('यएणआरअ', 'नआहई'): 541,
#  ('वइशएषअ', 'महअणअजए'): 539,
#  ('आहए', 'महअणऊनअ'): 538,
#  ('मइळअणआरअ', 'आहए'): 528,
#  ('आणइ', 'तयआअंचयआ'): 528,
#  ('यआ', 'परअकअरअणई'): 526,
#  ('नआहई', 'आहए'): 526,
#  ('आणइ', 'नअंतअरअ'): 522,
#  ('कअरअणआरअ', 'आहए'): 520,
#  ('नआहई', 'असआ'): 518,
#  ('तअरअ', 'तए'): 517,
#  ('नआवअ', 'आहए'): 511,
#  ('दइलई', 'हओतई'): 506,
#  ('लआखअ', 'रउपअयए'): 506,
#  ('पअणअ', 'यआ'): 505,
#  ('आहएतअ', 'तअरअ'): 504,
#  ('अटअकअ', 'कअरअणयआतअ'): 503,
#  ('उपअलअबधअ', 'कअरऊनअ'): 502,
#  ('आपअणअ', 'एकअ'): 499,
#  ('आहए', 'जए'): 499,
#  ('शअकयअ', 'आहए'): 491,
#  ('हओतई', 'यआ'): 491,
#  ('कअरऊ', 'शअकअतअ'): 490,
#  ('कअधई', 'कअधई'): 486,
#  ('सआअंगइतअलए', 'कई'): 486,
#  ('जआतअ', 'नआहई'): 484,
#  ('कआमअ', 'कअरअतअ'): 483,
#  ('हआ', 'परअकआरअ'): 483,
#  ('यआ', 'दओनअ'): 483,
#  ('आहएतअ', 'मआतरअ'): 480,
#  ('आणइ', 'तयआचयआ'): 478,
#  ('आलअं', 'आहए'): 475,
#  ('जआतअ', 'आहएतअ'): 475,
#  ('गअरअजएचए', 'आहए'): 474,
#  ('हआ', 'चइतरअपअटअ'): 474,
#  ('टईकआ', 'कएलई'): 474,
#  ('दइलए', 'हओतए'): 473,
#  ('घएतअलई', 'आहए'): 471,
#  ('यआअंचयआ', 'हअसतए'): 466,
#  ('पओलईसअ', 'ठआणयआतअ'): 465,
#  ('आहए', 'कआहई'): 465,
#  ('वयअकतअ', 'कएलए'): 464,
#  ('कअरईतअ', 'आहएतअ'): 463,
#  ('यआअंनई', 'यआ'): 462,
#  ('कएलआ', 'जआतअ'): 462,
#  ('नइरमआणअ', 'झआलई'): 462,
#  ('आहए', 'यआमउळए'): 458,
#  ('आलयआ', 'आहएतअ'): 456,
#  ('जआसतईतअ', 'जआसतअ'): 455,
#  ('घएणयआतअ', 'आलआ'): 451,
#  ('महअटअलअं', 'आहए'): 450,
#  ('वआढअ', 'झआलई'): 448,
#  ('कआमअ', 'कएलए'): 447,
#  ('हई', 'घअटअनआ'): 446,
#  ('यआअंनई', 'वयअकतअ'): 443,
#  ('सउरउ', 'आहए'): 442,
#  ('यएणआरअ', 'आहएतअ'): 441,
#  ('सउरऊ', 'कएलई'): 438,
#  ('मइळअतअ', 'आहए'): 437,
#  ('नआहई', 'फअकतअ'): 436,
#  ('दइलआ', 'हओतआ'): 436,
#  ('आहएतअ', 'तए'): 434,
#  ('जइलहआ', 'पअरइषअदअ'): 434,
#  ('मओदई', 'यआअंनई'): 431,
#  ('आहए', 'आजअ'): 431,
#  ('पअणअ', 'तओ'): 428,
#  ('कअरअणयआतअ', 'आलअं'): 426,
#  ('हए', 'लअकषआतअ'): 425,
#  ('असआ', 'सअवआलअ'): 425,
#  ('सआअंगअणयआतअ', 'आलए'): 425,
#  ('जअखअमई', 'झआलए'): 424,
#  ('असए', 'आवआहअनअ'): 423,
#  ('कओटई', 'लआखअ'): 420,
#  ('हओतए', 'तयआमउळए'): 419,
#  ('हआ', 'नइरणअयअ'): 418,
#  ('हओतआ', 'यआ'): 416,
#  ('सउरऊ', 'झआलई'): 414,
#  ('घअटअनआ', 'घअडअलई'): 412,
#  ('नआहई', 'मआतरअ'): 411,
#  ('फअकतअ', 'एकअ'): 410,
#  ('कई', 'एकअ'): 410,
#  ('हओतए', 'कई'): 409,
#  ('यआअंचआ', 'सअमआवएशअ'): 409,
#  ('हओऊ', 'शअकअतओ'): 407,
#  ('हओतए', 'मआतरअ'): 406,
#  ('कआमअ', 'सउरऊ'): 406,
#  ('सआअंगइतअलए', 'आहए'): 405,
#  ('खअरअं', 'तअरअ'): 404,
#  ('पअतरअकआरअ', 'पअरइषअदएतअ'): 404,
#  ('गएलए', 'हओतए'): 402,
#  ('यएतअ', 'आहएतअ'): 401,
#  ('मओठयआ', 'परअमआणआवअरअ'): 400,
#  ('तअयआरअ', 'कअरअणयआसआठई'): 399,
#  ('दइसऊनअ', 'यएतअ'): 399,
#  ('हअजआरअ', 'कओटई'): 398,
#  ('सउरउवआतअ', 'झआलई'): 396,
#  ('लआगअतअ', 'आहए'): 394,
#  ('दइलएलयआ', 'मआहइतईनउसआरअ'): 394,
#  ('आहए', 'तयआतअ'): 393,
#  ('पअणअ', 'आतआ'): 392,
#  ('असअतईलअ', 'तअरअ'): 391,
#  ('घओषअणआ', 'कएलई'): 390,
#  ('हओतअ', 'आहएतअ'): 390,
#  ('आयओजअनअ', 'कअरअणयआतअ'): 388,
#  ('आयओजइतअ', 'कअरअणयआतअ'): 385,
#  ('दइसअतअ', 'नआहई'): 385,
#  ('आहए', 'गएलयआ'): 385,
#  ('झआलई', 'असऊनअ'): 384,
#  ('वअ', 'इतअरअ'): 383,
#  ('रआजयअ', 'सअरअकआरअनए'): 382,
#  ('नउकअसआनअ', 'झआलए'): 382,
#  ('दआखअलअ', 'कएलई'): 381,
#  ('आहएतअ', 'असए'): 377,
#  ('कएलयआ', 'आहएतअ'): 376,
#  ('एकअ', 'लअहआनअ'): 376,
#  ('सअमओरअ', 'आलई'): 375,
#  ('मअधयए', 'एकअ'): 374,
#  ('छअतरअपअतई', 'शइवआजई'): 374,
#  ('गआअंधई', 'यआअंनई'): 374,
#  ('कएलए', 'जआतअ'): 373,
#  ('परअवएशअ', 'कएलआ'): 373,
#  ('नआहई', 'महअणऊनअ'): 372,
#  ('पअणअ', 'तए'): 372,
#  ('भएटअ', 'घएतअलई'): 371,
#  ('सउरऊ', 'कअरअणयआतअ'): 369,
#  ('रआषटरअवआदई', 'कआअँगरएसअचए'): 369,
#  ('हआ', 'परअशनअ'): 369,
#  ('सअमओरअ', 'आलए'): 369,
#  ('नअसएलअ', 'तअरअ'): 369,
#  ('लआगअलई', 'आहए'): 368,
#  ('तअयआरअ', 'कअरअणयआतअ'): 366,
#  ('आणइ', 'आपअणअ'): 365,
#  ('तअरअ', 'यआ'): 365,
#  ('आणइ', 'तयआ'): 363,
#  ('अशआ', 'परअकआरए'): 361,
#  ('कअरअणयआतअ', 'यएईलअ'): 360,
#  ('नआहई', 'अशई'): 359,
#  ('उपअलअबधअ', 'आहए'): 359,
#  ('आहएतअ', 'कई'): 359,
#  ('सअरवओचचअ', 'नयआयआलअयआनए'): 359,
#  ('असआ', 'वइशवआसअ'): 357,
#  ('मआहईतअ', 'आहए'): 356,
#  ('अमइतअ', 'शअहआ'): 356,
#  ('आहए', 'तयआअंनई'): 355,
#  ('मअहअतवआचए', 'आहए'): 355,
#  ('आहए', 'नअवई'): 355,
#  ('सउरऊ', 'असअलएलयआ'): 354,
#  ('नइरणअयअ', 'घएणयआतअ'): 354,
#  ('असअलयआचआ', 'आरओपअ'): 353,
#  ('लआगअलए', 'आहए'): 352,
#  ('झआलए', 'असऊनअ'): 351,
#  ('हए', 'एकअ'): 350,
#  ('दआखअलअ', 'कएलआ'): 350,
#  ('आहए', 'सअधयआ'): 348,
#  ('सअंजअयअ', 'रआऊतअ'): 347,
#  ('हओतई', 'पअणअ'): 347,
#  ('तए', 'यआ'): 347,
#  ('हओतआ', 'आणइ'): 346,
#  ('मआतरअ', 'आतआ'): 345,
#  ('कअरऊ', 'नअकआ'): 345,
#  ('हओऊ', 'नअयए'): 345,
#  ('यआचआ', 'अरथअ'): 345,
#  ('कएअंदरअ', 'सअरअकआरअनए'): 344,
#  ('कआरअवआई', 'कएलई'): 343,
#  ('सउरऊ', 'हओतए'): 342,
#  ('अनएकअ', 'ठइकआणई'): 341,
#  ('असए', 'महअटअलए'): 341,
#  ('नआहई', 'असअं'): 339,
#  ('आहए', 'आमहई'): 339,
#  ('घएतअलआ', 'हओतआ'): 339,
#  ('चअंदरअकआअंतअ', 'पआटईलअ'): 338,
#  ('नइरमआणअ', 'झआलआ'): 338,
#  ('यआअंनई', 'आजअ'): 337,
#  ('परअयअतनअ', 'कअरअतअ'): 337,
#  ('हओतआ', 'पअणअ'): 337,
#  ('आहए', 'तयआअंनआ'): 336,
#  ('तयआचअ', 'वएळई'): 335,
#  ('हए', 'कआमअ'): 334,
#  ('सउरऊ', 'आहएतअ'): 334,
#  ('कअरअतअ', 'हओतए'): 334,
#  ('तअरअ', 'कआहई'): 333,
#  ('गअरअजअ', 'नआहई'): 333,
#  ('नआहई', 'कई'): 333,
#  ('कअरअतआ', 'यएईलअ'): 332,
#  ('नआहई', 'कआरअणअ'): 331,
#  ('एकअ', 'दइवअसअ'): 330,
#  ('गएलए', 'आहए'): 330,
#  ('यआअंचई', 'भएटअ'): 329,
#  ('पओलईसअ', 'नइरईकषअकअ'): 328,
#  ('हआ', 'एकअ'): 328,
#  ('झआलआ', 'असऊनअ'): 327,
#  ('आदएशअ', 'दइलए'): 327,
#  ('हओणआरअ', 'आहएतअ'): 327,
#  ('आणइ', 'मअगअ'): 326,
#  ('आहए', 'मअगअ'): 325,
#  ('असए', 'सआअंगइतअलए'): 324,
#  ('आतआ', 'यआ'): 323,
#  ('एकअ', 'वइशएषअ'): 323,
#  ('मअहआरआषटरअ', 'दएशआ'): 323,
#  ('पएकषआ', 'जआसतअ'): 322,
#  ('एकअ', 'वयअकतई'): 322,
#  ('हओतई', 'आणइ'): 321,
#  ('दएणयआतअ', 'यएणआरअ'): 321,
#  ('रउगणआलअयआतअ', 'दआखअलअ'): 321,
#  ('आहए', 'यआतअ'): 320,
#  ('भआरअतईयअ', 'जअनअतआ'): 320,
#  ('ठअरअणआरअ', 'आहए'): 320,
#  ('यआअंनई', 'आपअलयआ'): 320,
#  ('कअरअणए', 'शअकयअ'): 319,
#  ('आहए', 'कआयअ'): 319,
#  ('टईमअ', 'मअहआरआषटरअ'): 319,
#  ('कएलई', 'यआ'): 318,
#  ('कअरअणआरअ', 'नआहई'): 317,
#  ('दइसऊनअ', 'आलए'): 317,
#  ('रआणए', 'यआअंनई'): 317,
#  ('कअरअणआरअ', 'आहएतअ'): 317,
#  ('कएलई', 'असऊनअ'): 316,
#  ('हओतए', 'तए'): 316,
#  ('नआरआयअणअ', 'रआणए'): 316,
#  ('दआखअलअ', 'झआलए'): 315,
#  ('कअरऊ', 'नअयए'): 314,
#  ('कआहई', 'दइवअसआअंपऊरवई'): 314,
#  ('नआहई', 'तए'): 314,
#  ('यआ', 'चइतरअपअटआतअ'): 312,
#  ('झआलयआ', 'आहएतअ'): 312,
#  ('लआगअलआ', 'आहए'): 312,
#  ('सउरऊ', 'कएलए'): 312,
#  ('हओतए', 'हए'): 311,
#  ('आहए', 'तएवहआ'): 309,
#  ('हओतई', 'मआतरअ'): 309,
#  ('पअकषअपरअमउखअ', 'उदधअवअ'): 308,
#  ('आलई', 'असऊनअ'): 307,
#  ('आहए', 'तयआअंचयआ'): 306,
#  ('नअयए', 'महअणऊनअ'): 306,
#  ('कअरईतअ', 'आहए'): 306,
#  ('पअंकअजआ', 'मउअंडए'): 305,
#  ('तयआ', 'वएळई'): 305,
#  ('कएलई', 'जआणआरअ'): 305,
#  ('कएलअं', 'हओतअं'): 305,
#  ('आणइ', 'तयआअंनआ'): 304,
#  ('तअरअ', 'आपअणअ'): 304,
#  ('कएलए', 'आणइ'): 303,
#  ('लओकअसअभआ', 'नइवअडअणउकईतअ'): 303,
#  ('हई', 'मआहइतई'): 303,
#  ('उचचअ', 'नयआयआलअयआनए'): 302,
#  ('कआरअवआई', 'कअरअणयआतअ'): 301,
#  ('मआजई', 'मउखयअमअंतरई'): 301,
#  ('तयआमउळए', 'आतआ'): 301,
#  ('नअकआरअ', 'दइलआ'): 300,
#  ('वइरओधई', 'पअकषअनएतए'): 299,
#  ('कअरअणयआचई', 'मआगअणई'): 299,
#  ('रआषटरअवआदई', 'कआअँगरएसअ'): 299,
#  ('मए', 'रओजई'): 298,
#  ('अरजअ', 'दआखअलअ'): 298,
#  ('गअंभईरअ', 'जअखअमई'): 297,
#  ('जआहईरअ', 'कएलए'): 297,
#  ('तए', 'बओलअतअ'): 297,
#  ('यआ', 'कआळआतअ'): 297,
#  ('वएळअ', 'आलई'): 296,
#  ('कएलए', 'जआतआतअ'): 295,
#  ('कआहई', 'ठइकआणई'): 295,
#  ('कअरअणयआतअ', 'आलयआ'): 295,
#  ('असअलयआचए', 'सआअंगइतअलए'): 295,
#  ('आदइतयअ', 'ठआकअरए'): 294,
#  ('सअहअभआगई', 'झआलए'): 294,
#  ('घएतअलई', 'हओतई'): 294,
#  ('आहए', 'आपअलयआ'): 294,
#  ('वअयअ', 'रआ'): 293,
#  ('पओलइसअ', 'ठआणयआतअ'): 293,
#  ('कएलआ', 'तअरअ'): 293,
#  ('मआजई', 'आमअदआरअ'): 292,
#  ('वआपअरअ', 'कअरऊनअ'): 291,
#  ('लअकषआतअ', 'ठएवआ'): 290,
#  ('एकअ', 'चआअंगअलआ'): 290,
#  ('गएलआ', 'आहए'): 289,
#  ('वइचआरअ', 'कएलआ'): 289,
#  ('धआवआ', 'कएलयआ'): 286,
#  ('हओणआरअ', 'असऊनअ'): 286,
#  ('आहए', 'यआचआ'): 286,
#  ('आणइ', 'तई'): 285,
#  ('कअरअणयआचए', 'आदएशअ'): 284,
#  ('पआटईलअ', 'यआअंचयआ'): 284,
#  ('जआणआरअ', 'नआहई'): 284,
#  ('आपअणअ', 'आपअलयआ'): 284,
#  ('कअरअणयआचई', 'गअरअजअ'): 283,
#  ('वआपअरअ', 'कएलआ'): 283,
#  ('मआनअलए', 'जआतए'): 282,
#  ('असए', 'तयआअंनई'): 282,
#  ('शइवअसएनआ', 'पअकषअपरअमउखअ'): 282,
#  ('असआ', 'आरओपअ'): 281,
#  ('यआअंनई', 'महअटअलए'): 281,
#  ('मइळआलआ', 'आहए'): 280,
#  ('पएकषआ', 'अधइकअ'): 280,
#  ('मआहइतई', 'आहए'): 280,
#  ('कअरआ', 'आणइ'): 280,
#  ('नआहई', 'तओ'): 279,
#  ('आणइ', 'आतआ'): 278,
#  ('अवअलअंबऊनअ', 'असअतए'): 278,
#  ('वइधआनअसअभआ', 'नइवअडअणउकईतअ'): 278,
#  ('धअनअंजअयअ', 'मउअंडए'): 277,
#  ('मउअंडए', 'यआअंनई'): 277,
#  ('यआ', 'पआरशवअभऊमईवअरअ'): 277,
#  ('कएलई', 'आणइ'): 277,
#  ('आणइ', 'कआहई'): 277,
#  ('गएलयआ', 'दओनअ'): 277,
#  ('सआजअरआ', 'कएलआ'): 276,
#  ('घअडअलई', 'आहए'): 275,
#  ('जआतअ', 'हओतए'): 274,
#  ('कअरअतआ', 'यएणआरअ'): 273,
#  ('आलए', 'असऊनअ'): 273,
#  ('हओतआ', 'मआतरअ'): 273,
#  ('पअरआभअवअ', 'कएलआ'): 272,
#  ('वइरओधअ', 'कएलआ'): 272,
#  ('गएलयआ', 'वअरषई'): 272,
#  ('आहए', 'अनएकअ'): 272,
#  ('आहए', 'सअरवअ'): 272,
#  ('कअरअतअ', 'नआहई'): 271,
#  ('तआबयआतअ', 'घएतअलए'): 271,
#  ('असआ', 'इशआरआ'): 271,
#  ('बअसअलआ', 'आहए'): 270,
#  ('लअकषआतअ', 'घएऊनअ'): 270,
#  ('तयआअंचयआ', 'सवअतअ'): 270,
#  ('असआलअ', 'तअरअ'): 270,
#  ('यआ', 'सअंदअरभआतअ'): 270,
#  ('कअमई', 'आहए'): 270,
#  ('आहए', 'यआमअधयए'): 269,
#  ('एकअ', 'नअवईनअ'): 269,
#  ('कआहई', 'दइवअसआअंपआसऊनअ'): 268,
#  ('यआ', 'कआलआवअधईतअ'): 268,
#  ('तअयआरअ', 'कएलए'): 267,
#  ('गएलए', 'आहएतअ'): 267,
#  ('कएलई', 'जआईलअ'): 267,
#  ('खअळअबअळअ', 'उडआलई'): 267,
#  ('एकआचअ', 'वएळई'): 266,
#  ('यआचइकआ', 'दआखअलअ'): 265,
#  ('आहए', 'मअधयए'): 265,
#  ('वआटअतअ', 'नआहई'): 264,
#  ('तअकरआरअ', 'दआखअलअ'): 264,
#  ('हओतए', 'तअरअ'): 264,
#  ('मउअंबअई', 'उचचअ'): 264,
#  ('कअरऊ', 'शअकअतओ'): 263,
#  ('पअरइणआमअ', 'महअणऊनअ'): 263,
#  ('नआरआजई', 'वयअकतअ'): 263,
#  ('जआहईरअ', 'कअरअणयआतअ'): 262,
#  ('मइळअतअ', 'नआहई'): 262,
#  ('घएणयआतअ', 'आलई'): 262,
#  ('अशआ', 'अनएकअ'): 262,
#  ('चआअंगअलए', 'आहए'): 262,
#  ('कआअँगरएसअ', 'आणइ'): 261,
#  ('चअरचआ', 'कएलई'): 261,
#  ('सवअतअ', 'लआ'): 261,
#  ('हओईलअ', 'असए'): 261,
#  ('आणइ', 'तयआमउळए'): 260,
#  ('कएअंदरईयअ', 'मअंतरई'): 260,
#  ('असए', 'यआ'): 260,
#  ('महअणऊनअ', 'कआमअ'): 260,
#  ('वआढअतअ', 'आहए'): 260,
#  ('चअरचआ', 'सउरऊ'): 259,
#  ('महअणअणए', 'आहए'): 259,
#  ('ठआकअरए', 'यआअंचयआ'): 259,
#  ('जआणआरअ', 'आहएतअ'): 258,
#  ('सपअषटअ', 'झआलए'): 258,
#  ('आहए', 'तयआसआठई'): 258,
#  ('लआगअलए', 'आहएतअ'): 258,
#  ('कअमई', 'कअरअणयआसआठई'): 258,
#  ('भआरअतअ', 'आणइ'): 258,
#  ('असआ', 'दआवआ'): 257,
#  ('परअयअतनअ', 'कएलए'): 257,
#  ('धआवअ', 'घएतअलई'): 256,
#  ('तअसएचअ', 'यआ'): 256,
#  ('महअटअलए', 'जआतए'): 256,
#  ('घएतअ', 'आहएतअ'): 256,
#  ('कई', 'यआ'): 256,
#  ('रआऊतअ', 'यआअंनई'): 256,
#  ('पअणअ', 'हए'): 256,
#  ('तअरअ', 'दउसअरईकअडए'): 255,
#  ('हऊनअ', 'अधइकअ'): 255,
#  ('आहए', 'यआचई'): 255,
#  ('झआलअं', 'आहए'): 254,
#  ('सआदअरअ', 'कएलए'): 254,
#  ('कएलए', 'यआ'): 254,
#  ('आहए', 'वअ'): 253,
#  ('शइअंदए', 'यआअंनई'): 253,
#  ('कएलआ', 'आणइ'): 252,
#  ('जयएषठअ', 'नएतए'): 252,
#  ('सअकआळई', 'वआजअतआ'): 252,
#  ('नअयए', 'यआसआठई'): 252,
#  ('आदई', 'उपअसथइतअ'): 252,
#  ('सओपए', 'आहए'): 252,
#  ('कअरऊ', 'शअकअतआतअ'): 252,
#  ('मइळआलई', 'आहए'): 251,
#  ('यआचई', 'खआतरई'): 251,
#  ('उपअसथइतअ', 'कएलआ'): 251,
#  ('कएलआ', 'यआ'): 251,
#  ('सउरऊ', 'कएलआ'): 251,
#  ('जआहईरअ', 'कएलई'): 250,
#  ('यअशअ', 'आलए'): 250,
#  ('जआनएवआरई', 'रओजई'): 250,
#  ('उमएदअवआरई', 'अरजअ'): 249,
#  ('आणइ', 'हए'): 248,
#  ('दअरअमयआनअ', 'यआ'): 248,
#  ('अधयअकषअ', 'शअरअदअ'): 247,
#  ('मओठयआ', 'सअंखयएनए'): 247,
#  ('आलई', 'नआहई'): 246,
#  ('एकअ', 'वइशइषटअ'): 246,
#  ('हई', 'एकअ'): 245,
#  ('दआखअलअ', 'कएलए'): 245,
#  ('आणइ', 'आपअलयआ'): 244,
#  ('घएतअलए', 'आहए'): 244,
#  ('धअककआ', 'बअसअलआ'): 243,
#  ('रआहअणआरअ', 'आहए'): 242,
#  ('जअयअंतअ', 'पआटईलअ'): 242,
#  ('यआअंनई', 'यआवएळई'): 242,
#  ('नआहई', 'हआ'): 242,
#  ('नइरमआणअ', 'झआलए'): 241,
#  ('हई', 'गओषटअ'): 240,
#  ('नआहई', 'अशआ'): 240,
#  ('आलआ', 'नआहई'): 239,
#  ('आलए', 'नआहई'): 239,
#  ('कओटई', 'रउपअयआअंचई'): 239,
#  ('कअरअणयआचई', 'सअंधई'): 238,
#  ('झआलआ', 'नआहई'): 238,
#  ('नआहई', 'यआचई'): 238,
#  ('कएलई', 'तअरअ'): 238,
#  ('यआ', 'भआगआतअ'): 237,
#  ('उचचअ', 'नयआयआलअयआतअ'): 237,
#  ('आहए', 'तयआलआ'): 237,
#  ('असअलयआचए', 'तयआअंनई'): 236,
#  ('हओतई', 'तयआमउळए'): 236,
#  ('आहए', 'एकआ'): 236,
#  ('जइलहआ', 'पअरइषअदएचयआ'): 235,
#  ('आहए', 'तअथआपइ'): 235,
#  ('नअमऊदअ', 'कएलए'): 235,
#  ('वआपअरअलए', 'जआतए'): 235,
#  ('एकअ', 'अतइशअयअ'): 235,
#  ('आवअशयअकअतआ', 'आहए'): 235,
#  ('आलई', 'आहएतअ'): 234,
#  ('सउरऊ', 'झआलआ'): 234,
#  ('आहएतअ', 'तअसएचअ'): 234,
#  ('कअठईणअ', 'आहए'): 234,
#  ('पअरअवआनअगई', 'दएतए'): 234,
#  ('हई', 'बआबअ'): 233,
#  ('तअरअ', 'तई'): 233,
#  ('नअ', 'घएतआ'): 233,
#  ('असऊनअ', 'तए'): 232,
#  ('दएतअ', 'नआहई'): 232,
#  ('जआईलअ', 'असए'): 232,
#  ('एकअ', 'भआगअ'): 232,
#  ('झआलए', 'तअरअ'): 232,
#  ('झआलई', 'नआहई'): 231,
#  ('आहए', 'तयआचयआ'): 231,
#  ('आहए', 'असएहई'): 231,
#  ('हओतअ', 'असऊनअ'): 231,
#  ('दइसअतअ', 'आहएतअ'): 230,
#  ('अखइलअ', 'भआरअतईयअ'): 230,
#  ('कआरयअकआरई', 'अधइकआरई'): 230,
#  ('झआलआ', 'तअरअ'): 230,
#  ('हओतआ', 'तयआमउळए'): 229,
#  ('यओगयअ', 'आहए'): 229,
#  ('अशई', 'अपएकषआ'): 229,
#  ('असए', 'तए'): 228,
#  ('सआअंगइतअलए', 'हओतए'): 228,
#  ('गउनहए', 'दआखअलअ'): 228,
#  ('आहएतअ', 'तयआ'): 228,
#  ('वयअकतअ', 'हओतअ'): 228,
#  ('दएणआरअ', 'नआहई'): 228,
#  ('हए', 'दएखईलअ'): 227,
#  ('वआढअलई', 'आहए'): 227,
#  ('यएईलअ', 'असए'): 227,
#  ('कअरअतअ', 'असअतआनआ'): 226,
#  ('आहए', 'तयआनउसआरअ'): 226,
#  ('आलअं', 'हओतअं'): 226,
#  ('ऑनअलआईनअ', 'टईमअ'): 226,
#  ('मअदअतअ', 'कएलई'): 226,
#  ('वइरआटअ', 'कओहअलई'): 226,
#  ('जए', 'कआहई'): 225,
#  ('डऑ', 'बआबआसआहएबअ'): 225,
#  ('शइवआजई', 'मअहआरआजअ'): 225,
#  ('जआऊ', 'शअकअतओ'): 224,
#  ('आहए', 'परअतयएकअ'): 224,
#  ('मअहआरआषटरअ', 'रआजयअ'): 224,
#  ('असए', 'मअतअ'): 224,
#  ('आलआ', 'असऊनअ'): 223,
#  ('चअरचआ', 'झआलई'): 223,
#  ('नआहई', 'कआ'): 223,
#  ('नअवई', 'मउअंबअई'): 223,
#  ('मओठअआ', 'परअमआणआतअ'): 223,
#  ('यआ', 'बऐठअकईतअ'): 222,
#  ('कएलए', 'जआणआरअ'): 222,
#  ('यआचई', 'मआहइतई'): 221,
#  ('सअरवआतअ', 'मओठआ'): 221,
#  ('यआ', 'वइषअयआवअरअ'): 221,
#  ('लअकषअ', 'कएअंदरइतअ'): 221,
#  ('मअदअतअ', 'कअरअतए'): 221,
#  ('आहए', 'मअलआ'): 221,
#  ('यआअंनई', 'सपअषटअ'): 220,
#  ('कएलए', 'नआहई'): 220,
#  ('आहए', 'यआबआबअतअ'): 220,
#  ('दआवआ', 'कएलआ'): 220,
#  ('जअणआअंचआ', 'मऋतयऊ'): 220,
#  ('पअणअ', 'एकअ'): 220,
#  ('परअयअतनअ', 'सउरऊ'): 220,
#  ('हई', 'कआरअवआई'): 219,
#  ('आहए', 'कइअंवआ'): 219,
#  ('तयआ', 'ठइकआणई'): 219,
#  ('पआरअ', 'पअडअलआ'): 219,
#  ('मआहइतई', 'सअमओरअ'): 218,
#  ('जआधअवअ', 'यआअंनई'): 218,
#  ('घएणए', 'आवअशयअकअ'): 218,
#  ('सआमओरए', 'जआवए'): 218,
#  ('तयआअंनई', 'यआवएळई'): 217,
#  ('सउरऊ', 'झआलए'): 217,
#  ('तयआचयआ', 'सवअतअ'): 217,
#  ('आहएतअ', 'एकअ'): 217,
#  ('सअरवओचचअ', 'नयआयआलअयआतअ'): 217,
#  ('पओलइसआअंनई', 'अटअकअ'): 217,
#  ('जआऊ', 'शअकअतअ'): 217,
#  ('सअरवआतअ', 'मओठई'): 216,
#  ('बआबआसआहएबअ', 'आअंबएडअकअरअ'): 216,
#  ('असएहई', 'तयआअंनई'): 216,
#  ('रउपअयए', 'खअरचअ'): 216,
#  ('मउखयअ', 'कआरयअकआरई'): 216,
#  ('कएलए', 'गएलए'): 216,
#  ('घएणयआतअ', 'आलए'): 216,
#  ('जआतअ', 'असअतआनआ'): 216,
#  ('दओनअ', 'दइवअसअ'): 216,
#  ('पअतरअकआरअ', 'पअरइषअदअ'): 215,
#  ('झआलए', 'आणइ'): 215,
#  ('कई', 'कआयअ'): 215,
#  ('वयअकतअ', 'कअरअणयआतअ'): 215,
#  ('दइसऊनअ', 'यएतए'): 215,
#  ('डइसएअंबअरअ', 'रओजई'): 214,
#  ('आजअ', 'सअकआळई'): 214,
#  ('चअवहआणअ', 'यआअंनई'): 214,
#  ('भएटअ', 'दइलई'): 213,
#  ('जउलऐ', 'रओजई'): 213,
#  ('तअरअ', 'मई'): 213,
#  ('तअयआरअ', 'कअरअणए'): 213,
#  ('आहए', 'शइवआयअ'): 213,
#  ('परअशनअ', 'आहए'): 212,
#  ('वइजअयअ', 'मइळअवअलआ'): 212,
#  ('कअरआवई', 'अशई'): 212,
#  ('हओतए', 'असए'): 212,
#  ('पअवआरअ', 'यआअंचयआ'): 212,
#  ('आहए', 'पउणए'): 212,
#  ('गएलई', 'आहए'): 211,
#  ('तअयआरअ', 'कएलआ'): 211,
#  ('असअलयआचआ', 'दआवआ'): 211,
#  ('एकअ', 'आहए'): 211,
#  ('आणइ', 'मई'): 211,
#  ('कई', 'मई'): 211,
#  ('असअतए', 'तअरअ'): 210,
#  ('आणइ', 'सअरवअ'): 210,
#  ('ऑगअसटअ', 'रओजई'): 210,
#  ('सअरअकआरअ', 'सथआपअनअ'): 210,
#  ('हओतआ', 'तओ'): 209,
#  ('हए', 'सपअषटअ'): 209,
#  ('तए', 'एकअ'): 209,
#  ('एपरइलअ', 'रओजई'): 209,
#  ('असअलएलयआ', 'यआ'): 209,
#  ('तअरअ', 'तयआ'): 208,
#  ('सआरवअजअनइकअ', 'बआअंधअकआमअ'): 208,
#  ('कअरअणयआसआठई', 'एकअ'): 208,
#  ('सअरवआतअ', 'जआसतअ'): 208,
#  ('नआहई', 'पअरअंतउ'): 208,
#  ('नएतए', 'आणइ'): 207,
#  ('यएणआरअ', 'असऊनअ'): 207,
#  ('कएलए', 'असऊनअ'): 207,
#  ('आलए', 'यआ'): 207,
#  ('हआ', 'सइनएमआ'): 207,
#  ('यआ', 'दइवअशई'): 207,
#  ('उततअरअ', 'परअदएशअ'): 206,
#  ('कआहई', 'दइवअसअ'): 206,
#  ('गएलआ', 'हओतआ'): 206,
#  ('यआ', 'सपअरधएतअ'): 206,
#  ('एकअ', 'लआखअ'): 206,
#  ('उपअलअबधअ', 'आहएतअ'): 206,
#  ('ठएवअणयआतअ', 'आलए'): 206,
#  ('तअयआरअ', 'आहए'): 206,
#  ('कएलई', 'असअतआ'): 206,
#  ('शइफआरअसअ', 'कएलई'): 206,
#  ('यआअंचयआ', 'मआरगअदअरशअनआखआलई'): 206,
#  ('आहए', 'भआरअतईयअ'): 206,
#  ('नइतईनअ', 'गअडअकअरई'): 206,
#  ('कआयअमअ', 'आहए'): 205,
#  ('दइलए', 'जआतए'): 205,
#  ('आहए', 'तयआचई'): 205,
#  ('कएलई', 'नआहई'): 205,
#  ('आणइ', 'तयआनअंतअरअ'): 205,
#  ('गओषटअ', 'आहए'): 205,
#  ('महअटअलए', 'हओतए'): 204,
#  ('आहए', 'यआसआठई'): 204,
#  ('असए', 'महअणअतअ'): 204,
#  ('अपअघआतअ', 'झआलआ'): 204,
#  ('कअरअणयआचई', 'पअरअवआनअगई'): 204,
#  ('असआ', 'अंदआजअ'): 204,
#  ('कअरऊ', 'इचछइतअ'): 204,
#  ('कअरअणयआसअ', 'सअकषअमअ'): 203,
#  ('हओऊ', 'शअकअतआतअ'): 203,
#  ('झआलई', 'आणइ'): 203,
#  ('उपअचआरअ', 'सउरऊ'): 203,
#  ('नआहई', 'हई'): 203,
#  ('मअदअतअ', 'हओईलअ'): 202,
#  ('झआलआ', 'आणइ'): 202,
#  ('हआ', 'वइषअयअ'): 202,
#  ('मओदई', 'आणइ'): 202,
#  ('कएलआ', 'जआणआरअ'): 201,
#  ('यआ', 'वअरषई'): 201,
#  ('उडआलई', 'आहए'): 201,
#  ('कअरअणए', 'हए'): 200,
#  ('कएलआ', 'असऊनअ'): 200,
#  ('रआजयअ', 'सअरअकआरअ'): 200,
#  ('आहए', 'जअरअ'): 200,
#  ('लअवअकअरआतअ', 'लअवअकअरअ'): 199,
#  ('नइधअनअ', 'झआलए'): 199,
#  ('कअरऊनअ', 'दइलई'): 199,
#  ('सआमअनआ', 'कअरआवआ'): 198,
#  ('अशआ', 'पअरइसथइतईतअ'): 198,
#  ('आणइ', 'तयआचए'): 198,
#  ('यआअंनई', 'दइलआ'): 198,
#  ('हए', 'यआ'): 198,
#  ('सओनइयआ', 'गआअंधई'): 198,
#  ('लअकषआतअ', 'आलए'): 197,
#  ('तअरअ', 'एकअ'): 197,
#  ('पअंतअपरअधआनअ', 'मओदई'): 197,
#  ('आणइ', 'तयआअंचए'): 197,
#  ('चयआ', 'सउमआरआसअ'): 196,
#  ('मआरचअ', 'रओजई'): 196,
#  ('आहएतअ', 'हई'): 196,
#  ('कएलए', 'तअरअ'): 196,
#  ('नओवहएअंबअरअ', 'रओजई'): 196,
#  ('लअकषआतअ', 'घएतआ'): 196,
#  ('असए', 'नआहई'): 195,
#  ('यआअंचयआ', 'नएतऋतवआखआलई'): 195,
#  ('कओणअतयआहई', 'पअरइसथइतईतअ'): 195,
#  ('जऊनअ', 'रओजई'): 195,
#  ('रअददअ', 'कअरअणयआतअ'): 195,
#  ('तअरअ', 'मअगअ'): 195,
#  ('सअरवअ', 'कएलयआनअंतअरअ'): 195,
#  ('आलआ', 'आणइ'): 195,
#  ('भआगअ', 'आहए'): 195,
#  ('हअरअकअतअ', 'नआहई'): 194,
#  ('पअडअलआ', 'आहए'): 194,
#  ('आवआहअनअ', 'कएलए'): 194,
#  ('पअणअ', 'तयआ'): 194,
#  ('कआमअ', 'पऊरणअ'): 194,
#  ('एकअ', 'मओठआ'): 194,
#  ('आहए', 'फअकतअ'): 194,
#  ('दएणयआचआ', 'नइरणअयअ'): 194,
#  ('आरओपअ', 'कएलआ'): 194,
#  ('सअरवअ', 'कआहई'): 194,
#  ('कआहई', 'लओकअ'): 193,
#  ('भआजअपअ', 'आणइ'): 193,
#  ('चअरचआ', 'आहए'): 193,
#  ('सउरऊ', 'असअतआनआ'): 193,
#  ('जआणऊनअ', 'घयआ'): 193,
#  ('इशआरआ', 'दइलआ'): 192,
#  ('नआहईतअ', 'तअरअ'): 192,
#  ('यएऊ', 'शअकअतए'): 192,
#  ('सअपटएअंबअरअ', 'रओजई'): 192,
#  ('सथइतअ', 'आहए'): 192,
#  ('बअंदअ', 'कअरअणयआतअ'): 191,
#  ('कओटई', 'रउपअयआअंचआ'): 191,
#  ('नअ', 'दएतआ'): 191,
#  ('असए', 'सआअंगअतअ'): 191,
#  ('बआळआसआहएबअ', 'ठआकअरए'): 191,
#  ('कआहई', 'परअमआणआतअ'): 191,
#  ('सआदअरअ', 'कअरअणयआतअ'): 191,
#  ('मउखयअमअंतरई', 'उदधअवअ'): 191,
#  ('असऊनअ', 'तओ'): 190,
#  ('कएलआ', 'नआहई'): 190,
#  ('अशअकयअ', 'आहए'): 190,
#  ('एकअ', 'पअरइणआमअ'): 190,
#  ('कअमईतअ', 'कअमई'): 190,
#  ('जआतए', 'आणइ'): 190,
#  ('नआहई', 'तअसएचअ'): 190,
#  ('वइखए', 'पआटईलअ'): 190,
#  ('कअरआवआ', 'लआगअलआ'): 189,
#  ('वइधआनअसअभआ', 'नइवअडअणउकईचयआ'): 189,
#  ('आपअणअ', 'यआ'): 189,
#  ('चऔकअशई', 'कएलई'): 189,
#  ('असए', 'वआटअतए'): 189,
#  ('असऊ', 'शअकअतआतअ'): 189,
#  ('परअशनअ', 'उपअसथइतअ'): 188,
#  ('सअमआवएशअ', 'हओतआ'): 188,
#  ('हओतअ', 'असअलयआनए'): 188,
#  ('महअणअजए', 'यआ'): 188,
#  ('हअललआ', 'कएलआ'): 188,
#  ('फएबरउवआरई', 'रओजई'): 188,
#  ('झआलई', 'आहएतअ'): 188,
#  ('नआहई', 'एकअ'): 188,
#  ('घएऊ', 'शअकअतआ'): 187,
#  ('आहए', 'वइशएषअ'): 187,
#  ('आहएतअ', 'मउअंबअई'): 187,
#  ('शअकअणआरअ', 'नआहई'): 187,
#  ('कएलए', 'पआहइजए'): 187,
#  ('सआदअरअ', 'कएलआ'): 187,
#  ('कआहई', 'कआळअ'): 187,
#  ('हई', 'यओजअनआ'): 187,
#  ('पऊरणअ', 'कअरअणयआसआठई'): 186,
#  ('पआरअ', 'पअडअलई'): 186,
#  ('कएलए', 'जआईलअ'): 186,
#  ('हओतअ', 'असअलयआचए'): 186,
#  ('छअगअनअ', 'भउजअबअळअ'): 185,
#  ('आहए', 'तयआवएळई'): 185,
#  ('कइअंवआ', 'इतअरअ'): 185,
#  ('गरआमईणअ', 'भआगआतअ'): 185,
#  ('शअकयअ', 'नआहई'): 185,
#  ('बअअँकअ', 'ऑफअ'): 185,
#  ('मआजई', 'मअंतरई'): 184,
#  ('तयआअंनई', 'कएलआ'): 184,
#  ('आतमअहअतयआ', 'कएलई'): 184,
#  ('कअरअतअ', 'असअतआतअ'): 183,
#  ('हओतआ', 'हए'): 183,
#  ('सअमओरअ', 'आलआ'): 183,
#  ('तयआअंनई', 'सपअषटअ'): 183,
#  ('गरआमईणअ', 'भआगआतईलअ'): 183,
#  ('यआ', 'तईनअ'): 183,
#  ('आहए', 'अरथआतअ'): 182,
#  ('वइचआरअ', 'कअरऊनअ'): 182,
#  ('आहएतअ', 'जए'): 182,
#  ('कअरअणयआचए', 'कआमअ'): 182,
#  ('यआअंनई', 'महअटअलअं'): 182,
#  ('झआलएलयआ', 'यआ'): 182,
#  ('जआतअ', 'हओतई'): 182,
#  ('दएणए', 'आवअशयअकअ'): 181,
#  ('तअरअ', 'हए'): 181,
#  ('जअगआतईलअ', 'सअरवआतअ'): 181,
#  ('तयआअंचयआ', 'यआ'): 181,
#  ('परअयअतनअ', 'कअरआ'): 181,
#  ('आहएतअ', 'अशई'): 181,
#  ('झआलए', 'नआहई'): 181,
#  ('यआचआ', 'वइचआरअ'): 180,
#  ('आहएतअ', 'तओ'): 180,
#  ('आलए', 'आणइ'): 180,
#  ('घअटअनएचई', 'मआहइतई'): 180,
#  ('पओलइसअ', 'नइरईकषअकअ'): 180,
#  ('यआ', 'सअगअळयआ'): 180,
#  ('आलयआ', 'हओतयआ'): 180,
#  ('पआटईलअ', 'यआअंनआ'): 180,
#  ('मआहइतई', 'मइळअतआचअ'): 179,
#  ('यआ', 'नइवअडअणउकईतअ'): 179,
#  ('शएअरअ', 'कएलआ'): 179,
#  ('हओतए', 'तयआ'): 179,
#  ('वआजअणयआचयआ', 'सउमआरआसअ'): 179,
#  ('अनएकअ', 'वएळआ'): 178,
#  ('आहएतअ', 'आतआ'): 178,
#  ('सवअतअ', 'चई'): 178,
#  ('अधयअकषअ', 'रआहउलअ'): 178,
#  ('तयआअंनई', 'यआ'): 178,
#  ('अनएकअ', 'वअरषए'): 178,
#  ('वइनअंतई', 'कएलई'): 178,
#  ('कअमई', 'हओतअ'): 178,
#  ('नअयए', 'असए'): 178,
#  ('आणइ', 'अनयअ'): 178,
#  ('रआजईनआमआ', 'दइलआ'): 178,
#  ('तअरई', 'यआ'): 177,
#  ('एकअ', 'हअजआरअ'): 177,
#  ('ऑकटओबअरअ', 'रओजई'): 177,
#  ('झआलएलई', 'नआहई'): 177,
#  ('वआपअरऊ', 'शअकअतआ'): 177,
#  ('कई', 'तए'): 177,
#  ('सथआपअनआ', 'कएलई'): 177,
#  ('अशई', 'टईकआ'): 177,
#  ('सअकआळई', 'तए'): 177,
#  ('तअयआरअ', 'कअरऊनअ'): 177,
#  ('तअरउणअ', 'भआरअतअ'): 177,
#  ('जआसतअ', 'आहए'): 177,
#  ('आहए', 'यआचअ'): 176,
#  ('मअहइलआ', 'वअ'): 176,
#  ('जआणऊनअ', 'घएणयआसआठई'): 176,
#  ('वइचआरअ', 'कअरअतअ'): 175,
#  ('वइशवआसअ', 'आहए'): 175,
#  ('पआणई', 'पउरअवअठआ'): 175,
#  ('कआअँगरएसअचए', 'अधयअकषअ'): 175,
#  ('वअंचइतअ', 'बअहउजअनअ'): 175,
#  ('मओदई', 'यआअंचयआ'): 175,
#  ('सअंतआपअ', 'वयअकतअ'): 175,
#  ('कअरणअधआरअ', 'वइरआटअ'): 175,
#  ('शअकअतअ', 'नआहईतअ'): 174,
#  ('तयआमउळए', 'तए'): 174,
#  ('कएलई', 'आहएतअ'): 174,
#  ('कअरआवआ', 'लआगअतअ'): 173,
#  ('लआगअलए', 'हओतए'): 173,
#  ('सवआगअतअ', 'कएलए'): 173,
#  ('दइलयआ', 'आहएतअ'): 173,
#  ('मइळआलएलयआ', 'मआहइतईनउसआरअ'): 173,
#  ('जआऊ', 'नअयए'): 173,
#  ('कई', 'हए'): 172,
#  ('नइवअडअ', 'कअरअणयआतअ'): 172,
#  ('हओईलअ', 'आणइ'): 172,
#  ('यआ', 'कषएतरआतअ'): 172,
#  ('कअरअणयआतअ', 'आलएलई'): 172,
#  ('दएतअ', 'आहए'): 172,
#  ('यआ', 'सआमअनयआतअ'): 172,
#  ('लआगअलई', 'हओतई'): 171,
#  ('चआलऊ', 'आहए'): 171,
#  ('कएलएलई', 'नआहई'): 171,
#  ('आहए', 'तयआचआ'): 171,
#  ('असअतए', 'आणइ'): 171,
#  ('असए', 'आशवआसअनअ'): 171,
#  ('गएलयआ', 'अनएकअ'): 171,
#  ('यएथए', 'झआलएलयआ'): 171,
#  ('अरथअ', 'असआ'): 171,
#  ('पअणअ', 'तअरईहई'): 171,
#  ('कआमअ', 'कअरईतअ'): 170,
#  ('हओतआ', 'कई'): 170,
#  ('पआहअणई', 'कएलई'): 170,
#  ('घएणयआतअ', 'यएणआरअ'): 170,
#  ('हओतअ', 'असअलएलयआ'): 170,
#  ...}

# %%
# fin_dict_bi

# %%
with open('/content/gdrive/MyDrive/cs689/a1/whitespace/fin_whitespace1k_uni_tokens.txt', 'w',encoding = 'utf-8') as f3:
    for key, value in fin_dict.items():
        f3.write('%s : %s\n' % (key, value))
with open('/content/gdrive/MyDrive/cs689/a1/whitespace/fin_whitespace1k_bi_tokens.txt', 'w',encoding = 'utf-8') as f4:
    for key, value in fin_dict_bi.items():
        f4.write('%s : %s\n' % (key, value))

# %%
all_tokens = list(fin_dict.keys())

# %%
L_char_bi = []
L_syl_bi = []

# %%
syl_bi_global = {}
syl_bi_local = {}
char_bi_global = {}
char_bi_local = {}

# %%
i=0
# while (i<len(all_tokens)-1):
for tok in all_tokens:
  i=len(tok)-1
  while (i>0):
    if tok[i] != 'ं' and tok[i] != 'ँ' and tok[i] != 'ः' and tok[i-1] != 'ं' and tok[i-1] != 'ँ' and tok[i-1] != 'ः':
        if tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-1]+tok[i]] += fin_dict[tok]
    elif i>1 and tok[i-1] == 'ं' or tok[i-1] == 'ँ' or tok[i-1] == 'ः' or  tok[i] == 'ं' or tok[i] == 'ँ' or tok[i] == 'ः':
        if tok[i-2]+tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] += fin_dict[tok]
        # i-=1
    if (i<len(tok)-1) and (tok[i+1] == 'ं' or tok[i+1] == 'ँ' or tok[i+1] == 'ः'):
      i-=1
    i-=1

# %%
all_syllables = []
for i in range(len(all_tokens)):
    all_syllables.append([])

# %%
dict_count_uni = {}
dict_count_bi = {}
syl_count_uni = {}
syl_count_bi = {}

# %%
k=0
for words in all_tokens:
    j=0
    # for i in range(len(words)):
    i=0
    while (i<len(words)):
        if ord(words[i]) >=2305 and ord(words[i])<2325:
            if i<len(words)-1 and words[i+1] != 'ः' and words[i+1] != 'ं' and words[i+1] != 'ँ':
                if words[j:i+1] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+1]] = 1
                else:
                    syl_count_uni[words[j:i+1]] += 1
                all_syllables[k].append(words[j:i+1])
                j=i+1
            else:
                if words[j:i+2] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+2]] = 1
                else:
                    syl_count_uni[words[j:i+2]] += 1
                all_syllables[k].append(words[j:i+2])
                j=i+2
                i+=1
        i+=1
    if k%1000 == 0:
        print(k)
    k+=1

# %%
# fin_dict(all_tokens[0])

# %%
k=0
for syls in all_syllables:
    j=0
    for i in range(len(syls)-1):
        if syls[i]+syls[i+1] not in list(syl_bi_local.keys()):
            syl_bi_local[syls[i]+syls[i+1]] = 1
            syl_bi_global[syls[i]+syls[i+1]] = fin_dict[all_tokens[k]]
        else:
            syl_bi_local[syls[i]+syls[i+1]] += 1
            syl_bi_global[syls[i]+syls[i+1]] += fin_dict[all_tokens[k]]
    k+=1
    if k%10000==0:
        print(k)

# %%
fin_dict_char_l = {k: v for k, v in sorted(char_bi_local.items(), key=lambda item: item[1],reverse=True)}
fin_dict_syl_l = {k: v for k, v in sorted(syl_bi_local.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/whitespace/fin_whitespace1k_bi_chars.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('Char : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_char_l.items():
        f3.write('%s : %s : %s\n' % (key, value, char_bi_global[key]))
with open('/content/gdrive/MyDrive/cs689/a1/whitespace/fin_whitespace1k_bi_syls.txt', 'w',encoding = 'utf-8') as f4:
    f4.write('Syl : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_syl_l.items():
        f4.write('%s : %s : %s\n' % (key, value, syl_bi_global[key]))

# %% [markdown]
# ### Calculating precision, recall and f_score

# %%
import re

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/q3.txt','r',encoding='utf-8',errors='ignore')
q3_txt = z.read()
z.close()

# %%
q3_txt = re.sub(r"[^\u0900-\u094F\s,\u0966-\u096F1234567890]", "", q3_txt)

# %%
q3_txt = q3_txt.split('\n')

# %%
q3_txt[0]
# Out:
# 'श्रीगोंदे, गावातील, हेमाडपंथी, मंदिरे, कोळगावचा, सय्यदबाबा दर्गा, विसापूरचा, तलाव, शेख महंमद महाराजांची, समाधी, शिंदेकालिन, वाडे, ढोरजे येथील, काशीविश्वेश्वर मंदिर, मांडवगणचे, सिद्धेश्वर मंदिर, व , मांडव्यऋषींची, समाधी, कोसेगव्हाणचा, महादेवदरा, दैवदैठणचे, निंबराज समाधी मंदिर'

# %%
for i in range(len(q3_txt)):
  ''.join(q3_txt[i])
  q3_txt[i] = q3_txt[i].split(',')

# %%
# ground_truth

# %%
ground_truth = []
for i in range(len(q3_txt)):
  ground_truth.append(q3_txt[i])

# %%
test_sent = []
for i in range(len(q3_txt)):
  test_sent.append(''.join(q3_txt[i]))

# %%
new_tokens=[]

# %%
for tests in test_sent:
    tokens = tests.split()
    new_tokens.append(tokens)

# %%
new_tokens[0][1]
# Out:
# 'गावातील'

# %%
corrected_new_tokens = []

# %%
for i in range(len(new_tokens)):
  corrected_new_tokens.append([])
  for j in range(len(new_tokens[i])):
    corrected_new_tokens[i].append([])

# %%
for k in range(len(new_tokens)):
  for l in range(len(new_tokens[k])):
    for i in range(len(new_tokens[k][l])-1):
        # print(i)
        if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            if (new_tokens[k][l][i]!='अ' or new_tokens[k][l][i+1]!='ं'):
                corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            else:
                corrected_new_tokens[k][l].append('अं')
        elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            if ((ord(new_tokens[k][l][i+1])<2366 or ord(new_tokens[k][l][i+1])>=2382) and new_tokens[k][l][i+1] !='ं'):
                corrected_new_tokens[k][l].append('अ')
        elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
        elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309) and new_tokens[k][l][i-1] != 'अ'):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

    i = len(new_tokens[k][l])-1
    if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
    elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
        corrected_new_tokens[k][l].append(new_tokens[k][l][i])
        corrected_new_tokens[k][l].append('अ')
    elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
    elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309)):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

# %%
for i in range(len(corrected_new_tokens)):
    corrected_new_tokens[i] = [sublist for sublist in corrected_new_tokens[i] if sublist]

# %%
for i in range(len(corrected_new_tokens)):
  for j in range(len(corrected_new_tokens[i])):
    corrected_new_tokens[i][j] = ''.join(corrected_new_tokens[i][j])
  # if i%10000==0:
  #   print(i)

# %%
# corrected_new_tokens[0]

# %%
corrected_ground_truth = []

# %%
for i in range(len(ground_truth)):
  corrected_ground_truth.append([])
  for j in range(len(ground_truth[i])):
    corrected_ground_truth[i].append([])

# %%
for k in range(len(ground_truth)):
  for l in range(len(ground_truth[k])):
    for i in range(len(ground_truth[k][l])-1):
        # print(i)
        if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            if (ground_truth[k][l][i]!='अ' or ground_truth[k][l][i+1]!='ं'):
                corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            else:
                corrected_ground_truth[k][l].append('अं')
        elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            if ((ord(ground_truth[k][l][i+1])<2366 or ord(ground_truth[k][l][i+1])>=2382) and ground_truth[k][l][i+1] !='ं'):
                corrected_ground_truth[k][l].append('अ')
        elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
        elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309) and ground_truth[k][l][i-1] != 'अ'):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

    i = len(ground_truth[k][l])-1
    if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
    elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
        corrected_ground_truth[k][l].append(ground_truth[k][l][i])
        corrected_ground_truth[k][l].append('अ')
    elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
    elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309)):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

# %%
for i in range(len(corrected_ground_truth)):
    corrected_ground_truth[i] = [sublist for sublist in corrected_ground_truth[i] if sublist]

# %%
for i in range(len(corrected_ground_truth)):
  for j in range(len(corrected_ground_truth[i])):
    corrected_ground_truth[i][j] = ''.join(corrected_ground_truth[i][j])
  # if i%10000==0:
  #   print(i)

# %%
intersection = []
for i in range(len(q3_txt)):
  intersection.append(Counter(corrected_new_tokens[i]).keys() & Counter(corrected_ground_truth[i]).keys())

# %%
# intersection[1]
# Out:
# {'तयआअंनई', 'नएतयआअंचई', 'भआजअपआ', 'लअढआवए'}

# %%
len(set(corrected_new_tokens[0]))
# Out:
# 27

# %%
precision = []
recall = []
f_score = []
for i in range(len(q3_txt)):
  precision.append([])
  recall.append([])
  f_score.append([])

# %%
for i in range(len(q3_txt)):
  precision[i] = 100*len(intersection[i]) / len(set(corrected_new_tokens[i]))

  recall[i] = 100*len(intersection[i]) / len(set(corrected_ground_truth[i]))

  f_score[i] = 2 * precision[i] * recall[i] / (precision[i] + recall[i]) if precision[i] + recall[i] > 0 else 0

# %%
avg_precision = sum(precision)/len(precision)
avg_recall = sum(recall)/len(recall)
avg_f_score = sum(f_score)/len(f_score)

# %%
avg_precision,avg_recall,avg_f_score
# Out:
# (36.98399530752472, 52.131356537750406, 42.983029747360135)

# %%
# 'क्'+  'ू'

# %%
with open('/content/gdrive/MyDrive/cs689/a1/whitespace/q5_whitespace.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('avg_precision : avg_recall : avg_f_score\n')
    f3.write('%s : %s : %s\n' % (avg_precision, avg_recall, avg_f_score))
    f3.write('precision_per_sentence : recall_per_sentence : f_score_per_sentence\n')
    for i in range(len(q3_txt)):
        f3.write('%s : %s : %s\n' % (precision[i], recall[i], f_score[i]))
