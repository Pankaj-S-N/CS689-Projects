# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from collections import Counter
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('ai4bharat/indic-bert',lang='mr')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/5.65M [00:00<?, ?B/s]

# %%
import re

# %%
z = open('/content/gdrive/MyDrive/cs689/a1/q3.txt','r',encoding='utf-8',errors='ignore')
q3_txt = z.read()
z.close()

# %%
q3_txt = re.sub(r"[^\u0900-\u094F\s,\u0966-\u096F1234567890]", "", q3_txt)

# %%
q3_txt = q3_txt.split('\n')

# %%
q3_txt[5]
# Out:
# 'त्यामुळे, पश्चिम रेल्वेवरील, लोकसेवा, १० ते १५ मिनिटं, उशिराने, धावतील'

# %%
for i in range(len(q3_txt)):
  ''.join(q3_txt[i])
  q3_txt[i] = q3_txt[i].split(',')

# %%
# ground_truth

# %%
ground_truth = []
for i in range(len(q3_txt)):
  ground_truth.append(q3_txt[i])

# %%
test_sent = []
for i in range(len(q3_txt)):
  test_sent.append(''.join(q3_txt[i]))

# %%
new_tokens=[]

# %%
for tests in test_sent:
    tokens = tokenizer.tokenize(tests)
    new_tokens.append(tokens)

# %%
new_tokens[0][1]
# Out:
# 'गद'

# %%
corrected_new_tokens = []

# %%
for i in range(len(new_tokens)):
  corrected_new_tokens.append([])
  for j in range(len(new_tokens[i])):
    corrected_new_tokens[i].append([])

# %%
for k in range(len(new_tokens)):
  for l in range(len(new_tokens[k])):
    for i in range(len(new_tokens[k][l])-1):
        # print(i)
        if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            if (new_tokens[k][l][i]!='अ' or new_tokens[k][l][i+1]!='ं'):
                corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            else:
                corrected_new_tokens[k][l].append('अं')
        elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
            if ((ord(new_tokens[k][l][i+1])<2366 or ord(new_tokens[k][l][i+1])>=2382) and new_tokens[k][l][i+1] !='ं'):
                corrected_new_tokens[k][l].append('अ')
        elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
        elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309) and new_tokens[k][l][i-1] != 'अ'):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

    i = len(new_tokens[k][l])-1
    if (ord(new_tokens[k][l][i])>=2309 and ord(new_tokens[k][l][i])<=2324):
            corrected_new_tokens[k][l].append(new_tokens[k][l][i])
    elif (ord(new_tokens[k][l][i])>=2325 and ord(new_tokens[k][l][i])<=2361):
        corrected_new_tokens[k][l].append(new_tokens[k][l][i])
        corrected_new_tokens[k][l].append('अ')
    elif ((ord(new_tokens[k][l][i])>=2366 and ord(new_tokens[k][l][i])<2381)):
            corrected_new_tokens[k][l].append(chr(ord(new_tokens[k][l][i])-56))
    elif ((ord(new_tokens[k][l][i])>=2305 and ord(new_tokens[k][l][i])<2309)):
            corrected_new_tokens[k][l].append('अ'+new_tokens[k][l][i])

# %%
for i in range(len(corrected_new_tokens)):
    corrected_new_tokens[i] = [sublist for sublist in corrected_new_tokens[i] if sublist]

# %%
for i in range(len(corrected_new_tokens)):
  for j in range(len(corrected_new_tokens[i])):
    corrected_new_tokens[i][j] = ''.join(corrected_new_tokens[i][j])
  # if i%10000==0:
  #   print(i)

# %%
# corrected_new_tokens[0]

# %%
corrected_ground_truth = []

# %%
for i in range(len(ground_truth)):
  corrected_ground_truth.append([])
  for j in range(len(ground_truth[i])):
    corrected_ground_truth[i].append([])

# %%
for k in range(len(ground_truth)):
  for l in range(len(ground_truth[k])):
    for i in range(len(ground_truth[k][l])-1):
        # print(i)
        if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            if (ground_truth[k][l][i]!='अ' or ground_truth[k][l][i+1]!='ं'):
                corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            else:
                corrected_ground_truth[k][l].append('अं')
        elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
            if ((ord(ground_truth[k][l][i+1])<2366 or ord(ground_truth[k][l][i+1])>=2382) and ground_truth[k][l][i+1] !='ं'):
                corrected_ground_truth[k][l].append('अ')
        elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
        elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309) and ground_truth[k][l][i-1] != 'अ'):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

    i = len(ground_truth[k][l])-1
    if (ord(ground_truth[k][l][i])>=2309 and ord(ground_truth[k][l][i])<=2324):
            corrected_ground_truth[k][l].append(ground_truth[k][l][i])
    elif (ord(ground_truth[k][l][i])>=2325 and ord(ground_truth[k][l][i])<=2361):
        corrected_ground_truth[k][l].append(ground_truth[k][l][i])
        corrected_ground_truth[k][l].append('अ')
    elif ((ord(ground_truth[k][l][i])>=2366 and ord(ground_truth[k][l][i])<2381)):
            corrected_ground_truth[k][l].append(chr(ord(ground_truth[k][l][i])-56))
    elif ((ord(ground_truth[k][l][i])>=2305 and ord(ground_truth[k][l][i])<2309)):
            corrected_ground_truth[k][l].append('अ'+ground_truth[k][l][i])

# %%
for i in range(len(corrected_ground_truth)):
    corrected_ground_truth[i] = [sublist for sublist in corrected_ground_truth[i] if sublist]

# %%
for i in range(len(corrected_ground_truth)):
  for j in range(len(corrected_ground_truth[i])):
    corrected_ground_truth[i][j] = ''.join(corrected_ground_truth[i][j])
  # if i%10000==0:
  #   print(i)

# %%
intersection = []
for i in range(len(q3_txt)):
  intersection.append(Counter(corrected_new_tokens[i]).keys() & Counter(corrected_ground_truth[i]).keys())

# %%
intersection[1]
# Out:
# set()

# %%
len(set(corrected_new_tokens[0]))
# Out:
# 50

# %%
precision = []
recall = []
f_score = []
for i in range(len(q3_txt)):
  precision.append([])
  recall.append([])
  f_score.append([])

# %%
for i in range(len(q3_txt)):
  precision[i] = 100*len(intersection[i]) / len(set(corrected_new_tokens[i]))

  recall[i] = 100*len(intersection[i]) / len(set(corrected_ground_truth[i]))

  f_score[i] = 2 * precision[i] * recall[i] / (precision[i] + recall[i]) if precision[i] + recall[i] > 0 else 0

# %%
avg_precision = sum(precision)/len(precision)
avg_recall = sum(recall)/len(recall)
avg_f_score = sum(f_score)/len(f_score)

# %%
avg_precision,avg_recall,avg_f_score
# Out:
# (0.6784848484848485, 1.515151515151515, 0.9315998696643857)

# %%
# 'क्'+  'ू'

# %%
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/q5_indicbert.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('avg_precision : avg_recall : avg_f_score\n')
    f3.write('%s : %s : %s\n' % (avg_precision, avg_recall, avg_f_score))
    f3.write('precision_per_sentence : recall_per_sentence : f_score_per_sentence\n')
    for i in range(len(q3_txt)):
        f3.write('%s : %s : %s\n' % (precision[i], recall[i], f_score[i]))

# %%
filepath = '/content/gdrive/MyDrive/cs689/a1/pped_txt.txt'

# %%
z = open(filepath,'r',encoding='utf-8',errors='ignore')
marathi_corpus = z.read()
z.close()
marathi_corpus = marathi_corpus.split('\n')

max_length = 1000

tokenized_marathi_corpus = []
for text in marathi_corpus:
    tokens = tokenizer.tokenize(text)
    tokens = tokens[:max_length]
    tokenized_marathi_corpus.append(tokens)
flat_tokenized_marathi_corpus = [token for sublist in tokenized_marathi_corpus for token in sublist]

token_unigram_frequencies = Counter(flat_tokenized_marathi_corpus)

bi_grams = [(flat_tokenized_marathi_corpus[i], flat_tokenized_marathi_corpus[i + 1]) for i in range(len(flat_tokenized_marathi_corpus) - 1)]

bi_gram_frequencies = Counter(bi_grams)

# %%
type(flat_tokenized_marathi_corpus[1])

# %%
flat_tokenized_marathi_corpus[-100:]
# Out:
# ['▁त',
#  'वह',
#  '▁अश',
#  '▁प',
#  'य',
#  '▁तय',
#  'र',
#  '▁करण',
#  'य',
#  'च',
#  '▁वळ',
#  '▁आल',
#  '▁आह',
#  '▁य',
#  '▁च',
#  'तन',
#  'न',
#  '▁गर',
#  'सल',
#  '▁जत',
#  '▁वर',
#  'टच',
#  'य',
#  '▁गर',
#  'हजर',
#  'त',
#  '▁रह',
#  'त',
#  'वर',
#  '▁मठ',
#  '▁जब',
#  'ब',
#  'दर',
#  '▁मस',
#  'सल',
#  '▁शक',
#  'ष',
#  '▁मत',
#  'र',
#  '▁तर',
#  'ग',
#  'वस',
#  '▁ट',
#  'ळ',
#  '▁शकत',
#  '▁न',
#  'तर',
#  '▁तय',
#  'च',
#  '▁र',
#  'वन',
#  'ग',
#  '▁पल',
#  'स',
#  '▁कठ',
#  'डत',
#  '▁करण',
#  'यत',
#  '▁आल',
#  '▁गव',
#  '▁श',
#  'प',
#  'यर',
#  'डत',
#  'रफ',
#  '▁य',
#  'ग',
#  '▁',
#  'दन',
#  '▁सज',
#  'र',
#  '▁एक',
#  'दव',
#  'स',
#  '▁जय',
#  '▁मल',
#  'च',
#  '▁उपस',
#  'थ',
#  'त',
#  '▁कम',
#  '▁आह',
#  '▁तय',
#  'च',
#  'य',
#  '▁पलक',
#  'न',
#  '▁बल',
#  'वल',
#  '▁अल',
#  'प',
#  'वय',
#  'न',
#  '▁मग',
#  '▁श',
#  'फर',
#  'स',
#  '▁कल',
#  'ल',
#  '▁']

# %%
marathi_corpus[:2]
# Out:
# ['स्वप्न दाखविणे आणि आश्वासने देणारे नेतेही लोकांना खूप आवडतात',
#  'मुलांसोबतच पालकांना सांभाळण्याची जबाबदारी ही विवाहीत महिलांचीही आहे   केवळ विवाह झालाय म्हणून वृद्ध पालकांची जबाबदारी त्यांना झटकता येणार नाही असं हायकोर्टानं म्हटलंय']

# %%
tokenized_marathi_corpus[:10]
# Out:
# [['▁सव',
#   'पन',
#   '▁द',
#   'ख',
#   'वण',
#   '▁आण',
#   '▁आश',
#   'व',
#   'सन',
#   '▁दण',
#   'र',
#   '▁नत',
#   'ह',
#   '▁लक',
#   'न',
#   '▁खप',
#   '▁आवडत',
#   'त'],
#  ['▁मल',
#   'सब',
#   'तच',
#   '▁पलक',
#   'न',
#   '▁सभ',
#   'ळ',
#   'ण',
#   'य',
#   'च',
#   '▁जब',
#   'ब',
#   'दर',
#   '▁ह',
#   '▁व',
#   'वह',
#   'त',
#   '▁महल',
#   'च',
#   'ह',
#   '▁आह',
#   '▁कव',
#   'ळ',
#   '▁व',
#   'वह',
#   '▁झ',
#   'लय',
#   '▁मह',
#   'ण',
#   'न',
#   '▁व',
#   'द',
#   'ध',
#   '▁पलक',
#   'च',
#   '▁जब',
#   'ब',
#   'दर',
#   '▁तय',
#   'न',
#   '▁झटक',
#   'त',
#   '▁य',
#   'ण',
#   'र',
#   '▁न',
#   'ह',
#   '▁अस',
#   '▁ह',
#   'य',
#   'कर',
#   'टन',
#   '▁मह',
#   'टल',
#   'य'],
#  ['▁पह',
#   '▁क',
#   'य',
#   '▁बर',
#   'ळ',
#   'ल',
#   '▁पकड',
#   'य',
#   'च',
#   '▁पत',
#   'पर',
#   'धन',
#   '▁इमर',
#   'न',
#   '▁',
#   'खन'],
#  ['▁प',
#   'सब',
#   '▁म',
#   'वळ',
#   'म',
#   'ध',
#   'य',
#   '▁पवन',
#   '▁जल',
#   'वहन',
#   'वर',
#   'ध',
#   'त',
#   '▁आद',
#   'लन',
#   '▁करण',
#   'र',
#   'य',
#   '▁आद',
#   'लक',
#   '▁शतक',
#   'र',
#   'य',
#   'वर',
#   '▁गळ',
#   'बर',
#   '▁करण',
#   'य',
#   'च',
#   '▁आ',
#   'दश',
#   '▁म',
#   '▁दल',
#   'य',
#   'च',
#   '▁पत',
#   'पर',
#   'धन',
#   '▁नर',
#   'दर',
#   '▁मद',
#   'च',
#   '▁आर',
#   'प',
#   '▁चक',
#   'च',
#   '▁आह'],
#  ['▁व',
#   'षभ',
#   '▁क',
#   'ष',
#   'ल',
#   'लक',
#   '▁करण',
#   'न',
#   '▁तम',
#   'ह',
#   '▁अस',
#   'वस',
#   'थ',
#   '▁वह',
#   'ल'],
#  ['▁त',
#   '▁',
#   'कत',
#   '▁बद',
#   'दल',
#   '▁आम',
#   'ह',
#   '▁न',
#   'तर',
#   '▁त',
#   'महल',
#   '▁स',
#   'गत'],
#  ['▁',
#   'मख',
#   'य',
#   '▁पन',
#   '▁चल',
#   '▁घड',
#   'म',
#   'ड',
#   '▁शतक',
#   'र',
#   'यन',
#   '▁कर',
#   'जम',
#   'फ',
#   '▁कव',
#   '▁भर',
#   'प',
#   'ई'],
#  ['▁मल',
#   'म',
#   'ध',
#   'य',
#   '▁भद',
#   'भव',
#   '▁पलक',
#   'न',
#   '▁कर',
#   '▁न',
#   'य',
#   '▁मठ',
#   'ई',
#   '▁आण',
#   'ल',
#   '▁असल',
#   '▁तर',
#   '▁सर',
#   'वन',
#   '▁द',
#   'य',
#   'व',
#   '▁फ',
#   'कत',
#   '▁एकच',
#   '▁मल',
#   'ल',
#   'मल',
#   'ल',
#   '▁आण',
#   '▁इतर',
#   'न',
#   '▁न',
#   'ह',
#   '▁अस',
#   '▁न',
#   'क'],
#  ['▁रज',
#   'यत',
#   'ल',
#   '▁सर',
#   'कर',
#   '▁आण',
#   '▁',
#   'मख',
#   'यम',
#   'तर',
#   '▁च',
#   'गल',
#   '▁कम',
#   '▁करत',
#   '▁आहत'],
#  ['▁च',
#   'त',
#   'रपट',
#   'तल',
#   '▁गण',
#   '▁रम',
#   'क',
#   '▁जर',
#   '▁असल',
#   '▁तर',
#   '▁तय',
#   'त',
#   '▁बल',
#   'वड',
#   '▁सट',
#   'ईल',
#   '▁व',
#   'पर',
#   'ल',
#   '▁असल',
#   'यन',
#   '▁पर',
#   'क',
#   'षक',
#   'न',
#   '▁त',
#   '▁फर',
#   '▁आवडत',
#   '▁आह']]

# %%
tokenized_marathi_corpus[:10]

# %%
len(flat_tokenized_marathi_corpus)

# %%
corrected_tokenized_corpus = []

# %%
for i in range(len(flat_tokenized_marathi_corpus)):
  corrected_tokenized_corpus.append([])

# %%
j=0
while j < len(flat_tokenized_marathi_corpus):
  for i in range(len(flat_tokenized_marathi_corpus[j])-1):
      # print(i)
      if (ord(flat_tokenized_marathi_corpus[j][i])>=2309 and ord(flat_tokenized_marathi_corpus[j][i])<=2324):
          if (flat_tokenized_marathi_corpus[j][i]!='अ' or flat_tokenized_marathi_corpus[j][i+1]!='ं'):
              corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
          else:
              corrected_tokenized_corpus[j].append('अं')
      elif (ord(flat_tokenized_marathi_corpus[j][i])>=2325 and ord(flat_tokenized_marathi_corpus[j][i])<=2361):
          corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
          if ((ord(flat_tokenized_marathi_corpus[j][i+1])<2366 or ord(flat_tokenized_marathi_corpus[j][i+1])>=2382) and flat_tokenized_marathi_corpus[j][i+1] !='ं'):
              corrected_tokenized_corpus[j].append('अ')
      elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2366 and ord(flat_tokenized_marathi_corpus[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(flat_tokenized_marathi_corpus[j][i])-56))
      elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2305 and ord(flat_tokenized_marathi_corpus[j][i])<2309) and flat_tokenized_marathi_corpus[j][i-1] != 'अ'):
          corrected_tokenized_corpus[j].append('अ'+flat_tokenized_marathi_corpus[j][i])
      # elif flat_tokenized_marathi_corpus[j][i] == '#':
      #     corrected_tokenized_corpus[j].append('#')
  i = len(flat_tokenized_marathi_corpus[j])-1
  if (ord(flat_tokenized_marathi_corpus[j][i])>=2309 and ord(flat_tokenized_marathi_corpus[j][i])<=2324):
          corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
  elif (ord(flat_tokenized_marathi_corpus[j][i])>=2325 and ord(flat_tokenized_marathi_corpus[j][i])<=2361):
      corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
      corrected_tokenized_corpus[j].append('अ')
  elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2366 and ord(flat_tokenized_marathi_corpus[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(flat_tokenized_marathi_corpus[j][i])-56))
  elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2305 and ord(flat_tokenized_marathi_corpus[j][i])<2309)):
          corrected_tokenized_corpus[j].append('अ'+flat_tokenized_marathi_corpus[j][i])
  # elif flat_tokenized_marathi_corpus[j][i] == '#':
  #         corrected_tokenized_corpus[j].append('#')

  if j%10000==0:
    print(j)
  j+=1
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# 1460000
# 1470000
# 1480000
# 1490000
# 1500000
# 1510000
# 1520000
# 1530000
# 1540000
# 1550000
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# 1610000
# 1620000
# 1630000
# 1640000
# 1650000
# 1660000
# 1670000
# 1680000
# 1690000
# 1700000
# 1710000
# 1720000
# 1730000
# 1740000
# 1750000
# 1760000
# 1770000
# 1780000
# 1790000
# 1800000
# 1810000
# 1820000
# 1830000
# 1840000
# 1850000
# 1860000
# 1870000
# 1880000
# 1890000
# 1900000
# 1910000
# 1920000
# 1930000
# 1940000
# 1950000
# 1960000
# 1970000
# 1980000
# 1990000
# 2000000
# 2010000
# 2020000
# 2030000
# 2040000
# 2050000
# 2060000
# 2070000
# 2080000
# 2090000
# 2100000
# 2110000
# 2120000
# 2130000
# 2140000
# 2150000
# 2160000
# 2170000
# 2180000
# 2190000
# 2200000
# 2210000
# 2220000
# 2230000
# 2240000
# 2250000
# 2260000
# 2270000
# 2280000
# 2290000
# 2300000
# 2310000
# 2320000
# 2330000
# 2340000
# 2350000
# 2360000
# 2370000
# 2380000
# 2390000
# 2400000
# 2410000
# 2420000
# 2430000
# 2440000
# 2450000
# 2460000
# 2470000
# 2480000
# 2490000
# 2500000
# 2510000
# 2520000
# 2530000
# 2540000
# 2550000
# 2560000
# 2570000
# 2580000
# 2590000
# 2600000
# 2610000
# 2620000
# 2630000
# 2640000
# 2650000
# 2660000
# 2670000
# 2680000
# 2690000
# 2700000
# 2710000
# 2720000
# 2730000
# 2740000
# 2750000
# 2760000
# 2770000
# 2780000
# 2790000
# 2800000
# 2810000
# 2820000
# 2830000
# 2840000
# 2850000
# 2860000
# 2870000
# 2880000
# 2890000
# 2900000
# 2910000
# 2920000
# 2930000
# 2940000
# 2950000
# 2960000
# 2970000
# 2980000
# 2990000
# 3000000
# 3010000
# 3020000
# 3030000
# 3040000
# 3050000
# 3060000
# 3070000
# 3080000
# 3090000
# 3100000
# 3110000
# 3120000
# 3130000
# 3140000
# 3150000
# 3160000
# 3170000
# 3180000
# 3190000
# 3200000
# 3210000
# 3220000
# 3230000
# 3240000
# 3250000
# 3260000
# 3270000
# 3280000
# 3290000
# 3300000
# 3310000
# 3320000
# 3330000
# 3340000
# 3350000
# 3360000
# 3370000
# 3380000
# 3390000
# 3400000
# 3410000
# 3420000
# 3430000
# 3440000
# 3450000
# 3460000
# 3470000
# 3480000
# 3490000
# 3500000
# 3510000
# 3520000
# 3530000
# 3540000
# 3550000
# 3560000
# 3570000
# 3580000
# 3590000
# 3600000
# 3610000
# 3620000
# 3630000
# 3640000
# 3650000
# 3660000
# 3670000
# 3680000
# 3690000
# 3700000
# 3710000
# 3720000
# 3730000
# 3740000
# 3750000
# 3760000
# 3770000
# 3780000
# 3790000
# 3800000
# 3810000
# 3820000
# 3830000
# 3840000
# 3850000
# 3860000
# 3870000
# 3880000
# 3890000
# 3900000
# 3910000
# 3920000
# 3930000
# 3940000
# 3950000
# 3960000
# 3970000
# 3980000
# 3990000
# 4000000
# 4010000
# 4020000
# 4030000
# 4040000
# 4050000
# 4060000
# 4070000
# 4080000
# 4090000
# 4100000
# 4110000
# 4120000
# 4130000
# 4140000
# 4150000
# 4160000
# 4170000
# 4180000
# 4190000
# 4200000
# 4210000
# 4220000
# 4230000
# 4240000
# 4250000
# 4260000
# 4270000
# 4280000
# 4290000
# 4300000
# 4310000
# 4320000
# 4330000
# 4340000
# 4350000
# 4360000
# 4370000
# 4380000
# 4390000
# 4400000
# 4410000
# 4420000
# 4430000
# 4440000
# 4450000
# 4460000
# 4470000
# 4480000
# 4490000
# 4500000
# 4510000
# 4520000
# 4530000
# 4540000
# 4550000
# 4560000
# 4570000
# 4580000
# 4590000
# 4600000
# 4610000
# 4620000
# 4630000
# 4640000
# 4650000
# 4660000
# 4670000
# 4680000
# 4690000
# 4700000
# 4710000
# 4720000
# 4730000
# 4740000
# 4750000
# 4760000
# 4770000
# 4780000
# 4790000
# 4800000
# 4810000
# 4820000
# 4830000
# 4840000
# 4850000
# 4860000
# 4870000
# 4880000
# 4890000
# 4900000
# 4910000
# 4920000
# 4930000
# 4940000
# 4950000
# 4960000
# 4970000
# 4980000
# 4990000
# 5000000
# 5010000
# 5020000
# 5030000
# 5040000
# 5050000
# 5060000
# 5070000
# 5080000
# 5090000
# 5100000
# 5110000
# 5120000
# 5130000
# 5140000
# 5150000
# 5160000
# 5170000
# 5180000
# 5190000
# 5200000
# 5210000
# 5220000
# 5230000
# 5240000
# 5250000
# 5260000
# 5270000
# 5280000
# 5290000
# 5300000
# 5310000
# 5320000
# 5330000
# 5340000
# 5350000
# 5360000
# 5370000
# 5380000
# 5390000
# 5400000
# 5410000
# 5420000
# 5430000
# 5440000
# 5450000
# 5460000
# 5470000
# 5480000
# 5490000
# 5500000
# 5510000
# 5520000
# 5530000
# 5540000
# 5550000
# 5560000
# 5570000
# 5580000
# 5590000
# 5600000
# 5610000
# 5620000
# 5630000
# 5640000
# 5650000
# 5660000
# 5670000
# 5680000
# 5690000
# 5700000
# 5710000
# 5720000
# 5730000
# 5740000
# 5750000
# 5760000
# 5770000
# 5780000
# 5790000
# 5800000
# 5810000
# 5820000
# 5830000
# 5840000
# 5850000
# 5860000
# 5870000
# 5880000
# 5890000
# 5900000
# 5910000
# 5920000
# 5930000
# 5940000
# 5950000
# 5960000
# 5970000
# 5980000
# 5990000
# 6000000
# 6010000
# 6020000
# 6030000
# 6040000
# 6050000
# 6060000
# 6070000
# 6080000
# 6090000
# 6100000
# 6110000
# 6120000
# 6130000
# 6140000
# 6150000
# 6160000
# 6170000
# 6180000
# 6190000
# 6200000
# 6210000
# 6220000
# 6230000
# 6240000
# 6250000
# 6260000
# 6270000
# 6280000
# 6290000
# 6300000
# 6310000
# 6320000
# 6330000
# 6340000
# 6350000
# 6360000
# 6370000
# 6380000
# 6390000
# 6400000
# 6410000
# 6420000
# 6430000
# 6440000
# 6450000
# 6460000
# 6470000
# 6480000
# 6490000
# 6500000
# 6510000
# 6520000
# 6530000
# 6540000
# 6550000
# 6560000
# 6570000
# 6580000
# 6590000
# 6600000
# 6610000
# 6620000
# 6630000
# 6640000
# 6650000
# 6660000
# 6670000
# 6680000
# 6690000
# 6700000
# 6710000
# 6720000
# 6730000
# 6740000
# 6750000
# 6760000
# 6770000
# 6780000
# 6790000
# 6800000
# 6810000
# 6820000
# 6830000
# 6840000
# 6850000
# 6860000
# 6870000
# 6880000
# 6890000
# 6900000
# 6910000
# 6920000
# 6930000
# 6940000
# 6950000
# 6960000
# 6970000
# 6980000
# 6990000
# 7000000
# 7010000
# 7020000
# 7030000
# 7040000
# 7050000
# 7060000
# 7070000
# 7080000
# 7090000
# 7100000
# 7110000
# 7120000
# 7130000
# 7140000
# 7150000
# 7160000
# 7170000
# 7180000
# 7190000
# 7200000
# 7210000
# 7220000
# 7230000
# 7240000
# 7250000
# 7260000
# 7270000
# 7280000
# 7290000
# 7300000
# 7310000
# 7320000
# 7330000
# 7340000
# 7350000
# 7360000
# 7370000
# 7380000
# 7390000
# 7400000
# 7410000
# 7420000
# 7430000
# 7440000
# 7450000
# 7460000
# 7470000
# 7480000
# 7490000
# 7500000
# 7510000
# 7520000
# 7530000
# 7540000
# 7550000
# 7560000
# 7570000
# 7580000
# 7590000
# 7600000
# 7610000
# 7620000
# 7630000
# 7640000
# 7650000
# 7660000
# 7670000
# 7680000
# 7690000
# 7700000
# 7710000
# 7720000
# 7730000
# 7740000
# 7750000
# 7760000
# 7770000
# 7780000
# 7790000
# 7800000
# 7810000
# 7820000
# 7830000
# 7840000
# 7850000
# 7860000
# 7870000
# 7880000
# 7890000
# 7900000
# 7910000
# 7920000
# 7930000
# 7940000
# 7950000
# 7960000
# 7970000
# 7980000
# 7990000
# 8000000
# 8010000
# 8020000
# 8030000
# 8040000
# 8050000
# 8060000
# 8070000
# 8080000
# 8090000
# 8100000
# 8110000
# 8120000
# 8130000
# 8140000
# 8150000
# 8160000
# 8170000
# 8180000
# 8190000
# 8200000
# 8210000
# 8220000
# 8230000
# 8240000
# 8250000
# 8260000
# 8270000
# 8280000
# 8290000
# 8300000
# 8310000
# 8320000
# 8330000
# 8340000
# 8350000
# 8360000
# 8370000
# 8380000
# 8390000
# 8400000
# 8410000
# 8420000
# 8430000
# 8440000
# 8450000
# 8460000
# 8470000
# 8480000
# 8490000
# 8500000
# 8510000
# 8520000
# 8530000
# 8540000
# 8550000
# 8560000
# 8570000
# 8580000
# 8590000
# 8600000
# 8610000
# 8620000
# 8630000
# 8640000
# 8650000
# 8660000
# 8670000
# 8680000
# 8690000
# 8700000
# 8710000
# 8720000
# 8730000
# 8740000
# 8750000
# 8760000
# 8770000
# 8780000
# 8790000
# 8800000
# 8810000
# 8820000
# 8830000
# 8840000
# 8850000
# 8860000
# 8870000
# 8880000
# 8890000
# 8900000
# 8910000
# 8920000
# 8930000
# 8940000
# 8950000
# 8960000
# 8970000
# 8980000
# 8990000
# 9000000
# 9010000
# 9020000
# 9030000
# 9040000
# 9050000
# 9060000
# 9070000
# 9080000
# 9090000
# 9100000
# 9110000
# 9120000
# 9130000
# 9140000
# 9150000
# 9160000
# 9170000
# 9180000
# 9190000
# 9200000
# 9210000
# 9220000
# 9230000
# 9240000
# 9250000
# 9260000
# 9270000
# 9280000
# 9290000
# 9300000
# 9310000
# 9320000
# 9330000
# 9340000
# 9350000
# 9360000
# 9370000
# 9380000
# 9390000
# 9400000
# 9410000
# 9420000
# 9430000
# 9440000
# 9450000
# 9460000
# 9470000
# 9480000
# 9490000
# 9500000
# 9510000
# 9520000
# 9530000
# 9540000
# 9550000
# 9560000
# 9570000
# 9580000
# 9590000
# 9600000
# 9610000
# 9620000
# 9630000
# 9640000
# 9650000
# 9660000
# 9670000
# 9680000
# 9690000
# 9700000
# 9710000
# 9720000
# 9730000
# 9740000
# 9750000
# 9760000
# 9770000
# 9780000
# 9790000
# 9800000
# 9810000
# 9820000
# 9830000
# 9840000
# 9850000
# 9860000
# 9870000
# 9880000
# 9890000
# 9900000
# 9910000
# 9920000
# 9930000
# 9940000
# 9950000
# 9960000
# 9970000
# 9980000
# 9990000
# 10000000
# 10010000
# 10020000
# 10030000
# 10040000
# 10050000
# 10060000
# 10070000
# 10080000
# 10090000
# 10100000
# 10110000
# 10120000
# 10130000
# 10140000
# 10150000
# 10160000
# 10170000
# 10180000
# 10190000
# 10200000
# 10210000
# 10220000
# 10230000
# 10240000
# 10250000
# 10260000
# 10270000
# 10280000
# 10290000
# 10300000
# 10310000
# 10320000
# 10330000
# 10340000
# 10350000
# 10360000
# 10370000
# 10380000
# 10390000
# 10400000
# 10410000
# 10420000
# 10430000
# 10440000
# 10450000
# 10460000
# 10470000
# 10480000
# 10490000
# 10500000
# 10510000
# 10520000
# 10530000
# 10540000
# 10550000
# 10560000
# 10570000
# 10580000
# 10590000
# 10600000
# 10610000
# 10620000
# 10630000
# 10640000
# 10650000
# 10660000
# 10670000
# 10680000
# 10690000
# 10700000
# 10710000
# 10720000
# 10730000
# 10740000
# 10750000
# 10760000
# 10770000
# 10780000
# 10790000
# 10800000
# 10810000
# 10820000
# 10830000
# 10840000
# 10850000
# 10860000
# 10870000
# 10880000
# 10890000
# 10900000
# 10910000
# 10920000
# 10930000
# 10940000
# 10950000
# 10960000
# 10970000
# 10980000
# 10990000
# 11000000
# 11010000
# 11020000
# 11030000
# 11040000
# 11050000
# 11060000
# 11070000
# 11080000
# 11090000
# 11100000
# 11110000
# 11120000
# 11130000
# 11140000
# 11150000
# 11160000
# 11170000
# 11180000
# 11190000
# 11200000
# 11210000
# 11220000
# 11230000
# 11240000
# 11250000
# 11260000
# 11270000
# 11280000
# 11290000
# 11300000
# 11310000
# 11320000
# 11330000
# 11340000
# 11350000
# 11360000
# 11370000
# 11380000
# 11390000
# 11400000
# 11410000
# 11420000
# 11430000
# 11440000
# 11450000
# 11460000
# 11470000
# 11480000
# 11490000
# 11500000
# 11510000
# 11520000
# 11530000
# 11540000
# 11550000
# 11560000
# 11570000
# 11580000
# 11590000
# 11600000
# 11610000
# 11620000
# 11630000
# 11640000
# 11650000
# 11660000
# 11670000
# 11680000
# 11690000
# 11700000
# 11710000
# 11720000
# 11730000
# 11740000
# 11750000
# 11760000
# 11770000
# 11780000
# 11790000
# 11800000
# 11810000
# 11820000
# 11830000
# 11840000
# 11850000
# 11860000
# 11870000
# 11880000
# 11890000
# 11900000
# 11910000
# 11920000
# 11930000
# 11940000
# 11950000
# 11960000
# 11970000
# 11980000
# 11990000
# 12000000
# 12010000
# 12020000
# 12030000
# 12040000
# 12050000
# 12060000
# 12070000
# 12080000
# 12090000
# 12100000
# 12110000
# 12120000
# 12130000
# 12140000
# 12150000
# 12160000
# 12170000
# 12180000
# 12190000
# 12200000
# 12210000
# 12220000
# 12230000
# 12240000
# 12250000

# %%
corrected_tokenized_corpus = [sublist for sublist in corrected_tokenized_corpus if sublist]

# %%
for i in range(len(corrected_tokenized_corpus)):
  corrected_tokenized_corpus[i] = ''.join(corrected_tokenized_corpus[i])
  if i%10000==0:
    print(i)

# %%
corrected_uni_freq = Counter(corrected_tokenized_corpus)

bi_grams = [(corrected_tokenized_corpus[i], corrected_tokenized_corpus[i + 1]) for i in range(len(corrected_tokenized_corpus) - 1)]
corrected_bi_freq = Counter(bi_grams)

# %%
fin_dict = {k: v for k, v in sorted(corrected_uni_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi = {k: v for k, v in sorted(corrected_bi_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi
# Out:
# {('चअ', 'यअ'): 154587,
#  ('यअ', 'चअ'): 132965,
#  ('नअ', 'हअ'): 42596,
#  ('तअयअ', 'चअ'): 38425,
#  ('धअ', 'यअ'): 35568,
#  ('मअहअ', 'णअ'): 32159,
#  ('तअ', 'तअ'): 29001,
#  ('यअ', 'पअरअ'): 27651,
#  ('तअयअ', 'नअ'): 27468,
#  ('यअसअ', 'ठअ'): 27057,
#  ('यअ', 'वअरअ'): 24425,
#  ('रअ', 'यअ'): 23863,
#  ('नअ', 'यअ'): 22879,
#  ('णअ', 'रअ'): 21943,
#  ('यअतअ', 'आलअ'): 21696,
#  ('तअ', 'यअ'): 21252,
#  ('कअ', 'यअ'): 20903,
#  ('यअ', 'दअ'): 20425,
#  ('यअ', 'वअ'): 20369,
#  ('सअ', 'ठअ'): 18460,
#  ('चअ', 'पअरअ'): 18141,
#  ('मअहअ', 'तअ'): 17679,
#  ('मअतअ', 'रअ'): 17384,
#  ('तअ', 'वअ'): 17212,
#  ('कअ', 'षअ'): 16717,
#  ('कअरअ', 'यअ'): 16260,
#  ('यअ', 'यअ'): 16220,
#  ('षअ', 'टअ'): 16209,
#  ('कअरअणअ', 'यअतअ'): 16183,
#  ('षअ', 'टअरअ'): 15992,
#  ('चअ', 'तअ'): 15928,
#  ('रअ', 'षअ'): 15878,
#  ('मअ', 'धअ'): 15790,
#  ('वअरअ', 'षअ'): 15674,
#  ('णअ', 'नअ'): 14375,
#  ('पअरअ', 'यअतअ'): 13919,
#  ('वअ', 'चअ'): 13897,
#  ('णअ', 'यअ'): 13838,
#  ('मअ', 'बअ'): 13528,
#  ('मअधअ', 'यअ'): 13177,
#  ('तअयअ', 'मअळअ'): 13150,
#  ('घअ', 'तअलअ'): 12921,
#  ('षअ', 'तअ'): 12880,
#  ('वअ', 'दअ'): 12588,
#  ('सअ', 'थअ'): 12474,
#  ('बअ', 'ई'): 12457,
#  ('पअरअ', 'णअ'): 12336,
#  ('असअ', 'नअ'): 12273,
#  ('पअ', 'सअनअ'): 12215,
#  ('चअ', 'वअ'): 12019,
#  ('चअ', 'नअ'): 11894,
#  ('वअ', 'ढअ'): 11853,
#  ('कअलअ', 'आहअ'): 11846,
#  ('अनअ', 'कअ'): 11795,
#  ('नअ', 'तअरअ'): 11787,
#  ('लअ', 'आहअ'): 11779,
#  ('पअकअ', 'षअ'): 11682,
#  ('असअलअ', 'यअ'): 11682,
#  ('वअ', 'पअरअ'): 11635,
#  ('पअरअ', 'वअ'): 11566,
#  ('पअरअ', 'कअरअ'): 11212,
#  ('कअरअणअ', 'यअ'): 11208,
#  ('भअ', 'जअ'): 11059,
#  ('थअ', 'तअ'): 10942,
#  ('रअ', 'आहअ'): 10936,
#  ('आपअ', 'लअयअ'): 10861,
#  ('दअ', 'यअ'): 10701,
#  ('यअ', 'णअ'): 10556,
#  ('धअ', 'तअ'): 10501,
#  ('कअरअ', 'वअ'): 10326,
#  ('नअवअ', 'डअ'): 10300,
#  ('दअ', 'तअ'): 10247,
#  ('षअ', 'यअ'): 9952,
#  ('यअ', 'गअ'): 9952,
#  ('हअ', 'यअ'): 9906,
#  ('आहअ', 'तअयअ'): 9892,
#  ('तअसअ', 'चअ'): 9807,
#  ('यअ', 'कअरअ'): 9737,
#  ('पअलअ', 'सअ'): 9715,
#  ('कअरअणअ', 'यअसअ'): 9709,
#  ('नअ', 'कअ'): 9529,
#  ('पअरअ', 'यअ'): 9500,
#  ('लअयअ', 'चअ'): 9343,
#  ('नअ', 'चअ'): 9342,
#  ('कअ', 'चअ'): 9321,
#  ('यअतअ', 'लअ'): 9281,
#  ('सअ', 'चअ'): 9243,
#  ('आहअ', 'यअ'): 9196,
#  ('यअतअ', 'नअ'): 9147,
#  ('आलअ', 'आहअ'): 9065,
#  ('आपअ', 'लअ'): 8995,
#  ('तअ', 'हअ'): 8942,
#  ('तअ', 'नअ'): 8941,
#  ('चअ', 'चअ'): 8917,
#  ('लअ', 'लअ'): 8886,
#  ('यअ', 'पअ'): 8855,
#  ('यअ', 'सअ'): 8688,
#  ('तअ', 'पअरअ'): 8613,
#  ('जअलअ', 'हअ'): 8598,
#  ('यअकअ', 'षअ'): 8559,
#  ('हअ', 'पअरअ'): 8552,
#  ('यअ', 'थअ'): 8520,
#  ('गअ', 'यअ'): 8496,
#  ('लअगअ', 'लअ'): 8441,
#  ('वअयअ', 'कअतअ'): 8418,
#  ('घअ', 'तअ'): 8418,
#  ('दअ', 'वअसअ'): 8416,
#  ('यअ', 'नअ'): 8381,
#  ('कअरअणअ', 'रअ'): 8379,
#  ('कअ', 'गअरअ'): 8365,
#  ('कअलअ', 'यअ'): 8312,
#  ('वअ', 'भअ'): 8165,
#  ('सअ', 'पअरअ'): 8136,
#  ('लअकअ', 'षअ'): 8091,
#  ('कअरअ', 'चअ'): 8027,
#  ('पअ', 'चअ'): 8021,
#  ('तअ', 'आहअ'): 8007,
#  ('जअ', 'पअ'): 7877,
#  ('सअ', 'थअनअ'): 7872,
#  ('यअनअ', 'तअरअ'): 7862,
#  ('हअणअ', 'रअ'): 7839,
#  ('णअ', 'जअ'): 7833,
#  ('सअरअ', 'वअतअ'): 7804,
#  ('णअ', 'यअसअ'): 7785,
#  ('वअ', 'चअरअ'): 7634,
#  ('हअतअ', 'यअ'): 7567,
#  ('पअरअ', 'सअ'): 7513,
#  ('चअ', 'हअ'): 7510,
#  ('नअ', 'तअ'): 7490,
#  ('तअ', 'हअतअ'): 7428,
#  ('सअरअ', 'कअरअ'): 7407,
#  ('धअ', 'वअ'): 7357,
#  ('षअ', 'चअ'): 7290,
#  ('सअ', 'वअतअ'): 7216,
#  ('वअशअ', 'षअ'): 7211,
#  ('गअरअ', 'सअ'): 7197,
#  ('डअ', 'णअकअ'): 7183,
#  ('चअ', 'मअहअ'): 7183,
#  ('वअरअ', 'धअ'): 7160,
#  ('तअ', 'सअ'): 7123,
#  ('यअतअ', 'यअ'): 7064,
#  ('भअ', 'गअ'): 7057,
#  ('वअरअ', 'नअ'): 7057,
#  ('लअ', 'नअ'): 7056,
#  ('तअचअ', 'यअ'): 6972,
#  ('णअ', 'लअ'): 6932,
#  ('रअपअ', 'यअ'): 6919,
#  ('तअ', 'तअयअ'): 6888,
#  ('कअणअ', 'तअ'): 6866,
#  ('मअहअ', 'रअ'): 6858,
#  ('सअगअ', 'तअलअ'): 6848,
#  ('वअ', 'षअ'): 6824,
#  ('तअयअ', 'रअ'): 6790,
#  ('वअयअ', 'वअसअ'): 6765,
#  ('वअशअ', 'यअकअ'): 6763,
#  ('चअ', 'गअलअ'): 6748,
#  ('मअळअ', 'लअ'): 6740,
#  ('रअजअ', 'यअ'): 6734,
#  ('नअ', 'शअ'): 6687,
#  ('अधअ', 'कअ'): 6676,
#  ('पअरअतअ', 'यअकअ'): 6657,
#  ('नअ', 'तअयअ'): 6643,
#  ('यअ', 'वअळअ'): 6641,
#  ('यअ', 'बअ'): 6554,
#  ('झअलअ', 'आहअ'): 6536,
#  ('यअ', 'जअनअ'): 6531,
#  ('सअ', 'यअ'): 6503,
#  ('सअ', 'घअ'): 6484,
#  ('पअरअ', 'कअरअणअ'): 6464,
#  ('आ', 'वअशअ'): 6462,
#  ('भअ', 'तअ'): 6379,
#  ('लअ', 'यअनअ'): 6313,
#  ('चअरअ', 'चअ'): 6299,
#  ('चअ', 'सअ'): 6292,
#  ('गअ', 'वअ'): 6263,
#  ('शअवअ', 'सअनअ'): 6228,
#  ('गअलअ', 'यअ'): 6207,
#  ('तअरअ', 'तअ'): 6200,
#  ('नअ', 'रअणअ'): 6114,
#  ('अधअ', 'कअरअ'): 6114,
#  ('मअयअ', 'नअ'): 6085,
#  ('यअमअ', 'तअरअ'): 6027,
#  ('वअरअ', 'लअ'): 6027,
#  ('रअ', 'नअ'): 6025,
#  ('लअ', 'हअतअ'): 5985,
#  ('दअसअ', 'रअ'): 5975,
#  ('रअ', 'चअ'): 5924,
#  ('रअणअ', 'यअ'): 5898,
#  ('तअ', 'रअपअटअ'): 5892,
#  ('मअहअ', 'नअ'): 5883,
#  ('पअरअ', 'शअनअ'): 5873,
#  ('दअरअ', 'मअयअ'): 5855,
#  ('तअ', 'वअहअ'): 5760,
#  ('जअ', 'तअ'): 5750,
#  ('चअ', 'छअ'): 5696,
#  ('असअलअ', 'लअयअ'): 5645,
#  ('वअ', 'तअ'): 5644,
#  ('सअधअ', 'यअ'): 5638,
#  ('यअ', 'थअलअ'): 5598,
#  ('शअतअकअ', 'रअ'): 5563,
#  ('बअ', 'धअ'): 5532,
#  ('तअ', 'आणअ'): 5490,
#  ('पअ', 'यअ'): 5472,
#  ('फअ', 'कअतअ'): 5471,
#  ('तअ', 'थअ'): 5461,
#  ('रअहअ', 'लअ'): 5455,
#  ('मअरअ', 'ठअ'): 5447,
#  ('दअलअ', 'लअ'): 5432,
#  ('शअ', 'चअ'): 5429,
#  ('तअ', 'कअलअ'): 5407,
#  ('कअ', 'षअणअ'): 5389,
#  ('दअ', 'धअ'): 5386,
#  ('मअखअ', 'यअमअ'): 5377,
#  ('आमअ', 'हअ'): 5374,
#  ('कअरअ', 'यअकअ'): 5370,
#  ('नअ', 'हअतअ'): 5359,
#  ('नअ', 'कअरअ'): 5356,
#  ('बअ', 'बअतअ'): 5351,
#  ('चअ', 'तअरअ'): 5336,
#  ('पअरअ', 'शअ'): 5324,
#  ('हअ', 'चअ'): 5307,
#  ('पअरअ', 'कअ'): 5306,
#  ('यअ', 'कअलअ'): 5289,
#  ('यअ', 'मअहअ'): 5284,
#  ('पअरअ', 'मअणअ'): 5257,
#  ('दअ', 'वअरअ'): 5254,
#  ('यअ', 'यअलअ'): 5225,
#  ('तअ', 'मअहअ'): 5211,
#  ('तअयअ', 'लअ'): 5208,
#  ('चअ', 'दअरअ'): 5198,
#  ('कअलअ', 'हअतअ'): 5186,
#  ('वअ', 'वअधअ'): 5165,
#  ('सअदअ', 'धअ'): 5157,
#  ('हअतअ', 'तअयअ'): 5151,
#  ('जअ', 'चअ'): 5114,
#  ('शअ', 'कअ'): 5104,
#  ('षअ', 'ठअ'): 5089,
#  ('सअबअ', 'धअ'): 5082,
#  ('मअरअ', 'गअ'): 5068,
#  ('षअ', 'तअरअ'): 5059,
#  ('असअतअ', 'नअ'): 5052,
#  ('असअलअ', 'तअरअ'): 5023,
#  ('डअ', 'कअ'): 5018,
#  ('हअ', 'तअयअ'): 5008,
#  ('अ', 'रअथअ'): 4998,
#  ('दअ', 'खअ'): 4984,
#  ('तअरअ', 'यअ'): 4971,
#  ('यअ', 'नअवअ'): 4953,
#  ('कअ', 'कअ'): 4945,
#  ('यअमअ', 'धअ'): 4941,
#  ('वअ', 'कअसअ'): 4921,
#  ('आणअ', 'तअयअ'): 4900,
#  ('गअ', 'चअ'): 4899,
#  ('हअतअ', 'तअ'): 4898,
#  ('पअनअ', 'हअ'): 4847,
#  ('सअनअ', 'चअ'): 4825,
#  ('ऊ', 'शअकअतअ'): 4815,
#  ('झअ', 'लअयअ'): 4807,
#  ('डअ', 'चअ'): 4797,
#  ('लअ', 'हअ'): 4789,
#  ('ठअ', 'कअणअ'): 4784,
#  ('वअ', 'कअरअ'): 4775,
#  ('णअ', 'यअतअ'): 4775,
#  ('नअ', 'वअ'): 4765,
#  ('मअठअ', 'यअ'): 4762,
#  ('मअगअ', 'णअ'): 4758,
#  ('रअसअ', 'तअ'): 4745,
#  ('आहअ', 'हअ'): 4730,
#  ('दअसअ', 'तअ'): 4722,
#  ('चअ', 'आहअ'): 4715,
#  ('नअ', 'कअलअ'): 4713,
#  ('टअ', 'यअ'): 4687,
#  ('लअ', 'चअ'): 4681,
#  ('चअ', 'नअवअ'): 4678,
#  ('कअरअ', 'यअनअ'): 4675,
#  ('आहअ', 'कअ'): 4675,
#  ('वअसअ', 'थअ'): 4657,
#  ('नअवअ', 'नअ'): 4647,
#  ('चअ', 'दअ'): 4616,
#  ('लअ', 'लअयअ'): 4614,
#  ('तअलअ', 'कअ'): 4600,
#  ('तअ', 'कअरअणअ'): 4548,
#  ('यअ', 'आणअ'): 4529,
#  ('यअ', 'वअयअ'): 4514,
#  ('पअरअ', 'दअशअ'): 4513,
#  ('चअ', 'तअयअ'): 4510,
#  ('पअरअ', 'चअ'): 4493,
#  ('आहअ', 'तअ'): 4488,
#  ('यअ', 'मअळअ'): 4475,
#  ('चअ', 'कअरअ'): 4471,
#  ('लअ', 'तअ'): 4450,
#  ('जअ', 'ञअ'): 4449,
#  ('लअ', 'यअ'): 4442,
#  ('टअकअ', 'कअ'): 4437,
#  ('णअ', 'तअ'): 4425,
#  ('जअसअ', 'तअ'): 4423,
#  ('झअलअ', 'लअयअ'): 4421,
#  ('यअकअ', 'आहअ'): 4405,
#  ('सअतअ', 'रअ'): 4397,
#  ('घअ', 'ऊनअ'): 4396,
#  ('चअ', 'कअमअ'): 4387,
#  ('कअडअ', 'नअ'): 4378,
#  ('गअ', 'षअ'): 4358,
#  ('दअ', 'यअरअ'): 4349,
#  ('ठअ', 'कअरअ'): 4344,
#  ('भअरअतअ', 'यअ'): 4343,
#  ('नअ', 'सअरअ'): 4342,
#  ('बअदअ', 'दअलअ'): 4337,
#  ('रअ', 'गअणअ'): 4337,
#  ('असअतअ', 'तअ'): 4328,
#  ('पअडअ', 'लअ'): 4327,
#  ('अधअ', 'यअकअ'): 4321,
#  ('यअ', 'कअ'): 4315,
#  ('नअ', 'पअरअ'): 4291,
#  ('कअलअ', 'लअ'): 4286,
#  ('वअरअ', 'तअ'): 4281,
#  ('आरअ', 'पअ'): 4275,
#  ('मअळअ', 'तअ'): 4274,
#  ('हअ', 'ईलअ'): 4271,
#  ('पअ', 'वअरअ'): 4239,
#  ('दअ', 'षअ'): 4224,
#  ('पअणअ', 'यअ'): 4206,
#  ('जअणअ', 'रअ'): 4200,
#  ('उतअ', 'तअरअ'): 4191,
#  ('पअ', 'शअ'): 4180,
#  ('तअ', 'कअ'): 4175,
#  ('दअणअ', 'यअतअ'): 4151,
#  ('यअ', 'आहअ'): 4143,
#  ('उपअसअ', 'थअ'): 4122,
#  ('पअलअ', 'सअनअ'): 4110,
#  ('कअलअ', 'जअतअ'): 4092,
#  ('यअरअ', 'थअ'): 4084,
#  ('कअपअ', 'नअ'): 4074,
#  ('यअ', 'सअहअ'): 4073,
#  ('तअ', 'तअरअ'): 4056,
#  ('तअ', 'असअलअ'): 4038,
#  ('वअ', 'सअतअ'): 4028,
#  ('यअ', 'पअकअ'): 4017,
#  ('नअ', 'रअमअणअ'): 4017,
#  ('जअ', 'वअनअ'): 4015,
#  ('पअरअ', 'धअनअ'): 4012,
#  ('कअ', 'धअ'): 4009,
#  ('पअरअ', 'धअ'): 4008,
#  ('आलअ', 'हअतअ'): 4003,
#  ('शअकअ', 'षअणअ'): 3997,
#  ('मअहअ', 'टअलअ'): 3993,
#  ('हअ', 'वअ'): 3992,
#  ('आमअ', 'चअ'): 3981,
#  ('डअ', 'यअ'): 3973,
#  ('यअ', 'एकअ'): 3971,
#  ('टअरअ', 'यअ'): 3963,
#  ('घअ', 'यअ'): 3960,
#  ('खअरअ', 'चअ'): 3949,
#  ('तअ', 'एकअ'): 3948,
#  ('बअरअ', 'बअरअ'): 3933,
#  ('हअ', 'यअतअ'): 3928,
#  ('चअ', 'डअ'): 3920,
#  ('वअ', 'जअयअ'): 3919,
#  ('ठअ', 'वअ'): 3914,
#  ('पअरअ', 'सअरअ'): 3908,
#  ('टअरअ', 'वअदअ'): 3884,
#  ('सअपअ', 'षअ'): 3880,
#  ('तअरअ', 'तअयअ'): 3875,
#  ('लअ', 'वअ'): 3864,
#  ('पअहअलअ', 'यअ'): 3858,
#  ('तअरअ', 'चअ'): 3849,
#  ('कअरअ', 'यअलअ'): 3835,
#  ('यअ', 'तअयअ'): 3831,
#  ('लअ', 'जअतअ'): 3829,
#  ('वअणअ', 'यअतअ'): 3823,
#  ('लअ', 'पअरअ'): 3811,
#  ('यअ', 'भअ'): 3806,
#  ('यअ', 'हअ'): 3797,
#  ('कअ', 'पअरअ'): 3770,
#  ('कअरअतअ', 'नअ'): 3770,
#  ('कअवअ', 'ळअ'): 3767,
#  ('हअ', 'हअ'): 3766,
#  ('दअरअ', 'शअनअ'): 3765,
#  ('कअरअ', 'डअ'): 3764,
#  ('आ', 'लअयअ'): 3762,
#  ('थअ', 'डअ'): 3759,
#  ('असअलअ', 'लअ'): 3750,
#  ('गअनअ', 'हअ'): 3749,
#  ('यअ', 'हअतअ'): 3746,
#  ('तअ', 'वअरअ'): 3736,
#  ('वअ', 'ई'): 3733,
#  ('पअरअ', 'णअमअ'): 3728,
#  ('वअ', 'ठअ'): 3721,
#  ('दअरअ', 'सअ'): 3713,
#  ('रअजअ', 'यअतअ'): 3702,
#  ('असअलअ', 'यअनअ'): 3699,
#  ('दअरअ', 'शअ'): 3698,
#  ('धअ', 'चअ'): 3694,
#  ('तअयअ', 'तअ'): 3678,
#  ('वअ', 'वअ'): 3677,
#  ('कअलअ', 'लअयअ'): 3661,
#  ('पअदअ', 'धअ'): 3655,
#  ('पअरअ', 'मअखअ'): 3650,
#  ('लअ', 'तअयअ'): 3646,
#  ('कअरअ', 'नअ'): 3615,
#  ('डअ', 'ळअ'): 3606,
#  ('चअ', 'शअकअ'): 3603,
#  ('यअ', 'मअतअ'): 3600,
#  ('सअ', 'गअतअ'): 3599,
#  ('मअखअ', 'यअ'): 3598,
#  ('पअरअ', 'वअशअ'): 3595,
#  ('पअदअ', 'नअ'): 3593,
#  ('नअवअ', 'हअतअ'): 3592,
#  ('नअ', 'यअतअ'): 3589,
#  ('वअणअ', 'यअ'): 3586,
#  ('यअ', 'कअडअ'): 3575,
#  ('यअ', 'तअरअ'): 3574,
#  ('यअ', 'मअनअ'): 3568,
#  ('चअ', 'एकअ'): 3559,
#  ('नअ', 'घअ'): 3550,
#  ('लअ', 'तअरअ'): 3539,
#  ('लअ', 'कअ'): 3537,
#  ('पअहअ', 'जअ'): 3533,
#  ('हअ', 'ऊ'): 3530,
#  ('कअ', 'वअ'): 3527,
#  ('पअरअ', 'थअमअ'): 3524,
#  ('सअ', 'टअरअ'): 3520,
#  ('चअ', 'आ'): 3510,
#  ('यअ', 'कअमअ'): 3510,
#  ('वअ', 'लअगअ'): 3505,
#  ('लअकअ', 'सअ'): 3503,
#  ('कअ', 'दअ'): 3486,
#  ('मअतअ', 'दअरअ'): 3486,
#  ('सअ', 'सअ'): 3473,
#  ('तअ', 'शअ'): 3468,
#  ('मअधअ', 'यअमअ'): 3467,
#  ('हअ', 'नअ'): 3463,
#  ('ळअ', 'चअ'): 3456,
#  ('पअरअ', 'कअलअ'): 3455,
#  ('चअ', 'कअ'): 3453,
#  ('दअलअ', 'आहअ'): 3453,
#  ('लअहअ', 'नअ'): 3448,
#  ('वअटअ', 'तअ'): 3446,
#  ('यअ', 'तअ'): 3411,
#  ('टअ', 'कअलअ'): 3397,
#  ('कअलअ', 'पअ'): 3394,
#  ('भअ', 'मअकअ'): 3394,
#  ('यअ', 'दअरअ'): 3382,
#  ('शअ', 'सअनअ'): 3376,
#  ('मअलअ', 'चअ'): 3367,
#  ('नअ', 'नअ'): 3366,
#  ('षअ', 'पअरअ'): 3355,
#  ('लअ', 'असअ'): 3351,
#  ('दअ', 'चअ'): 3351,
#  ('ञअ', 'नअ'): 3350,
#  ('पअरअ', 'भअवअ'): 3347,
#  ('अ', 'तअरअ'): 3343,
#  ('मअझअ', 'यअ'): 3331,
#  ('झअलअ', 'लअ'): 3331,
#  ('रअ', 'यअनअ'): 3329,
#  ('लअ', 'आणअ'): 3311,
#  ('कअ', 'यअतअ'): 3303,
#  ('यअकअ', 'रअतअ'): 3297,
#  ('यअ', 'शअ'): 3293,
#  ('हअ', 'एकअ'): 3268,
#  ('रअ', 'आहअतअ'): 3267,
#  ('तअमअ', 'चअ'): 3260,
#  ('रअजअ', 'कअ'): 3257,
#  ('पअरअ', 'षअदअ'): 3254,
#  ('यअकअ', 'तअ'): 3250,
#  ('एकअ', 'दअ'): 3234,
#  ('कअरअ', 'शअकअतअ'): 3231,
#  ('मअ', 'चअ'): 3230,
#  ('पअतअ', 'पअरअ'): 3226,
#  ('दअनअ', 'हअ'): 3218,
#  ('तअ', 'आहअतअ'): 3215,
#  ('चअ', 'मअतअ'): 3215,
#  ('यअ', 'सअरअ'): 3208,
#  ('यअ', 'झअलअ'): 3207,
#  ('आमअ', 'दअरअ'): 3199,
#  ('यअ', 'जअ'): 3195,
#  ('सअहअ', 'तअ'): 3195,
#  ('आहअ', 'असअ'): 3188,
#  ('षअ', 'मअ'): 3179,
#  ('यअलअ', 'यअ'): 3170,
#  ('यअतअ', 'आहअ'): 3166,
#  ('शअ', 'धअ'): 3153,
#  ('पअ', 'रअमअणअ'): 3144,
#  ('वअहअ', 'नअ'): 3128,
#  ('आहअ', 'पअणअ'): 3123,
#  ('असअणअ', 'रअ'): 3123,
#  ('ठअ', 'वअलअ'): 3121,
#  ('रअहअ', 'णअ'): 3120,
#  ('तअमअ', 'हअ'): 3119,
#  ('उतअ', 'पअदअ'): 3111,
#  ('चअ', 'हअतअ'): 3110,
#  ('चअ', 'भअ'): 3095,
#  ('वअ', 'यअ'): 3092,
#  ('झअलअ', 'हअतअ'): 3091,
#  ('यअनअ', 'कअलअ'): 3086,
#  ('अभअ', 'नअ'): 3084,
#  ('वअ', 'जअ'): 3082,
#  ('बअरअ', 'चअ'): 3069,
#  ('यअ', 'रअ'): 3066,
#  ('थअ', 'यअ'): 3061,
#  ('भअ', 'मअ'): 3058,
#  ('थअ', 'पअनअ'): 3057,
#  ('रअहअ', 'तअ'): 3045,
#  ('रअ', 'पअरअ'): 3044,
#  ('उमअ', 'दअ'): 3040,
#  ('नअ', 'यअमअ'): 3027,
#  ('रअ', 'रअ'): 3027,
#  ('सअरअकअ', 'षअ'): 3015,
#  ('सअ', 'भअ'): 3014,
#  ('तअ', 'कअरअ'): 3004,
#  ('सअ', 'वअरअ'): 2999,
#  ('शअकअ', 'यअतअ'): 2998,
#  ('यअ', 'दअनअ'): 2995,
#  ('मअतअ', 'यअ'): 2992,
#  ('सअसअ', 'थअ'): 2992,
#  ('यअ', 'तअरअणअ'): 2987,
#  ('मअरअ', 'चअ'): 2987,
#  ('सअ', 'तअनअ'): 2978,
#  ('आहअ', 'आणअ'): 2975,
#  ('भअ', 'षअ'): 2972,
#  ('वअरअ', 'यअ'): 2968,
#  ('यअ', 'डअ'): 2965,
#  ('रअ', 'तअरअ'): 2952,
#  ('तअ', 'पअणअ'): 2952,
#  ('कअरअमअ', 'चअरअ'): 2937,
#  ('रअ', 'असअलअ'): 2931,
#  ('शअ', 'तअ'): 2923,
#  ('कअ', 'षअकअ'): 2920,
#  ('धअ', 'कअरअ'): 2920,
#  ('सअरअवअ', 'चअ'): 2917,
#  ('खअ', 'यअ'): 2917,
#  ('इ', 'चअ'): 2916,
#  ('सअनअ', 'यअ'): 2903,
#  ('यअ', 'मअरअ'): 2900,
#  ('चअ', 'अधअ'): 2897,
#  ('तअरअ', 'पअरअ'): 2896,
#  ('हअतअ', 'नअ'): 2893,
#  ('रअ', 'लअवअ'): 2891,
#  ('सअरअकअ', 'रअनअ'): 2885,
#  ('इतअ', 'कअ'): 2882,
#  ('लअबअ', 'धअ'): 2881,
#  ('यअ', 'मअलअ'): 2880,
#  ('जअ', 'ऊ'): 2879,
#  ('तअरअ', 'कअ'): 2875,
#  ('वअ', 'कअ'): 2874,
#  ('यअनअ', 'यअ'): 2871,
#  ('उपअ', 'लअबअ'): 2871,
#  ('वअ', 'गअ'): 2869,
#  ('वअधअ', 'नअसअ'): 2866,
#  ('आ', 'नअदअ'): 2859,
#  ('पअरअ', 'तअ'): 2854,
#  ('आहअतअ', 'तअयअ'): 2852,
#  ('चअ', 'सअरअ'): 2847,
#  ('शअ', 'ळअ'): 2844,
#  ('पअरअ', 'तअनअ'): 2835,
#  ('नअसअ', 'भअ'): 2834,
#  ('फअ', 'यअ'): 2834,
#  ('ठअ', 'चअ'): 2830,
#  ('पअ', 'ठअ'): 2829,
#  ('नअसअ', 'लअ'): 2826,
#  ('आ', 'घअ'): 2825,
#  ('दअणअ', 'यअ'): 2821,
#  ('यअ', 'सअरअवअ'): 2815,
#  ('यअ', 'घअ'): 2811,
#  ('यअ', 'कअरअणअ'): 2803,
#  ('पअरअ', 'वअसअ'): 2791,
#  ('तअ', 'घअ'): 2791,
#  ('असअ', 'वअ'): 2791,
#  ('यअ', 'आ'): 2789,
#  ('मअहअ', 'पअलअ'): 2785,
#  ('कअरअ', 'लअ'): 2780,
#  ('दअरअ', 'चअ'): 2779,
#  ('लअयअ', 'वअरअ'): 2774,
#  ('कअमअ', 'तअ'): 2766,
#  ('वअ', 'मअनअ'): 2763,
#  ('तअ', 'यअहअ'): 2762,
#  ('सअकअ', 'ळअ'): 2749,
#  ('कअमअ', 'गअरअ'): 2746,
#  ('तअ', 'असअ'): 2744,
#  ('यअ', 'अधअ'): 2741,
#  ('जअमअ', 'नअ'): 2738,
#  ('कअलअ', 'हअ'): 2726,
#  ('उचअ', 'चअ'): 2725,
#  ('ठअ', 'वअणअ'): 2724,
#  ('झअलअ', 'यअनअ'): 2721,
#  ('लअ', 'आहअतअ'): 2719,
#  ('कअलअ', 'यअनअ'): 2717,
#  ('चअ', 'लअकअ'): 2712,
#  ('सअमअ', 'सअ'): 2704,
#  ('कअतअ', 'चअ'): 2701,
#  ('नअ', 'वअहअ'): 2692,
#  ('वअयअ', 'चअ'): 2691,
#  ('हअणअ', 'यअ'): 2688,
#  ('लअकअ', 'नअ'): 2687,
#  ('वअशअ', 'वअसअ'): 2686,
#  ('ळअ', 'नअ'): 2685,
#  ('मअनअ', 'यअ'): 2685,
#  ('अनअ', 'यअ'): 2679,
#  ('वअतअ', 'तअ'): 2679,
#  ('पअरअ', 'सअदअ'): 2678,
#  ('वअरअ', 'दअ'): 2678,
#  ('हअ', 'तअ'): 2676,
#  ('यअ', 'मअधअ'): 2675,
#  ('चअ', 'यअतअ'): 2672,
#  ('तअ', 'लअयअ'): 2672,
#  ('तअरअ', 'गअतअ'): 2670,
#  ('कअरअतअ', 'तअ'): 2669,
#  ('बअ', 'ठअकअ'): 2669,
#  ('घअ', 'चअ'): 2669,
#  ('यअ', 'टअ'): 2669,
#  ('तअ', 'झअलअ'): 2665,
#  ('नअ', 'सअ'): 2637,
#  ('अ', 'गअदअ'): 2636,
#  ('पअलअ', 'कअ'): 2633,
#  ('सअपअ', 'रअणअ'): 2633,
#  ('वअणअ', 'यअसअ'): 2630,
#  ('ळअ', 'यअ'): 2626,
#  ('तअ', 'पअ'): 2624,
#  ('वअलअ', 'आहअ'): 2624,
#  ('यअलअ', 'यअतअ'): 2623,
#  ('पअरअ', 'लअ'): 2621,
#  ('सअमअ', 'वअशअ'): 2617,
#  ('सअरअ', 'खअ'): 2608,
#  ('लअ', 'यअलअ'): 2608,
#  ('तअ', 'दअ'): 2606,
#  ('थअ', 'चअ'): 2595,
#  ('यअमअ', 'ळअ'): 2594,
#  ('रअ', 'कअलअ'): 2586,
#  ('सअचअ', 'नअ'): 2585,
#  ('पअकअ', 'सअ'): 2584,
#  ('नअ', 'दअलअ'): 2582,
#  ('यअ', 'तअलअ'): 2581,
#  ('तअलअ', 'आहअ'): 2573,
#  ('दअशअ', 'चअ'): 2570,
#  ('यअ', 'ईलअ'): 2568,
#  ('सअवअ', 'चअ'): 2566,
#  ('दअ', 'यअकअ'): 2565,
#  ('हअ', 'मअहअ'): 2563,
#  ('दअशअ', 'तअ'): 2554,
#  ('थअनअ', 'कअ'): 2552,
#  ('कअतअ', 'कअलअ'): 2542,
#  ('हअ', 'असअ'): 2532,
#  ('नअ', 'हअमअ'): 2532,
#  ('कअलअ', 'नअ'): 2518,
#  ('चअ', 'कअलअ'): 2509,
#  ('मअळअ', 'णअ'): 2507,
#  ('वअलअ', 'यअ'): 2495,
#  ('आरअ', 'थअकअ'): 2494,
#  ('जअतअ', 'तअ'): 2492,
#  ('यअ', 'रअजअ'): 2488,
#  ('चअ', 'वअरअ'): 2485,
#  ('आ', 'वअहअनअ'): 2479,
#  ('खअरअ', 'दअ'): 2479,
#  ('सअ', 'धअरअणअ'): 2478,
#  ('यअ', 'सअमअ'): 2476,
#  ('दअ', 'वअशअ'): 2467,
#  ('सअ', 'घअटअनअ'): 2463,
#  ('शअ', 'वअ'): 2460,
#  ('हअ', 'तअरअ'): 2458,
#  ('कअरअ', 'तअ'): 2456,
#  ('पअहअ', 'णअ'): 2453,
#  ('तअपअ', 'सअ'): 2451,
#  ('उपअ', 'यअ'): 2449,
#  ('दअ', 'पअरअ'): 2445,
#  ('चअ', 'सअमअ'): 2444,
#  ('मअलअ', 'नअ'): 2434,
#  ('धअ', 'यअकअ'): 2431,
#  ('तअ', 'असअतअ'): 2428,
#  ('मअणअ', 'तअ'): 2426,
#  ('रअ', 'कअरअणअ'): 2424,
#  ('गअ', 'भअरअ'): 2420,
#  ('यअ', 'अनअ'): 2409,
#  ('चअ', 'पअ'): 2404,
#  ('अ', 'जअनअ'): 2398,
#  ('आलअ', 'लअयअ'): 2392,
#  ('यअ', 'लअकअ'): 2391,
#  ('सअतअ', 'वअ'): 2390,
#  ('कअ', 'नअ'): 2390,
#  ('सअहअ', 'भअ'): 2389,
#  ('तअ', 'मअहअलअ'): 2385,
#  ('तअकअ', 'रअ'): 2385,
#  ('सअनअ', 'नअ'): 2383,
#  ('षअ', 'पअ'): 2381,
#  ('यअकअ', 'रअमअ'): 2379,
#  ('घअ', 'डअ'): 2373,
#  ('आलअ', 'लअ'): 2370,
#  ('ढअ', 'लअ'): 2367,
#  ('सअरअ', 'तअ'): 2365,
#  ('वअ', 'तअयअ'): 2363,
#  ('हअ', 'कअ'): 2360,
#  ('आहअ', 'पअरअ'): 2355,
#  ('हअतअ', 'आहअ'): 2353,
#  ('यअनअ', 'हअ'): 2352,
#  ('आदअ', 'लअनअ'): 2346,
#  ('पअरअ', 'वअनअ'): 2343,
#  ('रअ', 'हअ'): 2343,
#  ('ढअ', 'तअ'): 2342,
#  ('तअयअ', 'सअ'): 2339,
#  ('आणअ', 'नअ'): 2337,
#  ('सअमअनअ', 'यअ'): 2337,
#  ('दअलअ', 'यअ'): 2336,
#  ('चअ', 'शअ'): 2332,
#  ('टअरअ', 'चअ'): 2330,
#  ('वअहअ', 'तअकअ'): 2329,
#  ('मअजअ', 'रअ'): 2329,
#  ('दअणअ', 'रअ'): 2326,
#  ('मअलअ', 'गअ'): 2319,
#  ('कअरअणअ', 'तअ'): 2316,
#  ('ए', 'खअदअ'): 2314,
#  ('पअरअ', 'पअतअ'): 2314,
#  ('जअयअ', 'चअ'): 2312,
#  ('आरअ', 'गअ'): 2309,
#  ('णअ', 'चअ'): 2307,
#  ('चअ', 'रअजअ'): 2307,
#  ('लअयअ', 'तअ'): 2303,
#  ('शअबअ', 'दअ'): 2294,
#  ('कअलअ', 'जअ'): 2292,
#  ('टअचअ', 'यअ'): 2288,
#  ('यअनअ', 'दअलअ'): 2286,
#  ('रअ', 'शअ'): 2284,
#  ('आणअ', 'खअ'): 2282,
#  ('मअ', 'डअलअ'): 2281,
#  ('एकअ', 'पअरअ'): 2279,
#  ('सअदअ', 'सअ'): 2278,
#  ('वअसअ', 'तअ'): 2277,
#  ('मअणअ', 'सअ'): 2277,
#  ('यअनअ', 'तअयअ'): 2274,
#  ('ळअ', 'वअरअ'): 2274,
#  ('तअ', 'आलअ'): 2273,
#  ('आणअ', 'पअरअ'): 2272,
#  ('यअलअ', 'यअनअ'): 2268,
#  ('उपअ', 'चअरअ'): 2268,
#  ('वअहअ', 'डअ'): 2268,
#  ('सअ', 'शअ'): 2267,
#  ('वअसअ', 'यअ'): 2266,
#  ('बअ', 'यअ'): 2266,
#  ('तअ', 'जअ'): 2266,
#  ('यअ', 'ठअ'): 2265,
#  ('तअरअ', 'कअतअ'): 2265,
#  ('आहअ', 'मअतअ'): 2264,
#  ('तअनअ', 'धअ'): 2264,
#  ('मअडअ', 'ळअ'): 2263,
#  ('कअ', 'यअमअ'): 2258,
#  ('टअ', 'तअ'): 2252,
#  ('कअ', 'टअरअ'): 2245,
#  ('कअटअ', 'बअ'): 2242,
#  ('चअरअ', 'यअ'): 2241,
#  ('नअ', 'मअतअ'): 2241,
#  ('यअतअ', 'यअतअ'): 2239,
#  ('वअणअ', 'रअ'): 2236,
#  ('नअ', 'आणअ'): 2233,
#  ('भअ', 'नअवअ'): 2233,
#  ('पअतअ', 'रअ'): 2231,
#  ('वअतअ', 'तअरअ'): 2229,
#  ('कअ', 'सअनअ'): 2227,
#  ('नअ', 'एकअ'): 2222,
#  ('चअ', 'आणअ'): 2219,
#  ('चअ', 'आरअ'): 2217,
#  ('यअ', 'पअणअ'): 2216,
#  ('पअतअ', 'ळअ'): 2216,
#  ('ठअ', 'पअरअ'): 2212,
#  ('जअतअ', 'आहअ'): 2212,
#  ('बअ', 'जअ'): 2211,
#  ('अरअ', 'जअ'): 2211,
#  ('दअ', 'घअ'): 2207,
#  ('पअरअ', 'दअरअ'): 2206,
#  ('नअ', 'दअ'): 2201,
#  ('नअ', 'षअ'): 2200,
#  ('आहअतअ', 'यअ'): 2199,
#  ('कअरअ', 'जअ'): 2197,
#  ('दअरअ', 'वअ'): 2194,
#  ('लअकअ', 'चअ'): 2189,
#  ('आणअ', 'तअ'): 2188,
#  ('कअ', 'वअरअ'): 2178,
#  ('पअ', 'तअरअ'): 2175,
#  ('हअलअ', 'लअ'): 2172,
#  ('डअ', 'वअ'): 2172,
#  ('पअरअ', 'कअशअ'): 2172,
#  ('सअ', 'टअ'): 2168,
#  ('हअ', 'सअ'): 2166,
#  ('यअ', 'मअ'): 2166,
#  ('लअ', 'डअ'): 2160,
#  ('तअ', 'रअहअ'): 2156,
#  ('नअ', 'टअकअ'): 2155,
#  ('मअनअ', 'तअ'): 2153,
#  ('घअडअ', 'लअ'): 2142,
#  ('शअनअ', 'चअ'): 2140,
#  ('चअ', 'अ'): 2140,
#  ('कअढअ', 'णअ'): 2135,
#  ('बअसअ', 'लअ'): 2132,
#  ('तअयअ', 'वअरअ'): 2131,
#  ('यअ', 'चअरअ'): 2131,
#  ('फअडअ', 'णअ'): 2130,
#  ('यअ', 'सअमअरअ'): 2128,
#  ('वअरअ', 'पअरअ'): 2125,
#  ('मअटअ', 'रअ'): 2124,
#  ('एकअ', 'णअ'): 2120,
#  ('ई', 'तअ'): 2118,
#  ('यअतअ', 'आ'): 2116,
#  ('पअतअ', 'रअकअरअ'): 2114,
#  ('नअसअ', 'लअयअ'): 2114,
#  ('वअ', 'कअलअ'): 2110,
#  ('कअ', 'तअकअ'): 2104,
#  ('यअ', 'अ'): 2103,
#  ('ई', 'चअ'): 2093,
#  ('बअ', 'दअरअ'): 2085,
#  ('भअरअतअ', 'चअ'): 2077,
#  ('णअ', 'कअलअ'): 2077,
#  ('पअरअ', 'पअरअ'): 2076,
#  ('यअ', 'घअरअ'): 2075,
#  ('तअयअ', 'वअळअ'): 2070,
#  ('लअ', 'मअहअ'): 2070,
#  ('पअरअ', 'सअतअ'): 2070,
#  ('तअ', 'यअनअ'): 2068,
#  ('सअनअ', 'मअ'): 2063,
#  ('हअतअ', 'हअ'): 2062,
#  ('सअवअ', 'कअ'): 2060,
#  ('पअसअ', 'तअकअ'): 2058,
#  ('दअरअ', 'नअ'): 2057,
#  ('वअ', 'सअनअ'): 2055,
#  ('धअरअ', 'मअ'): 2055,
#  ('जअ', 'वअणअ'): 2054,
#  ('ठअ', 'यअ'): 2051,
#  ('पअरअ', 'भअ'): 2050,
#  ('यअतअ', 'तअ'): 2049,
#  ('नअ', 'मअहअ'): 2049,
#  ('पअढअ', 'लअ'): 2045,
#  ('कअमअ', 'नअ'): 2044,
#  ('नअरअमअ', 'तअ'): 2043,
#  ('पअ', 'पअरअ'): 2043,
#  ('तअ', 'मअ'): 2042,
#  ('हअ', 'कअरअ'): 2039,
#  ('तअ', 'सअवअ'): 2036,
#  ('अपअ', 'कअ'): 2034,
#  ('वअरअ', 'हअ'): 2033,
#  ('कअरअ', 'कअ'): 2032,
#  ('सअखअ', 'यअ'): 2031,
#  ('षअ', 'कअरअ'): 2029,
#  ('खअसअ', 'दअरअ'): 2028,
#  ('नअ', 'वअरअ'): 2022,
#  ('शअनअ', 'वअरअ'): 2020,
#  ('वअ', 'कअतअ'): 2017,
#  ('यअ', 'बअदअ'): 2016,
#  ('मअतअ', 'तअ'): 2015,
#  ('चअ', 'वअळअ'): 2009,
#  ('आहअ', 'तअरअ'): 2008,
#  ('कअढअ', 'लअ'): 2004,
#  ('यअ', 'नअतअ'): 2002,
#  ('शअकअतअ', 'नअ'): 1999,
#  ('यअमअ', 'तअनअ'): 1998,
#  ('कअ', 'हअ'): 1989,
#  ('चअ', 'कअरअणअ'): 1987,
#  ('आहअ', 'मअ'): 1986,
#  ('घअ', 'षअणअ'): 1985,
#  ('मअतअ', 'दअनअ'): 1984,
#  ('तअरअ', 'वअ'): 1984,
#  ('नअ', 'आपअ'): 1983,
#  ('यअतअ', 'चअ'): 1983,
#  ('गअणअ', 'लअयअ'): 1983,
#  ('यअ', 'असअ'): 1981,
#  ('जअनअ', 'वअरअ'): 1981,
#  ('यअ', 'टअकअ'): 1980,
#  ('शअकअ', 'लअ'): 1979,
#  ('यअ', 'बअरअ'): 1978,
#  ('शअकअ', 'यअ'): 1977,
#  ('कअलअ', 'तअयअ'): 1976,
#  ('यअ', 'आहअतअ'): 1975,
#  ('तअ', 'कअमअ'): 1968,
#  ('सअ', 'धअनअ'): 1968,
#  ('शअकअ', 'षअकअ'): 1965,
#  ('नअ', 'धअ'): 1965,
#  ('नअ', 'कअरअतअ'): 1963,
#  ('लअ', 'एकअ'): 1962,
#  ('वअजअ', 'तअ'): 1962,
#  ('चअरअ', 'लअ'): 1961,
#  ('आ', 'दअशअ'): 1957,
#  ('लअ', 'कअलअ'): 1955,
#  ('लअयअ', 'मअळअ'): 1951,
#  ('यअ', 'दअशअ'): 1950,
#  ('पअरअ', 'शअसअ'): 1946,
#  ('चअ', 'मअगअ'): 1945,
#  ('जअबअ', 'बअ'): 1942,
#  ('हअतअ', 'पअणअ'): 1941,
#  ('यअ', 'पअदअ'): 1941,
#  ('शअकअतअ', 'तअ'): 1934,
#  ('मअनअ', 'लअ'): 1931,
#  ('सअहअ', 'कअरअ'): 1930,
#  ('तअ', 'यअतअ'): 1927,
#  ('यअ', 'तअनअ'): 1925,
#  ('यअ', 'सअनअ'): 1923,
#  ('आहअ', 'मअहअ'): 1922,
#  ('रअजअ', 'कअरअणअ'): 1919,
#  ('यअ', 'पअलअ'): 1919,
#  ('सअ', 'गअ'): 1918,
#  ('चअ', 'वअयअ'): 1917,
#  ('जअणअ', 'नअ'): 1913,
#  ('तअरअ', 'रअ'): 1913,
#  ('लअ', 'सअ'): 1913,
#  ('वअ', 'असअ'): 1912,
#  ('नअ', 'मअलअ'): 1912,
#  ('लअगअ', 'णअ'): 1912,
#  ('कअरअ', 'सअ'): 1909,
#  ('यअनअ', 'सअगअ'): 1908,
#  ('तअ', 'मअळअ'): 1908,
#  ('ळअ', 'लअ'): 1905,
#  ('जअ', 'ईलअ'): 1905,
#  ('अनअ', 'भअवअ'): 1903,
#  ('तअ', 'वअरअणअ'): 1902,
#  ('लअ', 'असअतअ'): 1894,
#  ('णअकअ', 'तअ'): 1891,
#  ('दअशअ', 'तअलअ'): 1890,
#  ('असअ', 'मअहअ'): 1889,
#  ('चअ', 'सअवअ'): 1887,
#  ('हअतअ', 'आणअ'): 1886,
#  ('बअ', 'चअ'): 1883,
#  ('आणअ', 'वअ'): 1880,
#  ('अपअ', 'घअ'): 1877,
#  ('सअरअ', 'कअलअ'): 1875,
#  ('मअ', 'वअरअ'): 1875,
#  ('रअ', 'वअ'): 1874,
#  ('यअ', 'कअहअ'): 1871,
#  ('लअकअ', 'पअरअ'): 1871,
#  ('मअडअ', 'यअ'): 1870,
#  ('तअ', 'सअरअ'): 1869,
#  ('शअसअ', 'तअरअ'): 1859,
#  ('वअ', 'लअगअतअ'): 1858,
#  ('बअलअ', 'तअ'): 1858,
#  ('आहअ', 'वअ'): 1857,
#  ('शअ', 'वअरअ'): 1857,
#  ('सअवअ', 'तअचअ'): 1855,
#  ('लअयअ', 'सअ'): 1853,
#  ('तअरअ', 'नअ'): 1849,
#  ('हअ', 'दअखअलअ'): 1846,
#  ('धअकअ', 'कअ'): 1843,
#  ('नअगअरअ', 'कअ'): 1843,
#  ('अतअ', 'शअयअ'): 1841,
#  ('सअहअ', 'बअ'): 1840,
#  ('वअ', 'अशअ'): 1836,
#  ('कअ', 'कअरअ'): 1835,
#  ('यअसअ', 'रअखअ'): 1835,
#  ('षअ', 'सअ'): 1834,
#  ('असअ', 'सअ'): 1833,
#  ('टअलअ', 'आहअ'): 1832,
#  ('कअतअ', 'नअ'): 1832,
#  ('खअदअ', 'यअ'): 1829,
#  ('मअकअ', 'तअ'): 1828,
#  ('फअरअ', 'सअ'): 1827,
#  ('पअणअ', 'यअतअ'): 1826,
#  ('यअ', 'वअहअ'): 1822,
#  ('नअरअ', 'दअरअ'): 1820,
#  ('चअ', 'अनअ'): 1820,
#  ('सअ', 'जअयअ'): 1820,
#  ('वअदअ', 'चअ'): 1819,
#  ('तअनअ', 'चअ'): 1819,
#  ('हअतअ', 'कअ'): 1817,
#  ('रअ', 'कअरअ'): 1817,
#  ('एकअ', 'सअ'): 1817,
#  ('भअ', 'चअ'): 1815,
#  ('पअणअ', 'तअयअ'): 1815,
#  ('यअ', 'सअवअ'): 1814,
#  ('रअ', 'असअ'): 1812,
#  ('धअ', 'दअ'): 1809,
#  ('वअनअ', 'गअ'): 1808,
#  ('चअ', 'बअ'): 1808,
#  ('बअ', 'धअकअ'): 1808,
#  ('यअनअ', 'वअ'): 1806,
#  ('कअमअ', 'कअरअणअ'): 1803,
#  ('वअ', 'मअ'): 1803,
#  ('पअदअ', 'रअथअ'): 1802,
#  ('डअ', 'ओ'): 1801,
#  ('रअ', 'तअयअ'): 1800,
#  ('पअहअ', 'तअ'): 1799,
#  ('सअमअ', 'वअरअ'): 1797,
#  ('जअरअ', 'दअरअ'): 1797,
#  ('लअवअ', 'लअ'): 1795,
#  ('यअकअ', 'डअनअ'): 1795,
#  ('लअ', 'जअ'): 1794,
#  ('णअ', 'वअसअ'): 1793,
#  ('तअलअ', 'नअ'): 1792,
#  ('तअ', 'चअ'): 1791,
#  ('कअरअ', 'मअ'): 1788,
#  ('तअ', 'भअ'): 1786,
#  ('नअवअ', 'दअलअ'): 1781,
#  ('उदअ', 'धअ'): 1781,
#  ('वअरअ', 'वअ'): 1778,
#  ('षअ', 'मअतअ'): 1777,
#  ('चअ', 'मअलअ'): 1777,
#  ('कअ', 'सअ'): 1776,
#  ('कअरअ', 'कअटअ'): 1775,
#  ('यअ', 'चअकअ'): 1775,
#  ('घअटअनअ', 'चअ'): 1774,
#  ('टअ', 'ळअ'): 1772,
#  ('यअ', 'सअरअकअ'): 1771,
#  ('दअहअशअतअ', 'वअदअ'): 1771,
#  ('बअरअ', 'यअ'): 1769,
#  ('सअमअजअ', 'कअ'): 1767,
#  ('कअ', 'आणअ'): 1766,
#  ('थअ', 'टअ'): 1766,
#  ('णअ', 'वअ'): 1765,
#  ('नअ', 'यअकअ'): 1763,
#  ...}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert1k_uni_tokens.txt', 'w',encoding = 'utf-8') as f3:
    for key, value in fin_dict.items():
        f3.write('%s : %s\n' % (key, value))
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert1k_bi_tokens.txt', 'w',encoding = 'utf-8') as f4:
    for key, value in fin_dict_bi.items():
        f4.write('%s : %s\n' % (key, value))

# %%
all_tokens = list(fin_dict.keys())

# %%
L_char_bi = []
L_syl_bi = []

# %%
syl_bi_global = {}
syl_bi_local = {}
char_bi_global = {}
char_bi_local = {}

# %%
i=0
# while (i<len(all_tokens)-1):
for tok in all_tokens:
  i=len(tok)-1
  while (i>0):
    if tok[i] != 'ं' and tok[i] != 'ँ' and tok[i] != 'ः' and tok[i-1] != 'ं' and tok[i-1] != 'ँ' and tok[i-1] != 'ः':
        if tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-1]+tok[i]] += fin_dict[tok]
    elif i>1 and tok[i-1] == 'ं' or tok[i-1] == 'ँ' or tok[i-1] == 'ः' or  tok[i] == 'ं' or tok[i] == 'ँ' or tok[i] == 'ः':
        if tok[i-2]+tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] += fin_dict[tok]
        # i-=1
    if (i<len(tok)-1) and (tok[i+1] == 'ं' or tok[i+1] == 'ँ' or tok[i+1] == 'ः'):
      i-=1
    i-=1

# %%
all_syllables = []
for i in range(len(all_tokens)):
    all_syllables.append([])

# %%
dict_count_uni = {}
dict_count_bi = {}
syl_count_uni = {}
syl_count_bi = {}

# %%
k=0
for words in all_tokens:
    j=0
    # for i in range(len(words)):
    i=0
    while (i<len(words)):
        if ord(words[i]) >=2305 and ord(words[i])<2325:
            if i<len(words)-1 and words[i+1] != 'ः' and words[i+1] != 'ं' and words[i+1] != 'ँ':
                if words[j:i+1] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+1]] = 1
                else:
                    syl_count_uni[words[j:i+1]] += 1
                all_syllables[k].append(words[j:i+1])
                j=i+1
            else:
                if words[j:i+2] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+2]] = 1
                else:
                    syl_count_uni[words[j:i+2]] += 1
                all_syllables[k].append(words[j:i+2])
                j=i+2
                i+=1
        i+=1
    if k%1000 == 0:
        print(k)
    k+=1
# Out:
# 0
# 1000

# %%
# fin_dict(all_tokens[0])

# %%
k=0
for syls in all_syllables:
    j=0
    for i in range(len(syls)-1):
        if syls[i]+syls[i+1] not in list(syl_bi_local.keys()):
            syl_bi_local[syls[i]+syls[i+1]] = 1
            syl_bi_global[syls[i]+syls[i+1]] = fin_dict[all_tokens[k]]
        else:
            syl_bi_local[syls[i]+syls[i+1]] += 1
            syl_bi_global[syls[i]+syls[i+1]] += fin_dict[all_tokens[k]]
    k+=1
    if k%10000==0:
        print(k)

# %%
fin_dict_char_l = {k: v for k, v in sorted(char_bi_local.items(), key=lambda item: item[1],reverse=True)}
fin_dict_syl_l = {k: v for k, v in sorted(syl_bi_local.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert1k_bi_chars.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('Char : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_char_l.items():
        f3.write('%s : %s : %s\n' % (key, value, char_bi_global[key]))
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert1k_bi_syls.txt', 'w',encoding = 'utf-8') as f4:
    f4.write('Syl : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_syl_l.items():
        f4.write('%s : %s : %s\n' % (key, value, syl_bi_global[key]))

# %%
z = open(filepath,'r',encoding='utf-8',errors='ignore')
marathi_corpus = z.read()
z.close()
marathi_corpus = marathi_corpus.split('\n')

max_length = 2000

tokenized_marathi_corpus = []
for text in marathi_corpus:
    tokens = tokenizer.tokenize(text)
    tokens = tokens[:max_length]
    tokenized_marathi_corpus.append(tokens)
flat_tokenized_marathi_corpus = [token for sublist in tokenized_marathi_corpus for token in sublist]

token_unigram_frequencies = Counter(flat_tokenized_marathi_corpus)

bi_grams = [(flat_tokenized_marathi_corpus[i], flat_tokenized_marathi_corpus[i + 1]) for i in range(len(flat_tokenized_marathi_corpus) - 1)]
bi_gram_frequencies = Counter(bi_grams)

# %%
type(flat_tokenized_marathi_corpus[1])
# Out:
# str

# %%
flat_tokenized_marathi_corpus[:10]
# Out:
# ['▁सव', 'पन', '▁द', 'ख', 'वण', '▁आण', '▁आश', 'व', 'सन', '▁दण']

# %%
corrected_tokenized_corpus = []

# %%
for i in range(len(flat_tokenized_marathi_corpus)):
  corrected_tokenized_corpus.append([])

# %%
j=0
while j < len(flat_tokenized_marathi_corpus):
  for i in range(len(flat_tokenized_marathi_corpus[j])-1):
      # print(i)
      if (ord(flat_tokenized_marathi_corpus[j][i])>=2309 and ord(flat_tokenized_marathi_corpus[j][i])<=2324):
          if (flat_tokenized_marathi_corpus[j][i]!='अ' or flat_tokenized_marathi_corpus[j][i+1]!='ं'):
              corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
          else:
              corrected_tokenized_corpus[j].append('अं')
      elif (ord(flat_tokenized_marathi_corpus[j][i])>=2325 and ord(flat_tokenized_marathi_corpus[j][i])<=2361):
          corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
          if ((ord(flat_tokenized_marathi_corpus[j][i+1])<2366 or ord(flat_tokenized_marathi_corpus[j][i+1])>=2382) and flat_tokenized_marathi_corpus[j][i+1] !='ं'):
              corrected_tokenized_corpus[j].append('अ')
      elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2366 and ord(flat_tokenized_marathi_corpus[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(flat_tokenized_marathi_corpus[j][i])-56))
      elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2305 and ord(flat_tokenized_marathi_corpus[j][i])<2309) and flat_tokenized_marathi_corpus[j][i-1] != 'अ'):
          corrected_tokenized_corpus[j].append('अ'+flat_tokenized_marathi_corpus[j][i])
      # elif flat_tokenized_marathi_corpus[j][i] == '#':
      #     corrected_tokenized_corpus[j].append('#')
  i = len(flat_tokenized_marathi_corpus[j])-1
  if (ord(flat_tokenized_marathi_corpus[j][i])>=2309 and ord(flat_tokenized_marathi_corpus[j][i])<=2324):
          corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
  elif (ord(flat_tokenized_marathi_corpus[j][i])>=2325 and ord(flat_tokenized_marathi_corpus[j][i])<=2361):
      corrected_tokenized_corpus[j].append(flat_tokenized_marathi_corpus[j][i])
      corrected_tokenized_corpus[j].append('अ')
  elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2366 and ord(flat_tokenized_marathi_corpus[j][i])<2381)):
          corrected_tokenized_corpus[j].append(chr(ord(flat_tokenized_marathi_corpus[j][i])-56))
  elif ((ord(flat_tokenized_marathi_corpus[j][i])>=2305 and ord(flat_tokenized_marathi_corpus[j][i])<2309)):
          corrected_tokenized_corpus[j].append('अ'+flat_tokenized_marathi_corpus[j][i])
  # elif flat_tokenized_marathi_corpus[j][i] == '#':
  #         corrected_tokenized_corpus[j].append('#')

  # if j%10000==0:
  #   print(j)
  j+=1

# %%
corrected_tokenized_corpus = [sublist for sublist in corrected_tokenized_corpus if sublist]

# %%
for i in range(len(corrected_tokenized_corpus)):
  corrected_tokenized_corpus[i] = ''.join(corrected_tokenized_corpus[i])
  if i%10000==0:
    print(i)

# %%
corrected_uni_freq = Counter(corrected_tokenized_corpus)

bi_grams = [(corrected_tokenized_corpus[i], corrected_tokenized_corpus[i + 1]) for i in range(len(corrected_tokenized_corpus) - 1)]
corrected_bi_freq = Counter(bi_grams)

# %%
fin_dict = {k: v for k, v in sorted(corrected_uni_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi = {k: v for k, v in sorted(corrected_bi_freq.items(), key=lambda item: item[1],reverse=True)}

# %%
fin_dict_bi
# Out:
# {('चअ', 'यअ'): 154728,
#  ('यअ', 'चअ'): 133054,
#  ('नअ', 'हअ'): 42641,
#  ('तअयअ', 'चअ'): 38459,
#  ('धअ', 'यअ'): 35584,
#  ('मअहअ', 'णअ'): 32191,
#  ('तअ', 'तअ'): 29032,
#  ('यअ', 'पअरअ'): 27673,
#  ('तअयअ', 'नअ'): 27490,
#  ('यअसअ', 'ठअ'): 27072,
#  ('यअ', 'वअरअ'): 24451,
#  ('रअ', 'यअ'): 23886,
#  ('नअ', 'यअ'): 22890,
#  ('णअ', 'रअ'): 21958,
#  ('यअतअ', 'आलअ'): 21703,
#  ('तअ', 'यअ'): 21271,
#  ('कअ', 'यअ'): 20925,
#  ('यअ', 'दअ'): 20437,
#  ('यअ', 'वअ'): 20386,
#  ('सअ', 'ठअ'): 18469,
#  ('चअ', 'पअरअ'): 18152,
#  ('मअहअ', 'तअ'): 17687,
#  ('मअतअ', 'रअ'): 17385,
#  ('तअ', 'वअ'): 17223,
#  ('कअ', 'षअ'): 16723,
#  ('कअरअ', 'यअ'): 16267,
#  ('यअ', 'यअ'): 16229,
#  ('षअ', 'टअ'): 16222,
#  ('कअरअणअ', 'यअतअ'): 16189,
#  ('षअ', 'टअरअ'): 16004,
#  ('चअ', 'तअ'): 15940,
#  ('रअ', 'षअ'): 15891,
#  ('मअ', 'धअ'): 15799,
#  ('वअरअ', 'षअ'): 15683,
#  ('णअ', 'नअ'): 14384,
#  ('पअरअ', 'यअतअ'): 13923,
#  ('वअ', 'चअ'): 13903,
#  ('णअ', 'यअ'): 13860,
#  ('मअ', 'बअ'): 13529,
#  ('मअधअ', 'यअ'): 13194,
#  ('तअयअ', 'मअळअ'): 13154,
#  ('घअ', 'तअलअ'): 12933,
#  ('षअ', 'तअ'): 12885,
#  ('वअ', 'दअ'): 12594,
#  ('सअ', 'थअ'): 12483,
#  ('बअ', 'ई'): 12458,
#  ('पअरअ', 'णअ'): 12345,
#  ('असअ', 'नअ'): 12292,
#  ('पअ', 'सअनअ'): 12223,
#  ('चअ', 'वअ'): 12028,
#  ('चअ', 'नअ'): 11905,
#  ('वअ', 'ढअ'): 11864,
#  ('कअलअ', 'आहअ'): 11849,
#  ('अनअ', 'कअ'): 11803,
#  ('लअ', 'आहअ'): 11801,
#  ('नअ', 'तअरअ'): 11793,
#  ('पअकअ', 'षअ'): 11696,
#  ('असअलअ', 'यअ'): 11685,
#  ('वअ', 'पअरअ'): 11637,
#  ('पअरअ', 'वअ'): 11571,
#  ('पअरअ', 'कअरअ'): 11225,
#  ('कअरअणअ', 'यअ'): 11212,
#  ('भअ', 'जअ'): 11073,
#  ('थअ', 'तअ'): 10949,
#  ('रअ', 'आहअ'): 10940,
#  ('आपअ', 'लअयअ'): 10872,
#  ('दअ', 'यअ'): 10706,
#  ('यअ', 'णअ'): 10561,
#  ('धअ', 'तअ'): 10504,
#  ('कअरअ', 'वअ'): 10338,
#  ('नअवअ', 'डअ'): 10310,
#  ('दअ', 'तअ'): 10254,
#  ('यअ', 'गअ'): 9965,
#  ('षअ', 'यअ'): 9960,
#  ('हअ', 'यअ'): 9917,
#  ('आहअ', 'तअयअ'): 9899,
#  ('तअसअ', 'चअ'): 9812,
#  ('यअ', 'कअरअ'): 9745,
#  ('पअलअ', 'सअ'): 9718,
#  ('कअरअणअ', 'यअसअ'): 9710,
#  ('नअ', 'कअ'): 9538,
#  ('पअरअ', 'यअ'): 9503,
#  ('लअयअ', 'चअ'): 9356,
#  ('नअ', 'चअ'): 9346,
#  ('कअ', 'चअ'): 9325,
#  ('यअतअ', 'लअ'): 9286,
#  ('सअ', 'चअ'): 9243,
#  ('आहअ', 'यअ'): 9210,
#  ('यअतअ', 'नअ'): 9152,
#  ('आलअ', 'आहअ'): 9066,
#  ('आपअ', 'लअ'): 9006,
#  ('तअ', 'हअ'): 8954,
#  ('तअ', 'नअ'): 8949,
#  ('चअ', 'चअ'): 8929,
#  ('लअ', 'लअ'): 8911,
#  ('यअ', 'पअ'): 8868,
#  ('यअ', 'सअ'): 8689,
#  ('तअ', 'पअरअ'): 8618,
#  ('जअलअ', 'हअ'): 8605,
#  ('हअ', 'पअरअ'): 8565,
#  ('यअकअ', 'षअ'): 8559,
#  ('यअ', 'थअ'): 8529,
#  ('गअ', 'यअ'): 8508,
#  ('लअगअ', 'लअ'): 8450,
#  ('वअयअ', 'कअतअ'): 8420,
#  ('घअ', 'तअ'): 8420,
#  ('दअ', 'वअसअ'): 8419,
#  ('यअ', 'नअ'): 8387,
#  ('कअरअणअ', 'रअ'): 8385,
#  ('कअ', 'गअरअ'): 8372,
#  ('कअलअ', 'यअ'): 8315,
#  ('वअ', 'भअ'): 8166,
#  ('सअ', 'पअरअ'): 8136,
#  ('लअकअ', 'षअ'): 8096,
#  ('कअरअ', 'चअ'): 8037,
#  ('पअ', 'चअ'): 8025,
#  ('तअ', 'आहअ'): 8017,
#  ('जअ', 'पअ'): 7881,
#  ('सअ', 'थअनअ'): 7877,
#  ('यअनअ', 'तअरअ'): 7869,
#  ('णअ', 'जअ'): 7846,
#  ('हअणअ', 'रअ'): 7843,
#  ('सअरअ', 'वअतअ'): 7809,
#  ('णअ', 'यअसअ'): 7792,
#  ('वअ', 'चअरअ'): 7642,
#  ('हअतअ', 'यअ'): 7572,
#  ('पअरअ', 'सअ'): 7519,
#  ('चअ', 'हअ'): 7514,
#  ('नअ', 'तअ'): 7492,
#  ('तअ', 'हअतअ'): 7430,
#  ('सअरअ', 'कअरअ'): 7414,
#  ('धअ', 'वअ'): 7361,
#  ('षअ', 'चअ'): 7295,
#  ('सअ', 'वअतअ'): 7219,
#  ('वअशअ', 'षअ'): 7213,
#  ('गअरअ', 'सअ'): 7199,
#  ('डअ', 'णअकअ'): 7189,
#  ('चअ', 'मअहअ'): 7185,
#  ('वअरअ', 'धअ'): 7168,
#  ('तअ', 'सअ'): 7126,
#  ('वअरअ', 'नअ'): 7070,
#  ('यअतअ', 'यअ'): 7066,
#  ('लअ', 'नअ'): 7061,
#  ('भअ', 'गअ'): 7057,
#  ('तअचअ', 'यअ'): 6985,
#  ('णअ', 'लअ'): 6933,
#  ('रअपअ', 'यअ'): 6929,
#  ('तअ', 'तअयअ'): 6892,
#  ('कअणअ', 'तअ'): 6872,
#  ('मअहअ', 'रअ'): 6869,
#  ('सअगअ', 'तअलअ'): 6849,
#  ('वअ', 'षअ'): 6826,
#  ('तअयअ', 'रअ'): 6795,
#  ('वअयअ', 'वअसअ'): 6769,
#  ('वअशअ', 'यअकअ'): 6765,
#  ('चअ', 'गअलअ'): 6750,
#  ('मअळअ', 'लअ'): 6743,
#  ('रअजअ', 'यअ'): 6742,
#  ('नअ', 'शअ'): 6695,
#  ('अधअ', 'कअ'): 6679,
#  ('पअरअतअ', 'यअकअ'): 6661,
#  ('नअ', 'तअयअ'): 6649,
#  ('यअ', 'वअळअ'): 6643,
#  ('यअ', 'बअ'): 6556,
#  ('झअलअ', 'आहअ'): 6539,
#  ('यअ', 'जअनअ'): 6533,
#  ('सअ', 'यअ'): 6504,
#  ('सअ', 'घअ'): 6484,
#  ('पअरअ', 'कअरअणअ'): 6464,
#  ('आ', 'वअशअ'): 6464,
#  ('भअ', 'तअ'): 6387,
#  ('लअ', 'यअनअ'): 6314,
#  ('चअरअ', 'चअ'): 6299,
#  ('चअ', 'सअ'): 6298,
#  ('गअ', 'वअ'): 6269,
#  ('शअवअ', 'सअनअ'): 6232,
#  ('गअलअ', 'यअ'): 6214,
#  ('तअरअ', 'तअ'): 6199,
#  ('अधअ', 'कअरअ'): 6119,
#  ('नअ', 'रअणअ'): 6116,
#  ('मअयअ', 'नअ'): 6088,
#  ('वअरअ', 'लअ'): 6034,
#  ('रअ', 'नअ'): 6032,
#  ('यअमअ', 'तअरअ'): 6028,
#  ('लअ', 'हअतअ'): 5989,
#  ('दअसअ', 'रअ'): 5981,
#  ('रअ', 'चअ'): 5926,
#  ('रअणअ', 'यअ'): 5900,
#  ('तअ', 'रअपअटअ'): 5892,
#  ('पअरअ', 'शअनअ'): 5892,
#  ('मअहअ', 'नअ'): 5885,
#  ('दअरअ', 'मअयअ'): 5856,
#  ('तअ', 'वअहअ'): 5765,
#  ('जअ', 'तअ'): 5753,
#  ('चअ', 'छअ'): 5699,
#  ('असअलअ', 'लअयअ'): 5651,
#  ('वअ', 'तअ'): 5647,
#  ('सअधअ', 'यअ'): 5639,
#  ('यअ', 'थअलअ'): 5599,
#  ('शअतअकअ', 'रअ'): 5564,
#  ('बअ', 'धअ'): 5540,
#  ('तअ', 'आणअ'): 5489,
#  ('पअ', 'यअ'): 5479,
#  ('फअ', 'कअतअ'): 5472,
#  ('रअहअ', 'लअ'): 5461,
#  ('तअ', 'थअ'): 5461,
#  ('मअरअ', 'ठअ'): 5452,
#  ('शअ', 'चअ'): 5440,
#  ('दअलअ', 'लअ'): 5436,
#  ('तअ', 'कअलअ'): 5410,
#  ('कअ', 'षअणअ'): 5396,
#  ('दअ', 'धअ'): 5387,
#  ('कअरअ', 'यअकअ'): 5380,
#  ('मअखअ', 'यअमअ'): 5378,
#  ('आमअ', 'हअ'): 5376,
#  ('नअ', 'हअतअ'): 5366,
#  ('नअ', 'कअरअ'): 5360,
#  ('बअ', 'बअतअ'): 5351,
#  ('चअ', 'तअरअ'): 5341,
#  ('पअरअ', 'शअ'): 5327,
#  ('हअ', 'चअ'): 5313,
#  ('पअरअ', 'कअ'): 5308,
#  ('यअ', 'कअलअ'): 5295,
#  ('यअ', 'मअहअ'): 5287,
#  ('दअ', 'वअरअ'): 5265,
#  ('पअरअ', 'मअणअ'): 5263,
#  ('यअ', 'यअलअ'): 5229,
#  ('तअ', 'मअहअ'): 5214,
#  ('तअयअ', 'लअ'): 5214,
#  ('चअ', 'दअरअ'): 5204,
#  ('कअलअ', 'हअतअ'): 5190,
#  ('वअ', 'वअधअ'): 5165,
#  ('सअदअ', 'धअ'): 5158,
#  ('हअतअ', 'तअयअ'): 5155,
#  ('जअ', 'चअ'): 5123,
#  ('शअ', 'कअ'): 5108,
#  ('षअ', 'ठअ'): 5094,
#  ('सअबअ', 'धअ'): 5084,
#  ('मअरअ', 'गअ'): 5073,
#  ('षअ', 'तअरअ'): 5061,
#  ('असअतअ', 'नअ'): 5053,
#  ('असअलअ', 'तअरअ'): 5028,
#  ('डअ', 'कअ'): 5018,
#  ('हअ', 'तअयअ'): 5011,
#  ('अ', 'रअथअ'): 5001,
#  ('दअ', 'खअ'): 4988,
#  ('तअरअ', 'यअ'): 4973,
#  ('यअ', 'नअवअ'): 4963,
#  ('कअ', 'कअ'): 4958,
#  ('यअमअ', 'धअ'): 4942,
#  ('वअ', 'कअसअ'): 4922,
#  ('आणअ', 'तअयअ'): 4904,
#  ('हअतअ', 'तअ'): 4902,
#  ('गअ', 'चअ'): 4901,
#  ('पअनअ', 'हअ'): 4852,
#  ('सअनअ', 'चअ'): 4826,
#  ('ऊ', 'शअकअतअ'): 4818,
#  ('झअ', 'लअयअ'): 4810,
#  ('डअ', 'चअ'): 4798,
#  ('लअ', 'हअ'): 4795,
#  ('ठअ', 'कअणअ'): 4787,
#  ('वअ', 'कअरअ'): 4778,
#  ('णअ', 'यअतअ'): 4776,
#  ('मअठअ', 'यअ'): 4768,
#  ('नअ', 'वअ'): 4767,
#  ('मअगअ', 'णअ'): 4759,
#  ('रअसअ', 'तअ'): 4745,
#  ('दअसअ', 'तअ'): 4737,
#  ('आहअ', 'हअ'): 4737,
#  ('चअ', 'आहअ'): 4721,
#  ('नअ', 'कअलअ'): 4716,
#  ('टअ', 'यअ'): 4690,
#  ('आहअ', 'कअ'): 4685,
#  ('लअ', 'चअ'): 4685,
#  ('चअ', 'नअवअ'): 4680,
#  ('कअरअ', 'यअनअ'): 4679,
#  ('वअसअ', 'थअ'): 4662,
#  ('नअवअ', 'नअ'): 4648,
#  ('चअ', 'दअ'): 4621,
#  ('लअ', 'लअयअ'): 4619,
#  ('तअलअ', 'कअ'): 4601,
#  ('तअ', 'कअरअणअ'): 4550,
#  ('यअ', 'आणअ'): 4532,
#  ('यअ', 'वअयअ'): 4519,
#  ('पअरअ', 'दअशअ'): 4519,
#  ('चअ', 'तअयअ'): 4517,
#  ('पअरअ', 'चअ'): 4497,
#  ('आहअ', 'तअ'): 4491,
#  ('यअ', 'मअळअ'): 4480,
#  ('चअ', 'कअरअ'): 4474,
#  ('जअ', 'ञअ'): 4455,
#  ('लअ', 'तअ'): 4453,
#  ('लअ', 'यअ'): 4442,
#  ('टअकअ', 'कअ'): 4438,
#  ('णअ', 'तअ'): 4433,
#  ('जअसअ', 'तअ'): 4425,
#  ('झअलअ', 'लअयअ'): 4422,
#  ('यअकअ', 'आहअ'): 4407,
#  ('घअ', 'ऊनअ'): 4404,
#  ('सअतअ', 'रअ'): 4399,
#  ('चअ', 'कअमअ'): 4390,
#  ('कअडअ', 'नअ'): 4381,
#  ('गअ', 'षअ'): 4363,
#  ('दअ', 'यअरअ'): 4352,
#  ('नअ', 'सअरअ'): 4347,
#  ('ठअ', 'कअरअ'): 4346,
#  ('भअरअतअ', 'यअ'): 4344,
#  ('बअदअ', 'दअलअ'): 4340,
#  ('रअ', 'गअणअ'): 4338,
#  ('असअतअ', 'तअ'): 4334,
#  ('पअडअ', 'लअ'): 4330,
#  ('यअ', 'कअ'): 4321,
#  ('अधअ', 'यअकअ'): 4321,
#  ('कअलअ', 'लअ'): 4302,
#  ('नअ', 'पअरअ'): 4293,
#  ('वअरअ', 'तअ'): 4282,
#  ('मअळअ', 'तअ'): 4278,
#  ('हअ', 'ईलअ'): 4277,
#  ('आरअ', 'पअ'): 4276,
#  ('पअ', 'वअरअ'): 4239,
#  ('दअ', 'षअ'): 4233,
#  ('पअणअ', 'यअ'): 4210,
#  ('जअणअ', 'रअ'): 4204,
#  ('उतअ', 'तअरअ'): 4192,
#  ('पअ', 'शअ'): 4190,
#  ('तअ', 'कअ'): 4180,
#  ('दअणअ', 'यअतअ'): 4151,
#  ('यअ', 'आहअ'): 4148,
#  ('उपअसअ', 'थअ'): 4122,
#  ('पअलअ', 'सअनअ'): 4110,
#  ('कअलअ', 'जअतअ'): 4098,
#  ('यअरअ', 'थअ'): 4086,
#  ('यअ', 'सअहअ'): 4075,
#  ('कअपअ', 'नअ'): 4074,
#  ('तअ', 'तअरअ'): 4062,
#  ('तअ', 'असअलअ'): 4041,
#  ('यअ', 'पअकअ'): 4030,
#  ('वअ', 'सअतअ'): 4030,
#  ('नअ', 'रअमअणअ'): 4020,
#  ('जअ', 'वअनअ'): 4016,
#  ('पअरअ', 'धअनअ'): 4014,
#  ('कअ', 'धअ'): 4013,
#  ('पअरअ', 'धअ'): 4008,
#  ('आलअ', 'हअतअ'): 4004,
#  ('शअकअ', 'षअणअ'): 3999,
#  ('मअहअ', 'टअलअ'): 3996,
#  ('हअ', 'वअ'): 3992,
#  ('आमअ', 'चअ'): 3989,
#  ('डअ', 'यअ'): 3975,
#  ('यअ', 'एकअ'): 3973,
#  ('टअरअ', 'यअ'): 3964,
#  ('घअ', 'यअ'): 3964,
#  ('खअरअ', 'चअ'): 3952,
#  ('तअ', 'एकअ'): 3951,
#  ('बअरअ', 'बअरअ'): 3943,
#  ('हअ', 'यअतअ'): 3929,
#  ('चअ', 'डअ'): 3924,
#  ('वअ', 'जअयअ'): 3923,
#  ('ठअ', 'वअ'): 3915,
#  ('पअरअ', 'सअरअ'): 3908,
#  ('टअरअ', 'वअदअ'): 3884,
#  ('सअपअ', 'षअ'): 3882,
#  ('तअरअ', 'तअयअ'): 3876,
#  ('लअ', 'वअ'): 3874,
#  ('पअहअलअ', 'यअ'): 3860,
#  ('तअरअ', 'चअ'): 3855,
#  ('यअ', 'तअयअ'): 3835,
#  ('कअरअ', 'यअलअ'): 3835,
#  ('लअ', 'जअतअ'): 3833,
#  ('वअणअ', 'यअतअ'): 3823,
#  ('लअ', 'पअरअ'): 3812,
#  ('यअ', 'भअ'): 3810,
#  ('यअ', 'हअ'): 3799,
#  ('कअरअतअ', 'नअ'): 3776,
#  ('कअवअ', 'ळअ'): 3772,
#  ('कअ', 'पअरअ'): 3771,
#  ('हअ', 'हअ'): 3769,
#  ('आ', 'लअयअ'): 3766,
#  ('कअरअ', 'डअ'): 3765,
#  ('दअरअ', 'शअनअ'): 3765,
#  ('थअ', 'डअ'): 3764,
#  ('असअलअ', 'लअ'): 3755,
#  ('यअ', 'हअतअ'): 3754,
#  ('गअनअ', 'हअ'): 3750,
#  ('वअ', 'ई'): 3738,
#  ('तअ', 'वअरअ'): 3738,
#  ('पअरअ', 'णअमअ'): 3729,
#  ('वअ', 'ठअ'): 3725,
#  ('दअरअ', 'सअ'): 3714,
#  ('असअलअ', 'यअनअ'): 3706,
#  ('रअजअ', 'यअतअ'): 3702,
#  ('दअरअ', 'शअ'): 3699,
#  ('धअ', 'चअ'): 3695,
#  ('तअयअ', 'तअ'): 3685,
#  ('कअलअ', 'लअयअ'): 3683,
#  ('वअ', 'वअ'): 3680,
#  ('पअदअ', 'धअ'): 3658,
#  ('पअरअ', 'मअखअ'): 3651,
#  ('लअ', 'तअयअ'): 3649,
#  ('कअरअ', 'नअ'): 3615,
#  ('डअ', 'ळअ'): 3606,
#  ('सअ', 'गअतअ'): 3604,
#  ('पअरअ', 'वअशअ'): 3604,
#  ('चअ', 'शअकअ'): 3603,
#  ('मअखअ', 'यअ'): 3602,
#  ('यअ', 'मअतअ'): 3602,
#  ('नअवअ', 'हअतअ'): 3594,
#  ('पअदअ', 'नअ'): 3593,
#  ('वअणअ', 'यअ'): 3592,
#  ('नअ', 'यअतअ'): 3589,
#  ('यअ', 'कअडअ'): 3578,
#  ('यअ', 'तअरअ'): 3575,
#  ('यअ', 'मअनअ'): 3569,
#  ('चअ', 'एकअ'): 3564,
#  ('नअ', 'घअ'): 3553,
#  ('पअहअ', 'जअ'): 3545,
#  ('लअ', 'तअरअ'): 3543,
#  ('लअ', 'कअ'): 3540,
#  ('हअ', 'ऊ'): 3530,
#  ('पअरअ', 'थअमअ'): 3528,
#  ('कअ', 'वअ'): 3527,
#  ('सअ', 'टअरअ'): 3524,
#  ('यअ', 'कअमअ'): 3512,
#  ('चअ', 'आ'): 3511,
#  ('वअ', 'लअगअ'): 3509,
#  ('लअकअ', 'सअ'): 3508,
#  ('कअ', 'दअ'): 3491,
#  ('मअतअ', 'दअरअ'): 3487,
#  ('सअ', 'सअ'): 3474,
#  ('मअधअ', 'यअमअ'): 3471,
#  ('तअ', 'शअ'): 3469,
#  ('हअ', 'नअ'): 3467,
#  ('ळअ', 'चअ'): 3458,
#  ('चअ', 'कअ'): 3457,
#  ('पअरअ', 'कअलअ'): 3456,
#  ('दअलअ', 'आहअ'): 3453,
#  ('वअटअ', 'तअ'): 3453,
#  ('लअहअ', 'नअ'): 3450,
#  ('यअ', 'तअ'): 3413,
#  ('टअ', 'कअलअ'): 3403,
#  ('भअ', 'मअकअ'): 3395,
#  ('कअलअ', 'पअ'): 3394,
#  ('यअ', 'दअरअ'): 3389,
#  ('शअ', 'सअनअ'): 3378,
#  ('नअ', 'नअ'): 3370,
#  ('मअलअ', 'चअ'): 3369,
#  ('लअ', 'असअ'): 3358,
#  ('षअ', 'पअरअ'): 3357,
#  ('दअ', 'चअ'): 3357,
#  ('ञअ', 'नअ'): 3355,
#  ('पअरअ', 'भअवअ'): 3348,
#  ('अ', 'तअरअ'): 3344,
#  ('झअलअ', 'लअ'): 3340,
#  ('मअझअ', 'यअ'): 3334,
#  ('रअ', 'यअनअ'): 3331,
#  ('लअ', 'आणअ'): 3312,
#  ('कअ', 'यअतअ'): 3304,
#  ('यअकअ', 'रअतअ'): 3298,
#  ('यअ', 'शअ'): 3296,
#  ('हअ', 'एकअ'): 3273,
#  ('रअ', 'आहअतअ'): 3268,
#  ('तअमअ', 'चअ'): 3266,
#  ('रअजअ', 'कअ'): 3259,
#  ('पअरअ', 'षअदअ'): 3259,
#  ('यअकअ', 'तअ'): 3250,
#  ('एकअ', 'दअ'): 3239,
#  ('कअरअ', 'शअकअतअ'): 3231,
#  ('मअ', 'चअ'): 3230,
#  ('पअतअ', 'पअरअ'): 3228,
#  ('दअनअ', 'हअ'): 3220,
#  ('तअ', 'आहअतअ'): 3217,
#  ('चअ', 'मअतअ'): 3217,
#  ('यअ', 'सअरअ'): 3214,
#  ('यअ', 'झअलअ'): 3209,
#  ('आमअ', 'दअरअ'): 3199,
#  ('यअ', 'जअ'): 3196,
#  ('सअहअ', 'तअ'): 3195,
#  ('आहअ', 'असअ'): 3189,
#  ('षअ', 'मअ'): 3179,
#  ('यअलअ', 'यअ'): 3172,
#  ('यअतअ', 'आहअ'): 3166,
#  ('शअ', 'धअ'): 3157,
#  ('पअ', 'रअमअणअ'): 3148,
#  ('तअमअ', 'हअ'): 3128,
#  ('वअहअ', 'नअ'): 3128,
#  ('ठअ', 'वअलअ'): 3127,
#  ('आहअ', 'पअणअ'): 3125,
#  ('असअणअ', 'रअ'): 3125,
#  ('रअहअ', 'णअ'): 3122,
#  ('उतअ', 'पअदअ'): 3111,
#  ('चअ', 'हअतअ'): 3110,
#  ('चअ', 'भअ'): 3097,
#  ('वअ', 'यअ'): 3096,
#  ('झअलअ', 'हअतअ'): 3092,
#  ('यअनअ', 'कअलअ'): 3089,
#  ('वअ', 'जअ'): 3088,
#  ('अभअ', 'नअ'): 3084,
#  ('बअरअ', 'चअ'): 3075,
#  ('यअ', 'रअ'): 3068,
#  ('थअ', 'यअ'): 3067,
#  ('भअ', 'मअ'): 3059,
#  ('थअ', 'पअनअ'): 3059,
#  ('रअ', 'पअरअ'): 3048,
#  ('रअहअ', 'तअ'): 3047,
#  ('उमअ', 'दअ'): 3041,
#  ('रअ', 'रअ'): 3028,
#  ('नअ', 'यअमअ'): 3027,
#  ('सअ', 'भअ'): 3021,
#  ('सअरअकअ', 'षअ'): 3016,
#  ('तअ', 'कअरअ'): 3008,
#  ('सअ', 'वअरअ'): 3007,
#  ('शअकअ', 'यअतअ'): 2998,
#  ('यअ', 'दअनअ'): 2996,
#  ('मअतअ', 'यअ'): 2995,
#  ('सअसअ', 'थअ'): 2992,
#  ('मअरअ', 'चअ'): 2991,
#  ('यअ', 'तअरअणअ'): 2987,
#  ('सअ', 'तअनअ'): 2985,
#  ('आहअ', 'आणअ'): 2978,
#  ('भअ', 'षअ'): 2972,
#  ('यअ', 'डअ'): 2969,
#  ('वअरअ', 'यअ'): 2969,
#  ('रअ', 'तअरअ'): 2954,
#  ('तअ', 'पअणअ'): 2953,
#  ('कअरअमअ', 'चअरअ'): 2937,
#  ('रअ', 'असअलअ'): 2933,
#  ('शअ', 'तअ'): 2925,
#  ('सअरअवअ', 'चअ'): 2922,
#  ('कअ', 'षअकअ'): 2920,
#  ('धअ', 'कअरअ'): 2920,
#  ('इ', 'चअ'): 2918,
#  ('खअ', 'यअ'): 2917,
#  ('सअनअ', 'यअ'): 2905,
#  ('यअ', 'मअरअ'): 2903,
#  ('तअरअ', 'पअरअ'): 2899,
#  ('चअ', 'अधअ'): 2899,
#  ('हअतअ', 'नअ'): 2897,
#  ('रअ', 'लअवअ'): 2891,
#  ('सअरअकअ', 'रअनअ'): 2889,
#  ('यअ', 'मअलअ'): 2884,
#  ('जअ', 'ऊ'): 2884,
#  ('इतअ', 'कअ'): 2883,
#  ('लअबअ', 'धअ'): 2882,
#  ('वअ', 'कअ'): 2879,
#  ('तअरअ', 'कअ'): 2878,
#  ('वअ', 'गअ'): 2876,
#  ('उपअ', 'लअबअ'): 2872,
#  ('यअनअ', 'यअ'): 2871,
#  ('वअधअ', 'नअसअ'): 2868,
#  ('आ', 'नअदअ'): 2861,
#  ('पअरअ', 'तअ'): 2854,
#  ('आहअतअ', 'तअयअ'): 2852,
#  ('शअ', 'ळअ'): 2848,
#  ('चअ', 'सअरअ'): 2848,
#  ('नअसअ', 'भअ'): 2836,
#  ('पअरअ', 'तअनअ'): 2835,
#  ('फअ', 'यअ'): 2835,
#  ('ठअ', 'चअ'): 2834,
#  ('पअ', 'ठअ'): 2832,
#  ('नअसअ', 'लअ'): 2827,
#  ('आ', 'घअ'): 2825,
#  ('दअणअ', 'यअ'): 2823,
#  ('यअ', 'सअरअवअ'): 2821,
#  ('यअ', 'घअ'): 2812,
#  ('यअ', 'कअरअणअ'): 2804,
#  ('असअ', 'वअ'): 2795,
#  ('तअ', 'घअ'): 2794,
#  ('पअरअ', 'वअसअ'): 2791,
#  ('कअरअ', 'लअ'): 2790,
#  ('यअ', 'आ'): 2789,
#  ('मअहअ', 'पअलअ'): 2785,
#  ('लअयअ', 'वअरअ'): 2782,
#  ('दअरअ', 'चअ'): 2781,
#  ('कअमअ', 'तअ'): 2766,
#  ('तअ', 'यअहअ'): 2764,
#  ('वअ', 'मअनअ'): 2763,
#  ('तअ', 'असअ'): 2751,
#  ('सअकअ', 'ळअ'): 2749,
#  ('कअमअ', 'गअरअ'): 2746,
#  ('यअ', 'अधअ'): 2742,
#  ('जअमअ', 'नअ'): 2738,
#  ('कअलअ', 'हअ'): 2726,
#  ('उचअ', 'चअ'): 2726,
#  ('ठअ', 'वअणअ'): 2725,
#  ('लअ', 'आहअतअ'): 2722,
#  ('झअलअ', 'यअनअ'): 2721,
#  ('कअलअ', 'यअनअ'): 2718,
#  ('चअ', 'लअकअ'): 2714,
#  ('सअमअ', 'सअ'): 2704,
#  ('कअतअ', 'चअ'): 2702,
#  ('नअ', 'वअहअ'): 2694,
#  ('वअयअ', 'चअ'): 2693,
#  ('मअनअ', 'यअ'): 2691,
#  ('वअशअ', 'वअसअ'): 2690,
#  ('लअकअ', 'नअ'): 2689,
#  ('हअणअ', 'यअ'): 2689,
#  ('ळअ', 'नअ'): 2686,
#  ('हअ', 'तअ'): 2681,
#  ('अनअ', 'यअ'): 2681,
#  ('पअरअ', 'सअदअ'): 2680,
#  ('यअ', 'मअधअ'): 2679,
#  ('वअतअ', 'तअ'): 2679,
#  ('वअरअ', 'दअ'): 2678,
#  ('चअ', 'यअतअ'): 2675,
#  ('तअ', 'लअयअ'): 2673,
#  ('तअरअ', 'गअतअ'): 2670,
#  ('कअरअतअ', 'तअ'): 2669,
#  ('बअ', 'ठअकअ'): 2669,
#  ('घअ', 'चअ'): 2669,
#  ('यअ', 'टअ'): 2669,
#  ('तअ', 'झअलअ'): 2668,
#  ('नअ', 'सअ'): 2641,
#  ('अ', 'गअदअ'): 2636,
#  ('सअपअ', 'रअणअ'): 2634,
#  ('वअणअ', 'यअसअ'): 2634,
#  ('पअलअ', 'कअ'): 2633,
#  ('ळअ', 'यअ'): 2631,
#  ('तअ', 'पअ'): 2626,
#  ('वअलअ', 'आहअ'): 2626,
#  ('यअलअ', 'यअतअ'): 2623,
#  ('पअरअ', 'लअ'): 2622,
#  ('सअमअ', 'वअशअ'): 2618,
#  ('लअ', 'यअलअ'): 2615,
#  ('सअरअ', 'खअ'): 2610,
#  ('तअ', 'दअ'): 2609,
#  ('थअ', 'चअ'): 2596,
#  ('यअमअ', 'ळअ'): 2594,
#  ('पअकअ', 'सअ'): 2591,
#  ('यअ', 'तअलअ'): 2587,
#  ('नअ', 'दअलअ'): 2586,
#  ('सअचअ', 'नअ'): 2586,
#  ('रअ', 'कअलअ'): 2586,
#  ('दअशअ', 'चअ'): 2574,
#  ('तअलअ', 'आहअ'): 2573,
#  ('हअ', 'मअहअ'): 2569,
#  ('यअ', 'ईलअ'): 2569,
#  ('दअ', 'यअकअ'): 2568,
#  ('सअवअ', 'चअ'): 2567,
#  ('दअशअ', 'तअ'): 2560,
#  ('थअनअ', 'कअ'): 2553,
#  ('कअतअ', 'कअलअ'): 2542,
#  ('नअ', 'हअमअ'): 2536,
#  ('हअ', 'असअ'): 2533,
#  ('कअलअ', 'नअ'): 2521,
#  ('चअ', 'कअलअ'): 2517,
#  ('मअळअ', 'णअ'): 2508,
#  ('वअलअ', 'यअ'): 2497,
#  ('आरअ', 'थअकअ'): 2496,
#  ('जअतअ', 'तअ'): 2494,
#  ('यअ', 'रअजअ'): 2490,
#  ('चअ', 'वअरअ'): 2489,
#  ('सअ', 'धअरअणअ'): 2481,
#  ('आ', 'वअहअनअ'): 2480,
#  ('खअरअ', 'दअ'): 2479,
#  ('यअ', 'सअमअ'): 2476,
#  ('दअ', 'वअशअ'): 2468,
#  ('सअ', 'घअटअनअ'): 2464,
#  ('शअ', 'वअ'): 2464,
#  ('हअ', 'तअरअ'): 2462,
#  ('कअरअ', 'तअ'): 2459,
#  ('पअहअ', 'णअ'): 2457,
#  ('तअपअ', 'सअ'): 2453,
#  ('उपअ', 'यअ'): 2450,
#  ('चअ', 'सअमअ'): 2446,
#  ('दअ', 'पअरअ'): 2445,
#  ('मअलअ', 'नअ'): 2434,
#  ('तअ', 'असअतअ'): 2431,
#  ('धअ', 'यअकअ'): 2431,
#  ('मअणअ', 'तअ'): 2427,
#  ('रअ', 'कअरअणअ'): 2425,
#  ('गअ', 'भअरअ'): 2423,
#  ('यअ', 'अनअ'): 2410,
#  ('चअ', 'पअ'): 2408,
#  ('अ', 'जअनअ'): 2399,
#  ('कअ', 'नअ'): 2393,
#  ('यअ', 'लअकअ'): 2392,
#  ('आलअ', 'लअयअ'): 2392,
#  ('सअतअ', 'वअ'): 2390,
#  ('सअहअ', 'भअ'): 2389,
#  ('तअ', 'मअहअलअ'): 2388,
#  ('यअकअ', 'रअमअ'): 2388,
#  ('तअकअ', 'रअ'): 2385,
#  ('सअनअ', 'नअ'): 2383,
#  ('षअ', 'पअ'): 2382,
#  ('घअ', 'डअ'): 2373,
#  ('आलअ', 'लअ'): 2372,
#  ('ढअ', 'लअ'): 2368,
#  ('सअरअ', 'तअ'): 2367,
#  ('वअ', 'तअयअ'): 2367,
#  ('हअ', 'कअ'): 2366,
#  ('आहअ', 'पअरअ'): 2360,
#  ('यअनअ', 'हअ'): 2355,
#  ('हअतअ', 'आहअ'): 2353,
#  ('आदअ', 'लअनअ'): 2346,
#  ('ढअ', 'तअ'): 2343,
#  ('पअरअ', 'वअनअ'): 2343,
#  ('रअ', 'हअ'): 2343,
#  ('तअयअ', 'सअ'): 2340,
#  ('आणअ', 'नअ'): 2338,
#  ('सअमअनअ', 'यअ'): 2338,
#  ('दअलअ', 'यअ'): 2336,
#  ('टअरअ', 'चअ'): 2332,
#  ('चअ', 'शअ'): 2332,
#  ('दअणअ', 'रअ'): 2331,
#  ('मअजअ', 'रअ'): 2330,
#  ('वअहअ', 'तअकअ'): 2329,
#  ('मअलअ', 'गअ'): 2323,
#  ('जअयअ', 'चअ'): 2319,
#  ('ए', 'खअदअ'): 2318,
#  ('कअरअणअ', 'तअ'): 2317,
#  ('पअरअ', 'पअतअ'): 2317,
#  ('आरअ', 'गअ'): 2309,
#  ('णअ', 'चअ'): 2308,
#  ('चअ', 'रअजअ'): 2308,
#  ('लअयअ', 'तअ'): 2306,
#  ('शअबअ', 'दअ'): 2298,
#  ('कअलअ', 'जअ'): 2292,
#  ('टअचअ', 'यअ'): 2289,
#  ('यअनअ', 'दअलअ'): 2288,
#  ('रअ', 'शअ'): 2286,
#  ('आणअ', 'खअ'): 2283,
#  ('मअ', 'डअलअ'): 2282,
#  ('वअसअ', 'तअ'): 2280,
#  ('एकअ', 'पअरअ'): 2280,
#  ('सअदअ', 'सअ'): 2279,
#  ('मअणअ', 'सअ'): 2278,
#  ('यअनअ', 'तअयअ'): 2275,
#  ('तअ', 'आलअ'): 2274,
#  ('ळअ', 'वअरअ'): 2274,
#  ('आणअ', 'पअरअ'): 2272,
#  ('यअलअ', 'यअनअ'): 2270,
#  ('उपअ', 'चअरअ'): 2268,
#  ('वअहअ', 'डअ'): 2268,
#  ('बअ', 'यअ'): 2268,
#  ('तअ', 'जअ'): 2267,
#  ('सअ', 'शअ'): 2267,
#  ('वअसअ', 'यअ'): 2266,
#  ('यअ', 'ठअ'): 2265,
#  ('तअरअ', 'कअतअ'): 2265,
#  ('मअडअ', 'ळअ'): 2264,
#  ('आहअ', 'मअतअ'): 2264,
#  ('तअनअ', 'धअ'): 2264,
#  ('कअ', 'यअमअ'): 2262,
#  ('टअ', 'तअ'): 2257,
#  ('कअ', 'टअरअ'): 2245,
#  ('चअरअ', 'यअ'): 2243,
#  ('कअटअ', 'बअ'): 2242,
#  ('नअ', 'मअतअ'): 2241,
#  ('यअतअ', 'यअतअ'): 2240,
#  ('वअणअ', 'रअ'): 2237,
#  ('भअ', 'नअवअ'): 2234,
#  ('नअ', 'आणअ'): 2233,
#  ('पअतअ', 'रअ'): 2231,
#  ('वअतअ', 'तअरअ'): 2230,
#  ('नअ', 'एकअ'): 2229,
#  ('कअ', 'सअनअ'): 2228,
#  ('पअतअ', 'ळअ'): 2221,
#  ('चअ', 'आणअ'): 2219,
#  ('चअ', 'आरअ'): 2217,
#  ('यअ', 'पअणअ'): 2217,
#  ('बअ', 'जअ'): 2217,
#  ('जअतअ', 'आहअ'): 2214,
#  ('ठअ', 'पअरअ'): 2212,
#  ('अरअ', 'जअ'): 2211,
#  ('दअ', 'घअ'): 2207,
#  ('पअरअ', 'दअरअ'): 2206,
#  ('नअ', 'दअ'): 2204,
#  ('आहअतअ', 'यअ'): 2201,
#  ('नअ', 'षअ'): 2201,
#  ('दअरअ', 'वअ'): 2199,
#  ('कअरअ', 'जअ'): 2197,
#  ('लअकअ', 'चअ'): 2193,
#  ('आणअ', 'तअ'): 2189,
#  ('कअ', 'वअरअ'): 2178,
#  ('पअ', 'तअरअ'): 2175,
#  ('हअलअ', 'लअ'): 2174,
#  ('डअ', 'वअ'): 2173,
#  ('पअरअ', 'कअशअ'): 2172,
#  ('सअ', 'टअ'): 2168,
#  ('हअ', 'सअ'): 2166,
#  ('यअ', 'मअ'): 2166,
#  ('लअ', 'डअ'): 2164,
#  ('नअ', 'टअकअ'): 2159,
#  ('तअ', 'रअहअ'): 2158,
#  ('मअनअ', 'तअ'): 2153,
#  ('घअडअ', 'लअ'): 2142,
#  ('शअनअ', 'चअ'): 2141,
#  ('चअ', 'अ'): 2141,
#  ('कअढअ', 'णअ'): 2135,
#  ('बअसअ', 'लअ'): 2132,
#  ('यअ', 'चअरअ'): 2132,
#  ('तअयअ', 'वअरअ'): 2131,
#  ('फअडअ', 'णअ'): 2130,
#  ('यअ', 'सअमअरअ'): 2128,
#  ('वअरअ', 'पअरअ'): 2126,
#  ('मअटअ', 'रअ'): 2125,
#  ('एकअ', 'णअ'): 2121,
#  ('ई', 'तअ'): 2118,
#  ('यअतअ', 'आ'): 2117,
#  ('पअतअ', 'रअकअरअ'): 2114,
#  ('नअसअ', 'लअयअ'): 2114,
#  ('वअ', 'कअलअ'): 2110,
#  ('कअ', 'तअकअ'): 2104,
#  ('यअ', 'अ'): 2104,
#  ('ई', 'चअ'): 2095,
#  ('बअ', 'दअरअ'): 2087,
#  ('भअरअतअ', 'चअ'): 2079,
#  ('णअ', 'कअलअ'): 2077,
#  ('तअयअ', 'वअळअ'): 2076,
#  ('पअरअ', 'पअरअ'): 2076,
#  ('यअ', 'घअरअ'): 2075,
#  ('लअ', 'मअहअ'): 2070,
#  ('पअरअ', 'सअतअ'): 2070,
#  ('तअ', 'यअनअ'): 2068,
#  ('सअनअ', 'मअ'): 2063,
#  ('हअतअ', 'हअ'): 2063,
#  ('सअवअ', 'कअ'): 2060,
#  ('पअसअ', 'तअकअ'): 2059,
#  ('वअ', 'सअनअ'): 2058,
#  ('दअरअ', 'नअ'): 2058,
#  ('धअरअ', 'मअ'): 2057,
#  ('जअ', 'वअणअ'): 2056,
#  ('ठअ', 'यअ'): 2055,
#  ('यअतअ', 'तअ'): 2054,
#  ('पअरअ', 'भअ'): 2050,
#  ('पअढअ', 'लअ'): 2050,
#  ('नअ', 'मअहअ'): 2050,
#  ('कअमअ', 'नअ'): 2049,
#  ('तअ', 'मअ'): 2045,
#  ('नअरअमअ', 'तअ'): 2044,
#  ('पअ', 'पअरअ'): 2044,
#  ('हअ', 'कअरअ'): 2041,
#  ('तअ', 'सअवअ'): 2039,
#  ('अपअ', 'कअ'): 2037,
#  ('वअरअ', 'हअ'): 2034,
#  ('कअरअ', 'कअ'): 2033,
#  ('सअखअ', 'यअ'): 2031,
#  ('षअ', 'कअरअ'): 2031,
#  ('खअसअ', 'दअरअ'): 2028,
#  ('नअ', 'वअरअ'): 2023,
#  ('शअनअ', 'वअरअ'): 2022,
#  ('वअ', 'कअतअ'): 2021,
#  ('यअ', 'बअदअ'): 2016,
#  ('मअतअ', 'तअ'): 2015,
#  ('चअ', 'वअळअ'): 2012,
#  ('आहअ', 'तअरअ'): 2009,
#  ('कअढअ', 'लअ'): 2006,
#  ('यअ', 'नअतअ'): 2005,
#  ('यअमअ', 'तअनअ'): 2002,
#  ('शअकअतअ', 'नअ'): 2001,
#  ('कअ', 'हअ'): 1994,
#  ('यअ', 'टअकअ'): 1990,
#  ('चअ', 'कअरअणअ'): 1988,
#  ('नअ', 'आपअ'): 1987,
#  ('आहअ', 'मअ'): 1987,
#  ('घअ', 'षअणअ'): 1985,
#  ('तअरअ', 'वअ'): 1985,
#  ('यअ', 'बअरअ'): 1984,
#  ('यअ', 'असअ'): 1984,
#  ('मअतअ', 'दअनअ'): 1984,
#  ('जअनअ', 'वअरअ'): 1983,
#  ('यअतअ', 'चअ'): 1983,
#  ('गअणअ', 'लअयअ'): 1983,
#  ('यअ', 'आहअतअ'): 1980,
#  ('शअकअ', 'लअ'): 1979,
#  ('शअकअ', 'यअ'): 1978,
#  ('कअलअ', 'तअयअ'): 1977,
#  ('तअ', 'कअमअ'): 1971,
#  ('सअ', 'धअनअ'): 1969,
#  ('शअकअ', 'षअकअ'): 1966,
#  ('नअ', 'धअ'): 1965,
#  ('लअ', 'एकअ'): 1963,
#  ('नअ', 'कअरअतअ'): 1963,
#  ('चअरअ', 'लअ'): 1962,
#  ('वअजअ', 'तअ'): 1962,
#  ('आ', 'दअशअ'): 1959,
#  ('यअ', 'दअशअ'): 1956,
#  ('लअ', 'कअलअ'): 1955,
#  ('लअयअ', 'मअळअ'): 1951,
#  ('चअ', 'मअगअ'): 1947,
#  ('पअरअ', 'शअसअ'): 1946,
#  ('जअबअ', 'बअ'): 1944,
#  ('हअतअ', 'पअणअ'): 1943,
#  ('यअ', 'पअदअ'): 1943,
#  ('शअकअतअ', 'तअ'): 1934,
#  ('मअनअ', 'लअ'): 1932,
#  ('तअ', 'यअतअ'): 1931,
#  ('सअहअ', 'कअरअ'): 1931,
#  ('यअ', 'तअनअ'): 1928,
#  ('यअ', 'सअनअ'): 1924,
#  ('आहअ', 'मअहअ'): 1923,
#  ('रअजअ', 'कअरअणअ'): 1920,
#  ('चअ', 'वअयअ'): 1920,
#  ('यअ', 'पअलअ'): 1920,
#  ('सअ', 'गअ'): 1919,
#  ('तअरअ', 'रअ'): 1915,
#  ('लअ', 'सअ'): 1915,
#  ('जअणअ', 'नअ'): 1913,
#  ('लअगअ', 'णअ'): 1913,
#  ('वअ', 'असअ'): 1912,
#  ('नअ', 'मअलअ'): 1912,
#  ('कअरअ', 'सअ'): 1910,
#  ('तअ', 'मअळअ'): 1909,
#  ('यअनअ', 'सअगअ'): 1908,
#  ('ळअ', 'लअ'): 1907,
#  ('अनअ', 'भअवअ'): 1905,
#  ('जअ', 'ईलअ'): 1905,
#  ('तअ', 'वअरअणअ'): 1903,
#  ('लअ', 'असअतअ'): 1895,
#  ('दअशअ', 'तअलअ'): 1894,
#  ('णअकअ', 'तअ'): 1893,
#  ('असअ', 'मअहअ'): 1892,
#  ('चअ', 'सअवअ'): 1888,
#  ('बअ', 'चअ'): 1887,
#  ('हअतअ', 'आणअ'): 1886,
#  ('आणअ', 'वअ'): 1880,
#  ('अपअ', 'घअ'): 1877,
#  ('सअरअ', 'कअलअ'): 1877,
#  ('मअ', 'वअरअ'): 1876,
#  ('रअ', 'वअ'): 1875,
#  ('यअ', 'कअहअ'): 1872,
#  ('तअ', 'सअरअ'): 1871,
#  ('लअकअ', 'पअरअ'): 1871,
#  ('मअडअ', 'यअ'): 1870,
#  ('आहअ', 'वअ'): 1863,
#  ('शअ', 'वअरअ'): 1859,
#  ('वअ', 'लअगअतअ'): 1859,
#  ('शअसअ', 'तअरअ'): 1859,
#  ('बअलअ', 'तअ'): 1859,
#  ('सअवअ', 'तअचअ'): 1858,
#  ('लअयअ', 'सअ'): 1854,
#  ('तअरअ', 'नअ'): 1853,
#  ('हअ', 'दअखअलअ'): 1846,
#  ('धअकअ', 'कअ'): 1844,
#  ('नअगअरअ', 'कअ'): 1843,
#  ('सअहअ', 'बअ'): 1843,
#  ('अतअ', 'शअयअ'): 1842,
#  ('कअ', 'कअरअ'): 1838,
#  ('वअ', 'अशअ'): 1837,
#  ('यअसअ', 'रअखअ'): 1837,
#  ('असअ', 'सअ'): 1835,
#  ('कअतअ', 'नअ'): 1834,
#  ('षअ', 'सअ'): 1834,
#  ('खअदअ', 'यअ'): 1833,
#  ('टअलअ', 'आहअ'): 1832,
#  ('मअकअ', 'तअ'): 1828,
#  ('फअरअ', 'सअ'): 1828,
#  ('पअणअ', 'यअतअ'): 1826,
#  ('तअनअ', 'चअ'): 1824,
#  ('यअ', 'वअहअ'): 1822,
#  ('चअ', 'अनअ'): 1822,
#  ('नअरअ', 'दअरअ'): 1821,
#  ('वअदअ', 'चअ'): 1820,
#  ('हअतअ', 'कअ'): 1820,
#  ('सअ', 'जअयअ'): 1820,
#  ('भअ', 'चअ'): 1818,
#  ('रअ', 'कअरअ'): 1817,
#  ('एकअ', 'सअ'): 1817,
#  ('पअणअ', 'तअयअ'): 1817,
#  ('यअ', 'सअवअ'): 1814,
#  ('रअ', 'असअ'): 1813,
#  ('धअ', 'दअ'): 1810,
#  ('यअनअ', 'वअ'): 1809,
#  ('चअ', 'बअ'): 1809,
#  ('बअ', 'धअकअ'): 1809,
#  ('वअनअ', 'गअ'): 1808,
#  ('पअदअ', 'रअथअ'): 1805,
#  ('कअमअ', 'कअरअणअ'): 1804,
#  ('वअ', 'मअ'): 1803,
#  ('पअहअ', 'तअ'): 1802,
#  ('रअ', 'तअयअ'): 1801,
#  ('डअ', 'ओ'): 1801,
#  ('सअमअ', 'वअरअ'): 1797,
#  ('जअरअ', 'दअरअ'): 1797,
#  ('लअ', 'जअ'): 1796,
#  ('लअवअ', 'लअ'): 1795,
#  ('यअकअ', 'डअनअ'): 1795,
#  ('तअलअ', 'नअ'): 1794,
#  ('णअ', 'वअसअ'): 1793,
#  ('तअ', 'चअ'): 1792,
#  ('कअरअ', 'मअ'): 1788,
#  ('तअ', 'भअ'): 1787,
#  ('उदअ', 'धअ'): 1783,
#  ('नअवअ', 'दअलअ'): 1781,
#  ('चअ', 'मअलअ'): 1779,
#  ('वअरअ', 'वअ'): 1778,
#  ('षअ', 'मअतअ'): 1777,
#  ('कअ', 'सअ'): 1776,
#  ('कअरअ', 'कअटअ'): 1775,
#  ('यअ', 'चअकअ'): 1775,
#  ('टअ', 'ळअ'): 1774,
#  ('घअटअनअ', 'चअ'): 1774,
#  ('यअ', 'सअरअकअ'): 1772,
#  ('दअहअशअतअ', 'वअदअ'): 1772,
#  ('बअरअ', 'यअ'): 1771,
#  ('थअ', 'टअ'): 1769,
#  ('सअमअजअ', 'कअ'): 1767,
#  ('कअ', 'आणअ'): 1766,
#  ('णअ', 'वअ'): 1765,
#  ('कअ', 'मअहअ'): 1763,
#  ...}

# %%
# fin_dict_bi

# %%
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert2k_uni_tokens.txt', 'w',encoding = 'utf-8') as f3:
    for key, value in fin_dict.items():
        f3.write('%s : %s\n' % (key, value))
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert2k_bi_tokens.txt', 'w',encoding = 'utf-8') as f4:
    for key, value in fin_dict_bi.items():
        f4.write('%s : %s\n' % (key, value))

# %%
all_tokens = list(fin_dict.keys())

# %%
L_char_bi = []
L_syl_bi = []

# %%
syl_bi_global = {}
syl_bi_local = {}
char_bi_global = {}
char_bi_local = {}

# %%
i=0
# while (i<len(all_tokens)-1):
for tok in all_tokens:
  i=len(tok)-1
  while (i>0):
    if tok[i] != 'ं' and tok[i] != 'ँ' and tok[i] != 'ः' and tok[i-1] != 'ं' and tok[i-1] != 'ँ' and tok[i-1] != 'ः':
        if tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-1]+tok[i]] += fin_dict[tok]
    elif i>1 and tok[i-1] == 'ं' or tok[i-1] == 'ँ' or tok[i-1] == 'ः' or  tok[i] == 'ं' or tok[i] == 'ँ' or tok[i] == 'ः':
        if tok[i-2]+tok[i-1]+tok[i] not in list(char_bi_local.keys()):
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] = 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] = fin_dict[tok]
        else:
            char_bi_local[tok[i-2]+tok[i-1]+tok[i]] += 1
            char_bi_global[tok[i-2]+tok[i-1]+tok[i]] += fin_dict[tok]
        # i-=1
    if (i<len(tok)-1) and (tok[i+1] == 'ं' or tok[i+1] == 'ँ' or tok[i+1] == 'ः'):
      i-=1
    i-=1

# %%
all_syllables = []
for i in range(len(all_tokens)):
    all_syllables.append([])

# %%
dict_count_uni = {}
dict_count_bi = {}
syl_count_uni = {}
syl_count_bi = {}

# %%
k=0
for words in all_tokens:
    j=0
    # for i in range(len(words)):
    i=0
    while (i<len(words)):
        if ord(words[i]) >=2305 and ord(words[i])<2325:
            if i<len(words)-1 and words[i+1] != 'ः' and words[i+1] != 'ं' and words[i+1] != 'ँ':
                if words[j:i+1] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+1]] = 1
                else:
                    syl_count_uni[words[j:i+1]] += 1
                all_syllables[k].append(words[j:i+1])
                j=i+1
            else:
                if words[j:i+2] not in list(syl_count_uni.keys()):
                    syl_count_uni[words[j:i+2]] = 1
                else:
                    syl_count_uni[words[j:i+2]] += 1
                all_syllables[k].append(words[j:i+2])
                j=i+2
                i+=1
        i+=1
    if k%1000 == 0:
        print(k)
    k+=1
# Out:
# 0
# 1000

# %%
# fin_dict(all_tokens[0])

# %%
k=0
for syls in all_syllables:
    j=0
    for i in range(len(syls)-1):
        if syls[i]+syls[i+1] not in list(syl_bi_local.keys()):
            syl_bi_local[syls[i]+syls[i+1]] = 1
            syl_bi_global[syls[i]+syls[i+1]] = fin_dict[all_tokens[k]]
        else:
            syl_bi_local[syls[i]+syls[i+1]] += 1
            syl_bi_global[syls[i]+syls[i+1]] += fin_dict[all_tokens[k]]
    k+=1
    if k%10000==0:
        print(k)

# %%
fin_dict_char_l = {k: v for k, v in sorted(char_bi_local.items(), key=lambda item: item[1],reverse=True)}
fin_dict_syl_l = {k: v for k, v in sorted(syl_bi_local.items(), key=lambda item: item[1],reverse=True)}

# %%
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert2k_bi_chars.txt', 'w',encoding = 'utf-8') as f3:
    f3.write('Char : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_char_l.items():
        f3.write('%s : %s : %s\n' % (key, value, char_bi_global[key]))
with open('/content/gdrive/MyDrive/cs689/a1/indicbert/fin_indicbert2k_bi_syls.txt', 'w',encoding = 'utf-8') as f4:
    f4.write('Syl : Freq_in_tokens : Freq_in_corpus\n')
    for key, value in fin_dict_syl_l.items():
        f4.write('%s : %s : %s\n' % (key, value, syl_bi_global[key]))
